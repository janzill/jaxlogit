# %% [markdown]
# # Mixed Logit

# %%
import pandas as pd
import numpy as np
import jax

from jaxlogit.mixed_logit import MixedLogit

# %%
#  64bit precision
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Swissmetro Dataset

# %% [markdown]
# The swissmetro dataset contains stated-preferences for three alternative transportation modes that include car, train and a newly introduced mode: the swissmetro. This dataset is commonly used for estimation examples with the `Biogeme` and `PyLogit` packages. The dataset is available at http://transp-or.epfl.ch/data/swissmetro.dat and [Bierlaire et. al., (2001)](https://transp-or.epfl.ch/documents/proceedings/BierAxhaAbay01.pdf) provides a detailed discussion of the data as wells as its context and collection process. The explanatory variables in this example include the travel time (`TT`) and cost `CO` for each of the three alternative modes.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is imported to the Python environment using `pandas`. Then, two types of samples, ones with a trip purpose different to commute or business and ones with an unknown choice, are filtered out. The original dataset contains 10,729 records, but after filtering, 6,768 records remain for following analysis. Finally, a new column that uniquely identifies each sample is added to the dataframe and the `CHOICE` column, which originally contains a numerical coding of the choices, is mapped to a description that is consistent with the alternatives in the column names.

# %%
df_wide = pd.read_table("http://transp-or.epfl.ch/data/swissmetro.dat", sep='\t')

# Keep only observations for commute and business purposes that contain known choices
df_wide = df_wide[(df_wide['PURPOSE'].isin([1, 3]) & (df_wide['CHOICE'] != 0))]

df_wide['custom_id'] = np.arange(len(df_wide))  # Add unique identifier
df_wide['CHOICE'] = df_wide['CHOICE'].map({1: 'TRAIN', 2:'SM', 3: 'CAR'})
df_wide
# Out:
#       GROUP  SURVEY  SP   ID  PURPOSE  FIRST  TICKET  WHO  LUGGAGE  AGE  ...  \
# 0         2       0   1    1        1      0       1    1        0    3  ...
# 1         2       0   1    1        1      0       1    1        0    3  ...
# 2         2       0   1    1        1      0       1    1        0    3  ...
# 3         2       0   1    1        1      0       1    1        0    3  ...
# 4         2       0   1    1        1      0       1    1        0    3  ...
# ...     ...     ...  ..  ...      ...    ...     ...  ...      ...  ...  ...
# 8446      3       1   1  939        3      1       7    3        1    5  ...
# 8447      3       1   1  939        3      1       7    3        1    5  ...
# 8448      3       1   1  939        3      1       7    3        1    5  ...
# 8449      3       1   1  939        3      1       7    3        1    5  ...
# 8450      3       1   1  939        3      1       7    3        1    5  ...
#
#       TRAIN_CO  TRAIN_HE  SM_TT  SM_CO  SM_HE  SM_SEATS  CAR_TT  CAR_CO  \
# 0           48       120     63     52     20         0     117      65
# 1           48        30     60     49     10         0     117      84
# 2           48        60     67     58     30         0     117      52
# 3           40        30     63     52     20         0      72      52
# 4           36        60     63     42     20         0      90      84
# ...        ...       ...    ...    ...    ...       ...     ...     ...
# 8446        13        30     50     17     30         0     130      64
# 8447        12        30     53     16     10         0      80      80
# 8448        16        60     50     16     20         0      80      64
# 8449        16        30     53     17     30         0      80     104
# 8450        13        60     53     21     30         0     100      80
#
#       CHOICE  custom_id
# 0         SM          0
# 1         SM          1
# 2         SM          2
# 3         SM          3
# 4         SM          4
# ...      ...        ...
# 8446   TRAIN       6763
# 8447   TRAIN       6764
# 8448   TRAIN       6765
# 8449   TRAIN       6766
# 8450   TRAIN       6767
#
# [6768 rows x 29 columns]

# %% [markdown]
# ### Reshape data

# %% [markdown]
# The imported dataframe is in wide format, and it needs to be reshaped to long format for processing by `xlogit`, which offers the convenient `wide_to_long` utility for this reshaping process. The user needs to specify the column that uniquely identifies each sample, the names of the alternatives, the columns that vary across alternatives, and whether the alternative names are a prefix or suffix of the column names. Additionally, the user can specify a value (`empty_val`) to be used by default when an alternative is not available for a certain variable. Additional usage examples for the `wide_to_long` function are available in xlogit's documentation at https://xlogit.readthedocs.io/en/latest/notebooks/convert_data_wide_to_long.html. Also, details about the function parameters are available at the [API reference ](https://xlogit.readthedocs.io/en/latest/api/utils.html#xlogit.utils.wide_to_long).

# %%
from jaxlogit.utils import wide_to_long

df = wide_to_long(df_wide, id_col='custom_id', alt_name='alt', sep='_',
                  alt_list=['TRAIN', 'SM', 'CAR'], empty_val=0,
                  varying=['TT', 'CO', 'HE', 'AV', 'SEATS'], alt_is_prefix=True)
df
# Out:
#        custom_id    alt   TT   CO   HE  AV  SEATS  GROUP  SURVEY  SP  ...  \
# 0              0  TRAIN  112   48  120   1      0      2       0   1  ...
# 1              0     SM   63   52   20   1      0      2       0   1  ...
# 2              0    CAR  117   65    0   1      0      2       0   1  ...
# 3              1  TRAIN  103   48   30   1      0      2       0   1  ...
# 4              1     SM   60   49   10   1      0      2       0   1  ...
# ...          ...    ...  ...  ...  ...  ..    ...    ...     ...  ..  ...
# 20299       6766     SM   53   17   30   1      0      3       1   1  ...
# 20300       6766    CAR   80  104    0   1      0      3       1   1  ...
# 20301       6767  TRAIN  108   13   60   1      0      3       1   1  ...
# 20302       6767     SM   53   21   30   1      0      3       1   1  ...
# 20303       6767    CAR  100   80    0   1      0      3       1   1  ...
#
#        TICKET  WHO  LUGGAGE  AGE  MALE  INCOME  GA  ORIGIN  DEST  CHOICE
# 0           1    1        0    3     0       2   0       2     1      SM
# 1           1    1        0    3     0       2   0       2     1      SM
# 2           1    1        0    3     0       2   0       2     1      SM
# 3           1    1        0    3     0       2   0       2     1      SM
# 4           1    1        0    3     0       2   0       2     1      SM
# ...       ...  ...      ...  ...   ...     ...  ..     ...   ...     ...
# 20299       7    3        1    5     1       2   0       1     2   TRAIN
# 20300       7    3        1    5     1       2   0       1     2   TRAIN
# 20301       7    3        1    5     1       2   0       1     2   TRAIN
# 20302       7    3        1    5     1       2   0       1     2   TRAIN
# 20303       7    3        1    5     1       2   0       1     2   TRAIN
#
# [20304 rows x 23 columns]

# %% [markdown]
# ### Create model specification

# %% [markdown]
# Following the reshaping, users can create or update the dataset's columns in order to accommodate their model specification needs, if necessary. The code below shows how the columns `ASC_TRAIN` and `ASC_CAR` were created to incorporate alternative-specific constants in the model. In addition, the example illustrates an effective way of establishing variable interactions (e.g., trip costs for commuters with an annual pass) by updating existing columns conditional on values of other columns. Although apparently simple, column operations provide users with an intuitive and highly-flexible mechanism to incorporate model specification aspects, such as variable transformations, interactions, and alternative specific coefficients and constants. By operating the dataframe columns, any utility specification can be accommodated in `xlogit`. As shown in [this specification example](https://xlogit.readthedocs.io/en/latest/notebooks/multinomial_model.html#Create-model-specification), highly-flexible utility specifications can be modeled in `xlogit` by operating the dataframe columns.

# %%
df['ASC_TRAIN'] = np.ones(len(df))*(df['alt'] == 'TRAIN')
df['ASC_CAR'] = np.ones(len(df))*(df['alt'] == 'CAR')
df['TT'], df['CO'] = df['TT']/100, df['CO']/100  # Scale variables
annual_pass = (df['GA'] == 1) & (df['alt'].isin(['TRAIN', 'SM']))
df.loc[annual_pass, 'CO'] = 0  # Cost zero for pass holders

# %% [markdown]
# ### Estimate model parameters

# %% [markdown]
# The `fit` method estimates the model by taking as input the data from the previous step along with additional specification criteria, such as the distribution of the random parameters (`randvars`), the number of random draws (`n_draws`), and the availability of alternatives for the choice situations (`avail`). We set the optimization method as `L-BFGS-B` as this is a robust routine that usually helps solve convergence issues.  Once the estimation routine is completed, the `summary` method can be used to display the estimation results.

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'CO', 'TT']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars={'TT': 'n'},
    n_draws=1500,
)
model.summary()
# Out:
# 2025-07-04 14:06:12,313 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# INFO:2025-07-04 14:06:12,397:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 14:06:12,397 INFO jax._src.xla_bridge: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 14:06:14,522 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 14:06:15,121 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 7309.54
# 2025-07-04 14:06:15,124 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 14:06:15,886 INFO jaxlogit._optimize: Iter 1, fun = 5509.545, |grad| = 1054.174
# 2025-07-04 14:06:16,336 INFO jaxlogit._optimize: Iter 2, fun = 4969.103, |grad| = 571.378
# 2025-07-04 14:06:16,758 INFO jaxlogit._optimize: Iter 3, fun = 4611.336, |grad| = 275.850
# 2025-07-04 14:06:17,224 INFO jaxlogit._optimize: Iter 4, fun = 4470.256, |grad| = 221.282
# 2025-07-04 14:06:17,685 INFO jaxlogit._optimize: Iter 5, fun = 4395.300, |grad| = 63.354
# 2025-07-04 14:06:18,162 INFO jaxlogit._optimize: Iter 6, fun = 4380.971, |grad| = 54.077
# 2025-07-04 14:06:18,631 INFO jaxlogit._optimize: Iter 7, fun = 4366.435, |grad| = 40.186
# 2025-07-04 14:06:19,110 INFO jaxlogit._optimize: Iter 8, fun = 4360.871, |grad| = 13.210
# 2025-07-04 14:06:19,565 INFO jaxlogit._optimize: Iter 9, fun = 4360.011, |grad| = 10.823
# 2025-07-04 14:06:20,026 INFO jaxlogit._optimize: Iter 10, fun = 4359.481, |grad| = 6.401
# 2025-07-04 14:06:20,510 INFO jaxlogit._optimize: Iter 11, fun = 4359.251, |grad| = 2.223
# 2025-07-04 14:06:21,009 INFO jaxlogit._optimize: Iter 12, fun = 4359.224, |grad| = 1.269
# 2025-07-04 14:06:21,498 INFO jaxlogit._optimize: Iter 13, fun = 4359.219, |grad| = 0.360
# 2025-07-04 14:06:21,959 INFO jaxlogit._optimize: Iter 14, fun = 4359.218, |grad| = 0.078
# 2025-07-04 14:06:22,451 INFO jaxlogit._optimize: Iter 15, fun = 4359.218, |grad| = 0.018
# 2025-07-04 14:06:22,993 INFO jaxlogit._optimize: Iter 16, fun = 4359.218, |grad| = 0.002
# 2025-07-04 14:06:22,994 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -4359.22
# 2025-07-04 14:06:22,996 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 14:06:25,774 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 14:06:30,810 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 14:06:30,998 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 16
#     Function evaluations: 17
# Estimation time= 18.7 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# ASC_CAR                 0.2831119     0.0560481     5.0512331       4.5e-07 ***
# ASC_TRAIN              -0.5722801     0.0794782    -7.2004683      6.65e-13 ***
# CO                     -1.6601727     0.0778872   -21.3151023      1.26e-97 ***
# TT                     -3.2289922     0.1749822   -18.4532610      3.17e-74 ***
# sd.TT                   3.6485578     0.1683478    21.6727368     9.28e-101 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -4359.218
# AIC= 8728.436
# BIC= 8762.536

# %% [markdown]
# The negative signs for the cost and time coefficients suggest that decision makers experience a general disutility with alternatives that have higher waiting times and costs, which conforms to the underlying decision making theory. Note that these estimates are highly consistent with those returned by Biogeme (https://biogeme.epfl.ch/examples/swissmetro/05normalMixtureIntegral.html)

# %% [markdown]
# ## Electricity Dataset

# %% [markdown]
# The electricity dataset contains 4,308 choices among four electricity suppliers based on the attributes of the offered plans, which include prices(pf), contract lengths(cl), time of day rates (tod), seasonal rates(seas), as well as attributes of the suppliers, which include whether the supplier is local (loc) and well-known (wk). The data was collected through a survey where 12 different choice situations were presented to each participant. The multiple responses per participants were organized into panels. Given that some participants answered less than 12 of the choice situations, some panels are unbalanced, which `xlogit` is able to handle. [Revelt and Train (1999)](https://escholarship.org/content/qt1900p96t/qt1900p96t.pdf) provide a detailed description of this dataset.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is already in long format so no reshaping is necessary, it can be used directly in xlogit.

# %%
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/electricity_long.csv")
df
# Out:
#        choice   id  alt  pf  cl  loc  wk  tod  seas  chid
# 0           0    1    1   7   5    0   1    0     0     1
# 1           0    1    2   9   1    1   0    0     0     1
# 2           0    1    3   0   0    0   0    0     1     1
# 3           1    1    4   0   5    0   1    1     0     1
# 4           0    1    1   7   0    0   1    0     0     2
# ...       ...  ...  ...  ..  ..  ...  ..  ...   ...   ...
# 17227       0  361    4   0   1    1   0    0     1  4307
# 17228       1  361    1   9   0    0   1    0     0  4308
# 17229       0  361    2   7   0    0   0    0     0  4308
# 17230       0  361    3   0   1    0   1    0     1  4308
# 17231       0  361    4   0   5    1   0    1     0  4308
#
# [17232 rows x 10 columns]

# %% [markdown]
# ### Fit the model

# %% [markdown]
# Note that the parameter `panels` was included in the `fit` function in order to take into account panel structure of this dataset during estimation.

# %%
varnames = ['pf', 'cl', 'loc', 'wk', 'tod', 'seas']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    ids=df['chid'],
    panels=df['id'],
    alts=df['alt'],
    n_draws=600,
    randvars={'pf': 'n', 'cl': 'n', 'loc': 'n', 'wk': 'n', 'tod': 'n', 'seas': 'n'}
)
model.summary()
# Out:
# 2025-07-04 14:06:31,392 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 600 random draws for each random variable and observation.
# 2025-07-04 14:06:33,713 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 14:06:34,210 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 5620.08
# 2025-07-04 14:06:34,212 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 14:06:35,047 INFO jaxlogit._optimize: Iter 1, fun = 5377.286, |grad| = 814.514
# 2025-07-04 14:06:35,499 INFO jaxlogit._optimize: Iter 2, fun = 5324.697, |grad| = 662.525
# 2025-07-04 14:06:36,028 INFO jaxlogit._optimize: Iter 3, fun = 5276.612, |grad| = 517.721
# 2025-07-04 14:06:36,376 INFO jaxlogit._optimize: Iter 4, fun = 5196.625, |grad| = 3295.426
# 2025-07-04 14:06:36,725 INFO jaxlogit._optimize: Iter 5, fun = 5036.259, |grad| = 921.954
# 2025-07-04 14:06:37,151 INFO jaxlogit._optimize: Iter 6, fun = 4937.728, |grad| = 971.137
# 2025-07-04 14:06:37,533 INFO jaxlogit._optimize: Iter 7, fun = 4763.181, |grad| = 458.322
# 2025-07-04 14:06:37,875 INFO jaxlogit._optimize: Iter 8, fun = 4705.176, |grad| = 447.960
# 2025-07-04 14:06:38,207 INFO jaxlogit._optimize: Iter 9, fun = 4660.289, |grad| = 609.546
# 2025-07-04 14:06:38,608 INFO jaxlogit._optimize: Iter 10, fun = 4587.788, |grad| = 460.951
# 2025-07-04 14:06:38,991 INFO jaxlogit._optimize: Iter 11, fun = 4548.292, |grad| = 766.343
# 2025-07-04 14:06:39,388 INFO jaxlogit._optimize: Iter 12, fun = 4505.532, |grad| = 292.357
# 2025-07-04 14:06:39,795 INFO jaxlogit._optimize: Iter 13, fun = 4470.952, |grad| = 142.291
# 2025-07-04 14:06:40,173 INFO jaxlogit._optimize: Iter 14, fun = 4436.917, |grad| = 192.629
# 2025-07-04 14:06:40,550 INFO jaxlogit._optimize: Iter 15, fun = 4349.110, |grad| = 232.889
# 2025-07-04 14:06:40,914 INFO jaxlogit._optimize: Iter 16, fun = 4260.432, |grad| = 666.298
# 2025-07-04 14:06:41,264 INFO jaxlogit._optimize: Iter 17, fun = 4192.566, |grad| = 261.477
# 2025-07-04 14:06:41,623 INFO jaxlogit._optimize: Iter 18, fun = 4174.744, |grad| = 155.859
# 2025-07-04 14:06:41,979 INFO jaxlogit._optimize: Iter 19, fun = 4150.885, |grad| = 126.060
# 2025-07-04 14:06:42,380 INFO jaxlogit._optimize: Iter 20, fun = 4144.765, |grad| = 421.768
# 2025-07-04 14:06:42,758 INFO jaxlogit._optimize: Iter 21, fun = 4098.307, |grad| = 226.338
# 2025-07-04 14:06:43,159 INFO jaxlogit._optimize: Iter 22, fun = 4071.653, |grad| = 205.249
# 2025-07-04 14:06:43,782 INFO jaxlogit._optimize: Iter 23, fun = 4055.868, |grad| = 116.277
# 2025-07-04 14:06:44,145 INFO jaxlogit._optimize: Iter 24, fun = 4027.954, |grad| = 120.851
# 2025-07-04 14:06:44,490 INFO jaxlogit._optimize: Iter 25, fun = 4009.001, |grad| = 275.164
# 2025-07-04 14:06:44,861 INFO jaxlogit._optimize: Iter 26, fun = 3992.514, |grad| = 69.417
# 2025-07-04 14:06:45,212 INFO jaxlogit._optimize: Iter 27, fun = 3986.789, |grad| = 52.456
# 2025-07-04 14:06:45,602 INFO jaxlogit._optimize: Iter 28, fun = 3978.801, |grad| = 66.739
# 2025-07-04 14:06:46,005 INFO jaxlogit._optimize: Iter 29, fun = 3971.170, |grad| = 91.732
# 2025-07-04 14:06:46,584 INFO jaxlogit._optimize: Iter 30, fun = 3963.747, |grad| = 105.470
# 2025-07-04 14:06:46,948 INFO jaxlogit._optimize: Iter 31, fun = 3953.569, |grad| = 73.065
# 2025-07-04 14:06:47,308 INFO jaxlogit._optimize: Iter 32, fun = 3942.003, |grad| = 109.165
# 2025-07-04 14:06:47,685 INFO jaxlogit._optimize: Iter 33, fun = 3925.679, |grad| = 137.661
# 2025-07-04 14:06:48,284 INFO jaxlogit._optimize: Iter 34, fun = 3917.844, |grad| = 102.616
# 2025-07-04 14:06:48,657 INFO jaxlogit._optimize: Iter 35, fun = 3906.319, |grad| = 63.289
# 2025-07-04 14:06:49,007 INFO jaxlogit._optimize: Iter 36, fun = 3900.269, |grad| = 210.748
# 2025-07-04 14:06:49,381 INFO jaxlogit._optimize: Iter 37, fun = 3894.127, |grad| = 91.732
# 2025-07-04 14:06:49,787 INFO jaxlogit._optimize: Iter 38, fun = 3892.797, |grad| = 26.255
# 2025-07-04 14:06:50,214 INFO jaxlogit._optimize: Iter 39, fun = 3892.521, |grad| = 20.946
# 2025-07-04 14:06:50,588 INFO jaxlogit._optimize: Iter 40, fun = 3891.863, |grad| = 17.873
# 2025-07-04 14:06:50,961 INFO jaxlogit._optimize: Iter 41, fun = 3891.306, |grad| = 25.594
# 2025-07-04 14:06:51,333 INFO jaxlogit._optimize: Iter 42, fun = 3890.712, |grad| = 32.329
# 2025-07-04 14:06:51,753 INFO jaxlogit._optimize: Iter 43, fun = 3889.706, |grad| = 22.099
# 2025-07-04 14:06:52,138 INFO jaxlogit._optimize: Iter 44, fun = 3889.202, |grad| = 11.763
# 2025-07-04 14:06:52,522 INFO jaxlogit._optimize: Iter 45, fun = 3888.782, |grad| = 27.951
# 2025-07-04 14:06:53,092 INFO jaxlogit._optimize: Iter 46, fun = 3888.632, |grad| = 14.555
# 2025-07-04 14:06:53,499 INFO jaxlogit._optimize: Iter 47, fun = 3888.568, |grad| = 11.880
# 2025-07-04 14:06:53,900 INFO jaxlogit._optimize: Iter 48, fun = 3888.512, |grad| = 3.091
# 2025-07-04 14:06:54,297 INFO jaxlogit._optimize: Iter 49, fun = 3888.506, |grad| = 2.218
# 2025-07-04 14:06:54,681 INFO jaxlogit._optimize: Iter 50, fun = 3888.499, |grad| = 3.007
# 2025-07-04 14:06:55,102 INFO jaxlogit._optimize: Iter 51, fun = 3888.492, |grad| = 5.269
# 2025-07-04 14:06:55,502 INFO jaxlogit._optimize: Iter 52, fun = 3888.485, |grad| = 3.478
# 2025-07-04 14:06:55,889 INFO jaxlogit._optimize: Iter 53, fun = 3888.481, |grad| = 1.907
# 2025-07-04 14:06:56,296 INFO jaxlogit._optimize: Iter 54, fun = 3888.478, |grad| = 1.332
# 2025-07-04 14:06:56,683 INFO jaxlogit._optimize: Iter 55, fun = 3888.477, |grad| = 1.697
# 2025-07-04 14:06:57,067 INFO jaxlogit._optimize: Iter 56, fun = 3888.472, |grad| = 1.998
# 2025-07-04 14:06:57,443 INFO jaxlogit._optimize: Iter 57, fun = 3888.471, |grad| = 3.345
# 2025-07-04 14:06:57,840 INFO jaxlogit._optimize: Iter 58, fun = 3888.468, |grad| = 0.780
# 2025-07-04 14:06:58,223 INFO jaxlogit._optimize: Iter 59, fun = 3888.467, |grad| = 0.881
# 2025-07-04 14:06:58,638 INFO jaxlogit._optimize: Iter 60, fun = 3888.466, |grad| = 0.969
# 2025-07-04 14:06:59,028 INFO jaxlogit._optimize: Iter 61, fun = 3888.466, |grad| = 0.441
# 2025-07-04 14:06:59,432 INFO jaxlogit._optimize: Iter 62, fun = 3888.465, |grad| = 0.837
# 2025-07-04 14:07:00,071 INFO jaxlogit._optimize: Iter 63, fun = 3888.465, |grad| = 0.282
# 2025-07-04 14:07:00,456 INFO jaxlogit._optimize: Iter 64, fun = 3888.465, |grad| = 0.196
# 2025-07-04 14:07:00,893 INFO jaxlogit._optimize: Iter 65, fun = 3888.465, |grad| = 0.172
# 2025-07-04 14:07:01,247 INFO jaxlogit._optimize: Iter 66, fun = 3888.465, |grad| = 0.229
# 2025-07-04 14:07:01,769 INFO jaxlogit._optimize: Iter 67, fun = 3888.465, |grad| = 0.282
# 2025-07-04 14:07:02,134 INFO jaxlogit._optimize: Iter 68, fun = 3888.465, |grad| = 0.126
# 2025-07-04 14:07:02,516 INFO jaxlogit._optimize: Iter 69, fun = 3888.465, |grad| = 0.037
# 2025-07-04 14:07:02,948 INFO jaxlogit._optimize: Iter 70, fun = 3888.465, |grad| = 0.034
# 2025-07-04 14:07:03,358 INFO jaxlogit._optimize: Iter 71, fun = 3888.465, |grad| = 0.052
# 2025-07-04 14:07:03,795 INFO jaxlogit._optimize: Iter 72, fun = 3888.465, |grad| = 0.016
# 2025-07-04 14:07:04,163 INFO jaxlogit._optimize: Iter 73, fun = 3888.465, |grad| = 0.019
# 2025-07-04 14:07:04,522 INFO jaxlogit._optimize: Iter 74, fun = 3888.465, |grad| = 0.032
# 2025-07-04 14:07:04,524 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -3888.47
# 2025-07-04 14:07:04,525 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 14:07:07,801 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 14:07:13,185 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 14:07:13,407 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 74
#     Function evaluations: 83
# Estimation time= 42.0 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# pf                     -0.9971888     0.0378214   -26.3657437     3.73e-142 ***
# cl                     -0.2196766     0.0255173    -8.6089275      1.02e-17 ***
# loc                     2.2901968     0.1263079    18.1318519      7.26e-71 ***
# wk                      1.6942744     0.0961503    17.6210989      3.66e-67 ***
# tod                    -9.6751361     0.3350899   -28.8732511     9.81e-168 ***
# seas                   -9.6960628     0.3246480   -29.8663842     2.66e-178 ***
# sd.pf                   0.2207231     0.0191063    11.5523498      2.01e-30 ***
# sd.cl                   0.4115696     0.0254622    16.1639602       4.2e-57 ***
# sd.loc                  1.7840902     0.1181377    15.1017821      2.99e-50 ***
# sd.wk                   1.2296527     0.0943624    13.0311733      4.24e-38 ***
# sd.tod                  2.2758119     0.1737879    13.0953428      1.88e-38 ***
# sd.seas                 1.4861856     0.1638344     9.0712669      1.75e-19 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -3888.465
# AIC= 7800.930
# BIC= 7877.349

# %% [markdown]
# ## Fishing Dataset

# %% [markdown]
# This example illustrates the estimation of a Mixed Logit model for choices of 1,182 individuals for sport fishing modes using `xlogit`. The goal is to analyze the market shares of four alternatives (i.e., beach, pier, boat, and charter) based on their cost and fish catch rate. [Cameron (2005)](http://cameron.econ.ucdavis.edu/mmabook/mma.html) provides additional details about this dataset. The following code illustrates how to use `xlogit` to estimate the model parameters.

# %% [markdown]
# ### Read data

# %% [markdown]
# The data to be analyzed can be imported to Python using any preferred method. In this example, the data in CSV format was imported using the popular `pandas` Python package. However, it is worth highlighting that `xlogit` does not depend on the `pandas` package, as `xlogit` can take any array-like structure as input. This represents an additional advantage because `xlogit` can be used with any preferred dataframe library, and not only with `pandas`.

# %%
import pandas as pd
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/fishing_long.csv")
df
# Out:
#         id      alt  choice      income    price   catch
# 0        1    beach       0  7083.33170  157.930  0.0678
# 1        1     boat       0  7083.33170  157.930  0.2601
# 2        1  charter       1  7083.33170  182.930  0.5391
# 3        1     pier       0  7083.33170  157.930  0.0503
# 4        2    beach       0  1249.99980   15.114  0.1049
# ...    ...      ...     ...         ...      ...     ...
# 4723  1181     pier       0   416.66668   36.636  0.4522
# 4724  1182    beach       0  6250.00130  339.890  0.2537
# 4725  1182     boat       1  6250.00130  235.436  0.6817
# 4726  1182  charter       0  6250.00130  260.436  2.3014
# 4727  1182     pier       0  6250.00130  339.890  0.1498
#
# [4728 rows x 6 columns]

# %% [markdown]
# ### Fit model

# %% [markdown]
# Once the data is in the `Python` environment, `xlogit` can be used to fit the model, as shown below. The `MultinomialLogit` class is imported from `xlogit`, and its constructor is used to initialize a new model. The `fit` method estimates the model using the input data and estimation criteria provided as arguments to the method's call. The arguments of the `fit` methods are described in [`xlogit`'s documentation](https://https://xlogit.readthedocs.io/en/latest/api/).

# %%
varnames = ['price', 'catch']
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['id'],
    n_draws=1000,
    randvars={'price': 'n', 'catch': 'n'},
)
model.summary()
# Out:
# 2025-07-04 14:07:13,596 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1000 random draws for each random variable and observation.
# 2025-07-04 14:07:16,001 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 14:07:16,332 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 2586.70
# 2025-07-04 14:07:16,333 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 14:07:16,491 INFO jaxlogit._optimize: Iter 1, fun = 2261.519, |grad| = 509.074
# 2025-07-04 14:07:16,579 INFO jaxlogit._optimize: Iter 2, fun = 2246.481, |grad| = 455.966
# 2025-07-04 14:07:16,673 INFO jaxlogit._optimize: Iter 3, fun = 2119.608, |grad| = 531.081
# 2025-07-04 14:07:16,813 INFO jaxlogit._optimize: Iter 4, fun = 2086.043, |grad| = 710.226
# 2025-07-04 14:07:16,946 INFO jaxlogit._optimize: Iter 5, fun = 2043.830, |grad| = 954.897
# 2025-07-04 14:07:17,186 INFO jaxlogit._optimize: Iter 6, fun = 2029.430, |grad| = 1228.491
# 2025-07-04 14:07:17,298 INFO jaxlogit._optimize: Iter 7, fun = 1740.406, |grad| = 6252.681
# 2025-07-04 14:07:17,401 INFO jaxlogit._optimize: Iter 8, fun = 1323.545, |grad| = 2949.741
# 2025-07-04 14:07:17,695 INFO jaxlogit._optimize: Iter 9, fun = 1319.745, |grad| = 2290.032
# 2025-07-04 14:07:17,859 INFO jaxlogit._optimize: Iter 10, fun = 1317.251, |grad| = 701.782
# 2025-07-04 14:07:18,029 INFO jaxlogit._optimize: Iter 11, fun = 1315.894, |grad| = 307.943
# 2025-07-04 14:07:18,161 INFO jaxlogit._optimize: Iter 12, fun = 1315.774, |grad| = 694.959
# 2025-07-04 14:07:18,286 INFO jaxlogit._optimize: Iter 13, fun = 1315.209, |grad| = 119.849
# 2025-07-04 14:07:18,408 INFO jaxlogit._optimize: Iter 14, fun = 1314.519, |grad| = 303.384
# 2025-07-04 14:07:18,518 INFO jaxlogit._optimize: Iter 15, fun = 1312.178, |grad| = 1002.834
# 2025-07-04 14:07:18,655 INFO jaxlogit._optimize: Iter 16, fun = 1309.796, |grad| = 1246.221
# 2025-07-04 14:07:18,772 INFO jaxlogit._optimize: Iter 17, fun = 1308.134, |grad| = 1108.316
# 2025-07-04 14:07:18,891 INFO jaxlogit._optimize: Iter 18, fun = 1306.849, |grad| = 381.481
# 2025-07-04 14:07:19,016 INFO jaxlogit._optimize: Iter 19, fun = 1306.707, |grad| = 18.073
# 2025-07-04 14:07:19,155 INFO jaxlogit._optimize: Iter 20, fun = 1306.697, |grad| = 3.795
# 2025-07-04 14:07:19,335 INFO jaxlogit._optimize: Iter 21, fun = 1306.697, |grad| = 11.848
# 2025-07-04 14:07:19,453 INFO jaxlogit._optimize: Iter 22, fun = 1306.696, |grad| = 5.287
# 2025-07-04 14:07:19,671 INFO jaxlogit._optimize: Iter 23, fun = 1306.691, |grad| = 7.199
# 2025-07-04 14:07:19,783 INFO jaxlogit._optimize: Iter 24, fun = 1306.652, |grad| = 48.411
# 2025-07-04 14:07:19,906 INFO jaxlogit._optimize: Iter 25, fun = 1306.531, |grad| = 131.297
# 2025-07-04 14:07:20,019 INFO jaxlogit._optimize: Iter 26, fun = 1306.141, |grad| = 316.780
# 2025-07-04 14:07:20,140 INFO jaxlogit._optimize: Iter 27, fun = 1305.608, |grad| = 427.820
# 2025-07-04 14:07:20,290 INFO jaxlogit._optimize: Iter 28, fun = 1304.587, |grad| = 467.669
# 2025-07-04 14:07:20,406 INFO jaxlogit._optimize: Iter 29, fun = 1302.820, |grad| = 424.925
# 2025-07-04 14:07:20,573 INFO jaxlogit._optimize: Iter 30, fun = 1302.783, |grad| = 288.041
# 2025-07-04 14:07:20,696 INFO jaxlogit._optimize: Iter 31, fun = 1300.951, |grad| = 197.157
# 2025-07-04 14:07:20,861 INFO jaxlogit._optimize: Iter 32, fun = 1300.932, |grad| = 34.086
# 2025-07-04 14:07:20,986 INFO jaxlogit._optimize: Iter 33, fun = 1300.539, |grad| = 3.391
# 2025-07-04 14:07:21,109 INFO jaxlogit._optimize: Iter 34, fun = 1300.524, |grad| = 1.541
# 2025-07-04 14:07:21,239 INFO jaxlogit._optimize: Iter 35, fun = 1300.523, |grad| = 0.141
# 2025-07-04 14:07:21,367 INFO jaxlogit._optimize: Iter 36, fun = 1300.523, |grad| = 0.002
# 2025-07-04 14:07:21,505 INFO jaxlogit._optimize: Iter 37, fun = 1300.523, |grad| = 0.000
# 2025-07-04 14:07:21,507 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1300.52
# 2025-07-04 14:07:21,508 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 14:07:22,646 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 14:07:25,579 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 14:07:25,807 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 37
#     Function evaluations: 54
# Estimation time= 12.2 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# price                  -0.0272469     0.0022842   -11.9282999      4.71e-31 ***
# catch                   1.3260449     0.1738921     7.6256762      4.97e-14 ***
# sd.price                0.0102261     0.0021414     4.7753319      2.02e-06 ***
# sd.catch                1.5661804     0.3755151     4.1707526      3.26e-05 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1300.523
# AIC= 2609.046
# BIC= 2629.346

# %% [markdown]
# ## Car Dataset

# %% [markdown]
# The fourth example uses a stated preference panel dataset for choice of car. Three alternatives are considered, with upto 6 choice situations per individual. This again is an unbalanced panel with responses of some individuals less than 6 situations. The dataset contains 8 explanaotry variables: price, operating cost, range, and binary indicators to indicate whether the car is electric, hybrid, and if performance is high or medium respectively. This dataset was taken from Kenneth Train's MATLAB codes for estimation of Mixed Logit models as shown in this link: https://eml.berkeley.edu/Software/abstracts/train1006mxlmsl.html

# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/car100_long.csv")

# %% [markdown]
# Since price and operating cost need to be estimated with negative coefficients, we reverse the variable signs in the dataframe.

# %%
df['price'] = -df['price']/10000
df['opcost'] = -df['opcost']
df
# Out:
#       person_id  choice_id  alt  choice   price  opcost  range  ev  gas  \
# 0             1          1    1       0 -4.6763  -47.43    0.0   0    0
# 1             1          1    2       1 -5.7209  -27.43    1.3   1    0
# 2             1          1    3       0 -8.7960  -32.41    1.2   1    0
# 3             1          2    1       1 -3.3768   -4.89    1.3   1    0
# 4             1          2    2       0 -9.0336  -30.19    0.0   0    0
# ...         ...        ...  ...     ...     ...     ...    ...  ..  ...
# 4447        100       1483    2       0 -2.8036  -14.45    1.6   1    0
# 4448        100       1483    3       0 -1.9360  -54.76    0.0   0    1
# 4449        100       1484    1       1 -2.4054  -50.57    0.0   0    1
# 4450        100       1484    2       0 -5.2795  -21.25    0.0   0    0
# 4451        100       1484    3       0 -6.0705  -25.41    1.4   1    0
#
#       hybrid  hiperf  medhiperf
# 0          1       0          0
# 1          0       1          1
# 2          0       0          1
# 3          0       1          1
# 4          1       0          1
# ...      ...     ...        ...
# 4447       0       0          0
# 4448       0       1          1
# 4449       0       0          0
# 4450       1       0          1
# 4451       0       0          0
#
# [4452 rows x 12 columns]

# %% [markdown]
# ### Fit the model

# %%
varnames = ['hiperf', 'medhiperf', 'price', 'opcost', 'range', 'ev', 'hybrid'] 
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['choice_id'],
    panels=df['person_id'],
    randvars = {'price': 'ln', 'opcost': 'n',  'range': 'ln', 'ev':'n', 'hybrid': 'n'}, 
    n_draws = 1000,
)
model.summary()
# Out:
# 2025-07-04 14:18:05,049 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1000 random draws for each random variable and observation.
# 2025-07-04 14:18:06,082 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 14:18:06,717 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 1940.19
# 2025-07-04 14:18:06,719 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 14:18:07,090 INFO jaxlogit._optimize: Iter 1, fun = 1831.796, |grad| = 490.910
# 2025-07-04 14:18:07,295 INFO jaxlogit._optimize: Iter 2, fun = 1675.649, |grad| = 276.954
# 2025-07-04 14:18:07,509 INFO jaxlogit._optimize: Iter 3, fun = 1566.488, |grad| = 183.438
# 2025-07-04 14:18:07,714 INFO jaxlogit._optimize: Iter 4, fun = 1505.994, |grad| = 189.795
# 2025-07-04 14:18:08,180 INFO jaxlogit._optimize: Iter 5, fun = 1408.467, |grad| = 406.549
# 2025-07-04 14:18:08,798 INFO jaxlogit._optimize: Iter 6, fun = 1384.970, |grad| = 546.910
# 2025-07-04 14:18:09,320 INFO jaxlogit._optimize: Iter 7, fun = 1345.187, |grad| = 557.582
# 2025-07-04 14:18:09,849 INFO jaxlogit._optimize: Iter 8, fun = 1334.273, |grad| = 541.429
# 2025-07-04 14:18:10,176 INFO jaxlogit._optimize: Iter 9, fun = 1326.559, |grad| = 519.765
# 2025-07-04 14:18:10,516 INFO jaxlogit._optimize: Iter 10, fun = 1316.229, |grad| = 373.901
# 2025-07-04 14:18:10,872 INFO jaxlogit._optimize: Iter 11, fun = 1310.529, |grad| = 69.041
# 2025-07-04 14:18:11,155 INFO jaxlogit._optimize: Iter 12, fun = 1308.249, |grad| = 295.262
# 2025-07-04 14:18:11,402 INFO jaxlogit._optimize: Iter 13, fun = 1307.232, |grad| = 93.627
# 2025-07-04 14:18:11,675 INFO jaxlogit._optimize: Iter 14, fun = 1307.146, |grad| = 49.478
# 2025-07-04 14:18:11,912 INFO jaxlogit._optimize: Iter 15, fun = 1307.105, |grad| = 21.766
# 2025-07-04 14:18:12,164 INFO jaxlogit._optimize: Iter 16, fun = 1307.079, |grad| = 25.387
# 2025-07-04 14:18:12,407 INFO jaxlogit._optimize: Iter 17, fun = 1306.958, |grad| = 67.757
# 2025-07-04 14:18:12,639 INFO jaxlogit._optimize: Iter 18, fun = 1306.707, |grad| = 130.334
# 2025-07-04 14:18:12,880 INFO jaxlogit._optimize: Iter 19, fun = 1306.033, |grad| = 228.526
# 2025-07-04 14:18:13,112 INFO jaxlogit._optimize: Iter 20, fun = 1304.698, |grad| = 307.422
# 2025-07-04 14:18:13,352 INFO jaxlogit._optimize: Iter 21, fun = 1302.994, |grad| = 260.736
# 2025-07-04 14:18:13,577 INFO jaxlogit._optimize: Iter 22, fun = 1301.998, |grad| = 122.008
# 2025-07-04 14:18:13,842 INFO jaxlogit._optimize: Iter 23, fun = 1301.686, |grad| = 20.621
# 2025-07-04 14:18:14,084 INFO jaxlogit._optimize: Iter 24, fun = 1301.625, |grad| = 37.624
# 2025-07-04 14:18:14,320 INFO jaxlogit._optimize: Iter 25, fun = 1301.592, |grad| = 56.233
# 2025-07-04 14:18:14,582 INFO jaxlogit._optimize: Iter 26, fun = 1301.519, |grad| = 78.042
# 2025-07-04 14:18:14,828 INFO jaxlogit._optimize: Iter 27, fun = 1301.317, |grad| = 110.325
# 2025-07-04 14:18:15,086 INFO jaxlogit._optimize: Iter 28, fun = 1300.897, |grad| = 139.715
# 2025-07-04 14:18:15,322 INFO jaxlogit._optimize: Iter 29, fun = 1300.359, |grad| = 142.944
# 2025-07-04 14:18:15,658 INFO jaxlogit._optimize: Iter 30, fun = 1300.162, |grad| = 117.090
# 2025-07-04 14:18:15,894 INFO jaxlogit._optimize: Iter 31, fun = 1299.862, |grad| = 44.639
# 2025-07-04 14:18:16,125 INFO jaxlogit._optimize: Iter 32, fun = 1299.763, |grad| = 28.229
# 2025-07-04 14:18:16,370 INFO jaxlogit._optimize: Iter 33, fun = 1299.737, |grad| = 37.776
# 2025-07-04 14:18:16,648 INFO jaxlogit._optimize: Iter 34, fun = 1299.611, |grad| = 66.840
# 2025-07-04 14:18:16,893 INFO jaxlogit._optimize: Iter 35, fun = 1299.375, |grad| = 80.918
# 2025-07-04 14:18:17,141 INFO jaxlogit._optimize: Iter 36, fun = 1299.130, |grad| = 47.540
# 2025-07-04 14:18:17,383 INFO jaxlogit._optimize: Iter 37, fun = 1299.052, |grad| = 10.119
# 2025-07-04 14:18:17,622 INFO jaxlogit._optimize: Iter 38, fun = 1299.025, |grad| = 25.698
# 2025-07-04 14:18:17,888 INFO jaxlogit._optimize: Iter 39, fun = 1298.990, |grad| = 44.048
# 2025-07-04 14:18:18,132 INFO jaxlogit._optimize: Iter 40, fun = 1298.911, |grad| = 66.269
# 2025-07-04 14:18:18,384 INFO jaxlogit._optimize: Iter 41, fun = 1298.801, |grad| = 71.771
# 2025-07-04 14:18:18,756 INFO jaxlogit._optimize: Iter 42, fun = 1298.789, |grad| = 73.587
# 2025-07-04 14:18:18,991 INFO jaxlogit._optimize: Iter 43, fun = 1298.697, |grad| = 44.335
# 2025-07-04 14:18:19,244 INFO jaxlogit._optimize: Iter 44, fun = 1298.663, |grad| = 9.700
# 2025-07-04 14:18:19,484 INFO jaxlogit._optimize: Iter 45, fun = 1298.660, |grad| = 4.572
# 2025-07-04 14:18:19,724 INFO jaxlogit._optimize: Iter 46, fun = 1298.658, |grad| = 6.264
# 2025-07-04 14:18:19,961 INFO jaxlogit._optimize: Iter 47, fun = 1298.655, |grad| = 8.305
# 2025-07-04 14:18:20,199 INFO jaxlogit._optimize: Iter 48, fun = 1298.644, |grad| = 10.982
# 2025-07-04 14:18:20,438 INFO jaxlogit._optimize: Iter 49, fun = 1298.620, |grad| = 9.571
# 2025-07-04 14:18:20,727 INFO jaxlogit._optimize: Iter 50, fun = 1298.580, |grad| = 6.094
# 2025-07-04 14:18:21,067 INFO jaxlogit._optimize: Iter 51, fun = 1298.574, |grad| = 6.659
# 2025-07-04 14:18:21,293 INFO jaxlogit._optimize: Iter 52, fun = 1298.560, |grad| = 2.848
# 2025-07-04 14:18:21,630 INFO jaxlogit._optimize: Iter 53, fun = 1298.558, |grad| = 7.848
# 2025-07-04 14:18:21,875 INFO jaxlogit._optimize: Iter 54, fun = 1298.555, |grad| = 5.347
# 2025-07-04 14:18:22,142 INFO jaxlogit._optimize: Iter 55, fun = 1298.552, |grad| = 12.947
# 2025-07-04 14:18:22,395 INFO jaxlogit._optimize: Iter 56, fun = 1298.548, |grad| = 8.261
# 2025-07-04 14:18:22,648 INFO jaxlogit._optimize: Iter 57, fun = 1298.542, |grad| = 1.991
# 2025-07-04 14:18:22,936 INFO jaxlogit._optimize: Iter 58, fun = 1298.540, |grad| = 2.813
# 2025-07-04 14:18:23,188 INFO jaxlogit._optimize: Iter 59, fun = 1298.534, |grad| = 4.493
# 2025-07-04 14:18:23,423 INFO jaxlogit._optimize: Iter 60, fun = 1298.522, |grad| = 5.880
# 2025-07-04 14:18:23,661 INFO jaxlogit._optimize: Iter 61, fun = 1298.494, |grad| = 7.014
# 2025-07-04 14:18:24,034 INFO jaxlogit._optimize: Iter 62, fun = 1298.483, |grad| = 14.011
# 2025-07-04 14:18:24,273 INFO jaxlogit._optimize: Iter 63, fun = 1298.445, |grad| = 7.536
# 2025-07-04 14:18:24,503 INFO jaxlogit._optimize: Iter 64, fun = 1298.401, |grad| = 21.024
# 2025-07-04 14:18:24,873 INFO jaxlogit._optimize: Iter 65, fun = 1298.380, |grad| = 17.614
# 2025-07-04 14:18:25,108 INFO jaxlogit._optimize: Iter 66, fun = 1298.353, |grad| = 15.179
# 2025-07-04 14:18:25,364 INFO jaxlogit._optimize: Iter 67, fun = 1298.300, |grad| = 8.206
# 2025-07-04 14:18:25,711 INFO jaxlogit._optimize: Iter 68, fun = 1298.283, |grad| = 20.241
# 2025-07-04 14:18:25,962 INFO jaxlogit._optimize: Iter 69, fun = 1298.262, |grad| = 9.561
# 2025-07-04 14:18:26,197 INFO jaxlogit._optimize: Iter 70, fun = 1298.252, |grad| = 4.272
# 2025-07-04 14:18:26,442 INFO jaxlogit._optimize: Iter 71, fun = 1298.247, |grad| = 3.534
# 2025-07-04 14:18:26,677 INFO jaxlogit._optimize: Iter 72, fun = 1298.240, |grad| = 3.279
# 2025-07-04 14:18:26,937 INFO jaxlogit._optimize: Iter 73, fun = 1298.230, |grad| = 3.460
# 2025-07-04 14:18:27,182 INFO jaxlogit._optimize: Iter 74, fun = 1298.214, |grad| = 5.172
# 2025-07-04 14:18:27,463 INFO jaxlogit._optimize: Iter 75, fun = 1298.203, |grad| = 10.769
# 2025-07-04 14:18:27,838 INFO jaxlogit._optimize: Iter 76, fun = 1298.196, |grad| = 10.605
# 2025-07-04 14:18:28,096 INFO jaxlogit._optimize: Iter 77, fun = 1298.189, |grad| = 6.281
# 2025-07-04 14:18:28,345 INFO jaxlogit._optimize: Iter 78, fun = 1298.185, |grad| = 1.554
# 2025-07-04 14:18:28,592 INFO jaxlogit._optimize: Iter 79, fun = 1298.184, |grad| = 1.143
# 2025-07-04 14:18:28,848 INFO jaxlogit._optimize: Iter 80, fun = 1298.183, |grad| = 1.498
# 2025-07-04 14:18:29,242 INFO jaxlogit._optimize: Iter 81, fun = 1298.183, |grad| = 1.591
# 2025-07-04 14:18:29,491 INFO jaxlogit._optimize: Iter 82, fun = 1298.183, |grad| = 0.870
# 2025-07-04 14:18:29,755 INFO jaxlogit._optimize: Iter 83, fun = 1298.183, |grad| = 1.290
# 2025-07-04 14:18:29,997 INFO jaxlogit._optimize: Iter 84, fun = 1298.182, |grad| = 1.508
# 2025-07-04 14:18:30,240 INFO jaxlogit._optimize: Iter 85, fun = 1298.181, |grad| = 1.012
# 2025-07-04 14:18:30,467 INFO jaxlogit._optimize: Iter 86, fun = 1298.180, |grad| = 3.706
# 2025-07-04 14:18:30,824 INFO jaxlogit._optimize: Iter 87, fun = 1298.179, |grad| = 3.209
# 2025-07-04 14:18:31,101 INFO jaxlogit._optimize: Iter 88, fun = 1298.179, |grad| = 2.732
# 2025-07-04 14:18:31,352 INFO jaxlogit._optimize: Iter 89, fun = 1298.178, |grad| = 1.186
# 2025-07-04 14:18:31,594 INFO jaxlogit._optimize: Iter 90, fun = 1298.177, |grad| = 0.610
# 2025-07-04 14:18:31,839 INFO jaxlogit._optimize: Iter 91, fun = 1298.177, |grad| = 0.388
# 2025-07-04 14:18:32,167 INFO jaxlogit._optimize: Iter 92, fun = 1298.177, |grad| = 2.139
# 2025-07-04 14:18:32,398 INFO jaxlogit._optimize: Iter 93, fun = 1298.177, |grad| = 0.694
# 2025-07-04 14:18:32,632 INFO jaxlogit._optimize: Iter 94, fun = 1298.177, |grad| = 0.544
# 2025-07-04 14:18:32,895 INFO jaxlogit._optimize: Iter 95, fun = 1298.177, |grad| = 0.574
# 2025-07-04 14:18:33,143 INFO jaxlogit._optimize: Iter 96, fun = 1298.176, |grad| = 0.456
# 2025-07-04 14:18:33,383 INFO jaxlogit._optimize: Iter 97, fun = 1298.176, |grad| = 1.376
# 2025-07-04 14:18:33,621 INFO jaxlogit._optimize: Iter 98, fun = 1298.176, |grad| = 0.997
# 2025-07-04 14:18:33,960 INFO jaxlogit._optimize: Iter 99, fun = 1298.176, |grad| = 1.526
# 2025-07-04 14:18:34,214 INFO jaxlogit._optimize: Iter 100, fun = 1298.176, |grad| = 0.540
# 2025-07-04 14:18:34,451 INFO jaxlogit._optimize: Iter 101, fun = 1298.176, |grad| = 0.136
# 2025-07-04 14:18:34,677 INFO jaxlogit._optimize: Iter 102, fun = 1298.176, |grad| = 0.173
# 2025-07-04 14:18:35,013 INFO jaxlogit._optimize: Iter 103, fun = 1298.176, |grad| = 0.260
# 2025-07-04 14:18:35,267 INFO jaxlogit._optimize: Iter 104, fun = 1298.176, |grad| = 0.127
# 2025-07-04 14:18:35,510 INFO jaxlogit._optimize: Iter 105, fun = 1298.176, |grad| = 0.124
# 2025-07-04 14:18:35,779 INFO jaxlogit._optimize: Iter 106, fun = 1298.176, |grad| = 0.394
# 2025-07-04 14:18:36,016 INFO jaxlogit._optimize: Iter 107, fun = 1298.176, |grad| = 0.397
# 2025-07-04 14:18:36,252 INFO jaxlogit._optimize: Iter 108, fun = 1298.176, |grad| = 0.570
# 2025-07-04 14:18:36,498 INFO jaxlogit._optimize: Iter 109, fun = 1298.176, |grad| = 0.190
# 2025-07-04 14:18:36,735 INFO jaxlogit._optimize: Iter 110, fun = 1298.176, |grad| = 0.048
# 2025-07-04 14:18:36,969 INFO jaxlogit._optimize: Iter 111, fun = 1298.176, |grad| = 0.253
# 2025-07-04 14:18:37,231 INFO jaxlogit._optimize: Iter 112, fun = 1298.176, |grad| = 0.311
# 2025-07-04 14:18:37,490 INFO jaxlogit._optimize: Iter 113, fun = 1298.176, |grad| = 0.120
# 2025-07-04 14:18:37,725 INFO jaxlogit._optimize: Iter 114, fun = 1298.176, |grad| = 0.069
# 2025-07-04 14:18:37,957 INFO jaxlogit._optimize: Iter 115, fun = 1298.176, |grad| = 0.051
# 2025-07-04 14:18:38,314 INFO jaxlogit._optimize: Iter 116, fun = 1298.176, |grad| = 0.107
# 2025-07-04 14:18:38,561 INFO jaxlogit._optimize: Iter 117, fun = 1298.176, |grad| = 0.054
# 2025-07-04 14:18:38,789 INFO jaxlogit._optimize: Iter 118, fun = 1298.176, |grad| = 0.068
# 2025-07-04 14:18:39,038 INFO jaxlogit._optimize: Iter 119, fun = 1298.176, |grad| = 0.079
# 2025-07-04 14:18:39,293 INFO jaxlogit._optimize: Iter 120, fun = 1298.176, |grad| = 0.100
# 2025-07-04 14:18:39,553 INFO jaxlogit._optimize: Iter 121, fun = 1298.176, |grad| = 0.063
# 2025-07-04 14:18:39,883 INFO jaxlogit._optimize: Iter 122, fun = 1298.176, |grad| = 0.059
# 2025-07-04 14:18:40,276 INFO jaxlogit._optimize: Iter 123, fun = 1298.176, |grad| = 0.051
# 2025-07-04 14:18:40,519 INFO jaxlogit._optimize: Iter 124, fun = 1298.176, |grad| = 0.043
# 2025-07-04 14:18:40,753 INFO jaxlogit._optimize: Iter 125, fun = 1298.176, |grad| = 0.035
# 2025-07-04 14:18:40,987 INFO jaxlogit._optimize: Iter 126, fun = 1298.176, |grad| = 0.050
# 2025-07-04 14:18:41,224 INFO jaxlogit._optimize: Iter 127, fun = 1298.176, |grad| = 0.126
# 2025-07-04 14:18:41,570 INFO jaxlogit._optimize: Iter 128, fun = 1298.176, |grad| = 0.073
# 2025-07-04 14:18:41,828 INFO jaxlogit._optimize: Iter 129, fun = 1298.176, |grad| = 0.049
# 2025-07-04 14:18:42,096 INFO jaxlogit._optimize: Iter 130, fun = 1298.176, |grad| = 0.031
# 2025-07-04 14:18:42,334 INFO jaxlogit._optimize: Iter 131, fun = 1298.176, |grad| = 0.008
# 2025-07-04 14:18:42,335 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1298.18
# 2025-07-04 14:18:42,336 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 14:18:44,804 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 14:18:50,993 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 14:18:50,997 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 131
#     Function evaluations: 164
# Estimation time= 45.9 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# hiperf                  0.1057423     0.0967948     1.0924373         0.275
# medhiperf               0.5713368     0.1004435     5.6881405      1.54e-08 ***
# price                  -0.7405432     0.1406665    -5.2645315      1.61e-07 ***
# opcost                  0.0119847     0.0057168     2.0964165        0.0362 *
# range                  -0.6711015     0.4033526    -1.6638087        0.0964 .
# ev                     -1.5934820     0.3357166    -4.7465089      2.27e-06 ***
# hybrid                  0.7058535     0.1624154     4.3459763      1.48e-05 ***
# sd.price                0.9461504     0.1202474     7.8683639      6.87e-15 ***
# sd.opcost               0.0384702     0.0053641     7.1718298      1.16e-12 ***
# sd.range                0.5773598     0.1691684     3.4129301       0.00066 ***
# sd.ev                   0.9970705     0.2273423     4.3857679      1.24e-05 ***
# sd.hybrid               0.7459480     0.1665546     4.4786986      8.08e-06 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1298.176
# AIC= 2620.351
# BIC= 2683.981

# %% [markdown]
# ## References

# %% [markdown]
# - Bierlaire, M. (2018). PandasBiogeme: a short introduction. EPFL (Transport and Mobility Laboratory, ENAC).
#
# - Brathwaite, T., & Walker, J. L. (2018). Asymmetric, closed-form, finite-parameter models of multinomial choice. Journal of Choice Modelling, 29, 78–112.
#
# - Cameron, A. C., & Trivedi, P. K. (2005). Microeconometrics: methods and applications. Cambridge university press.
#
# - Croissant, Y. (2020). Estimation of Random Utility Models in R: The mlogit Package. Journal of Statistical Software, 95(1), 1-41.
#
# - Revelt, D., & Train, K. (1999). Customer-specific taste parameters and mixed logit. University of California, Berkeley.
