# %% [markdown]
# # Mixed Logit with correlations
#
# Using swissmetro data, comparing results to biogeme (Bierlaire, M. (2018). PandasBiogeme: a short introduction. EPFL (Transport and Mobility Laboratory, ENAC))

# %%
import pandas as pd
import numpy as np
import jax

from jaxlogit.mixed_logit import MixedLogit

# %%
#  64bit precision
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Swissmetro Dataset

# %% [markdown]
# The swissmetro dataset contains stated-preferences for three alternative transportation modes that include car, train and a newly introduced mode: the swissmetro. This dataset is commonly used for estimation examples with the `Biogeme` and `PyLogit` packages. The dataset is available at http://transp-or.epfl.ch/data/swissmetro.dat and [Bierlaire et. al., (2001)](https://transp-or.epfl.ch/documents/proceedings/BierAxhaAbay01.pdf) provides a detailed discussion of the data as wells as its context and collection process. The explanatory variables in this example include the travel time (`TT`) and cost `CO` for each of the three alternative modes.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is imported to the Python environment using `pandas`. Then, two types of samples, ones with a trip purpose different to commute or business and ones with an unknown choice, are filtered out. The original dataset contains 10,729 records, but after filtering, 6,768 records remain for following analysis. Finally, a new column that uniquely identifies each sample is added to the dataframe and the `CHOICE` column, which originally contains a numerical coding of the choices, is mapped to a description that is consistent with the alternatives in the column names.

# %%
df_wide = pd.read_table("http://transp-or.epfl.ch/data/swissmetro.dat", sep='\t')

# Keep only observations for commute and business purposes that contain known choices
df_wide = df_wide[(df_wide['PURPOSE'].isin([1, 3]) & (df_wide['CHOICE'] != 0))]

df_wide['custom_id'] = np.arange(len(df_wide))  # Add unique identifier
df_wide['CHOICE'] = df_wide['CHOICE'].map({1: 'TRAIN', 2:'SM', 3: 'CAR'})
df_wide
# Out:
#       GROUP  SURVEY  SP   ID  PURPOSE  FIRST  TICKET  WHO  LUGGAGE  AGE  ...  \
# 0         2       0   1    1        1      0       1    1        0    3  ...
# 1         2       0   1    1        1      0       1    1        0    3  ...
# 2         2       0   1    1        1      0       1    1        0    3  ...
# 3         2       0   1    1        1      0       1    1        0    3  ...
# 4         2       0   1    1        1      0       1    1        0    3  ...
# ...     ...     ...  ..  ...      ...    ...     ...  ...      ...  ...  ...
# 8446      3       1   1  939        3      1       7    3        1    5  ...
# 8447      3       1   1  939        3      1       7    3        1    5  ...
# 8448      3       1   1  939        3      1       7    3        1    5  ...
# 8449      3       1   1  939        3      1       7    3        1    5  ...
# 8450      3       1   1  939        3      1       7    3        1    5  ...
#
#       TRAIN_CO  TRAIN_HE  SM_TT  SM_CO  SM_HE  SM_SEATS  CAR_TT  CAR_CO  \
# 0           48       120     63     52     20         0     117      65
# 1           48        30     60     49     10         0     117      84
# 2           48        60     67     58     30         0     117      52
# 3           40        30     63     52     20         0      72      52
# 4           36        60     63     42     20         0      90      84
# ...        ...       ...    ...    ...    ...       ...     ...     ...
# 8446        13        30     50     17     30         0     130      64
# 8447        12        30     53     16     10         0      80      80
# 8448        16        60     50     16     20         0      80      64
# 8449        16        30     53     17     30         0      80     104
# 8450        13        60     53     21     30         0     100      80
#
#       CHOICE  custom_id
# 0         SM          0
# 1         SM          1
# 2         SM          2
# 3         SM          3
# 4         SM          4
# ...      ...        ...
# 8446   TRAIN       6763
# 8447   TRAIN       6764
# 8448   TRAIN       6765
# 8449   TRAIN       6766
# 8450   TRAIN       6767
#
# [6768 rows x 29 columns]

# %% [markdown]
# ### Reshape data

# %% [markdown]
# The imported dataframe is in wide format, and it needs to be reshaped to long format for processing by `xlogit`, which offers the convenient `wide_to_long` utility for this reshaping process. The user needs to specify the column that uniquely identifies each sample, the names of the alternatives, the columns that vary across alternatives, and whether the alternative names are a prefix or suffix of the column names. Additionally, the user can specify a value (`empty_val`) to be used by default when an alternative is not available for a certain variable. Additional usage examples for the `wide_to_long` function are available in xlogit's documentation at https://xlogit.readthedocs.io/en/latest/notebooks/convert_data_wide_to_long.html. Also, details about the function parameters are available at the [API reference ](https://xlogit.readthedocs.io/en/latest/api/utils.html#xlogit.utils.wide_to_long).

# %%
from jaxlogit.utils import wide_to_long

df = wide_to_long(df_wide, id_col='custom_id', alt_name='alt', sep='_',
                  alt_list=['TRAIN', 'SM', 'CAR'], empty_val=0,
                  varying=['TT', 'CO', 'HE', 'AV', 'SEATS'], alt_is_prefix=True)
df
# Out:
#        custom_id    alt   TT   CO   HE  AV  SEATS  GROUP  SURVEY  SP  ...  \
# 0              0  TRAIN  112   48  120   1      0      2       0   1  ...
# 1              0     SM   63   52   20   1      0      2       0   1  ...
# 2              0    CAR  117   65    0   1      0      2       0   1  ...
# 3              1  TRAIN  103   48   30   1      0      2       0   1  ...
# 4              1     SM   60   49   10   1      0      2       0   1  ...
# ...          ...    ...  ...  ...  ...  ..    ...    ...     ...  ..  ...
# 20299       6766     SM   53   17   30   1      0      3       1   1  ...
# 20300       6766    CAR   80  104    0   1      0      3       1   1  ...
# 20301       6767  TRAIN  108   13   60   1      0      3       1   1  ...
# 20302       6767     SM   53   21   30   1      0      3       1   1  ...
# 20303       6767    CAR  100   80    0   1      0      3       1   1  ...
#
#        TICKET  WHO  LUGGAGE  AGE  MALE  INCOME  GA  ORIGIN  DEST  CHOICE
# 0           1    1        0    3     0       2   0       2     1      SM
# 1           1    1        0    3     0       2   0       2     1      SM
# 2           1    1        0    3     0       2   0       2     1      SM
# 3           1    1        0    3     0       2   0       2     1      SM
# 4           1    1        0    3     0       2   0       2     1      SM
# ...       ...  ...      ...  ...   ...     ...  ..     ...   ...     ...
# 20299       7    3        1    5     1       2   0       1     2   TRAIN
# 20300       7    3        1    5     1       2   0       1     2   TRAIN
# 20301       7    3        1    5     1       2   0       1     2   TRAIN
# 20302       7    3        1    5     1       2   0       1     2   TRAIN
# 20303       7    3        1    5     1       2   0       1     2   TRAIN
#
# [20304 rows x 23 columns]

# %% [markdown]
# ### Create model specification

# %% [markdown]
# Following the reshaping, users can create or update the dataset's columns in order to accommodate their model specification needs, if necessary. The code below shows how the columns `ASC_TRAIN` and `ASC_CAR` were created to incorporate alternative-specific constants in the model. In addition, the example illustrates an effective way of establishing variable interactions (e.g., trip costs for commuters with an annual pass) by updating existing columns conditional on values of other columns. Although apparently simple, column operations provide users with an intuitive and highly-flexible mechanism to incorporate model specification aspects, such as variable transformations, interactions, and alternative specific coefficients and constants. By operating the dataframe columns, any utility specification can be accommodated in `xlogit`. As shown in [this specification example](https://xlogit.readthedocs.io/en/latest/notebooks/multinomial_model.html#Create-model-specification), highly-flexible utility specifications can be modeled in `xlogit` by operating the dataframe columns.

# %%
df['ASC_TRAIN'] = np.ones(len(df))*(df['alt'] == 'TRAIN')
df['ASC_CAR'] = np.ones(len(df))*(df['alt'] == 'CAR')
df['TT'], df['CO'] = df['TT']/100, df['CO']/100  # Scale variables
annual_pass = (df['GA'] == 1) & (df['alt'].isin(['TRAIN', 'SM']))
df.loc[annual_pass, 'CO'] = 0  # Cost zero for pass holders

# %% [markdown]
# ### Estimate model parameters

# %% [markdown]
# The `fit` method estimates the model by taking as input the data from the previous step along with additional specification criteria, such as the distribution of the random parameters (`randvars`), the number of random draws (`n_draws`), and the availability of alternatives for the choice situations (`avail`). We set the optimization method as `L-BFGS-B` as this is a robust routine that usually helps solve convergence issues.  Once the estimation routine is completed, the `summary` method can be used to display the estimation results.

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'CO', 'TT']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars={'TT': 'n'},
    n_draws=1500,
)
model.summary()
# Out:
# 2025-07-06 04:50:31,852 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# INFO:2025-07-06 04:50:31,961:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-06 04:50:31,961 INFO jax._src.xla_bridge: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# WARNING:2025-07-06 04:50:31,963:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# 2025-07-06 04:50:31,963 WARNING jax._src.xla_bridge: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# 2025-07-06 04:50:34,259 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-06 04:50:34,776 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 7309.54
# 2025-07-06 04:50:34,777 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-06 04:50:35,599 INFO jaxlogit._optimize: Iter 1, fun = 5509.545, |grad| = 1054.174
# 2025-07-06 04:50:36,093 INFO jaxlogit._optimize: Iter 2, fun = 4969.103, |grad| = 571.378
# 2025-07-06 04:50:36,631 INFO jaxlogit._optimize: Iter 3, fun = 4611.336, |grad| = 275.850
# 2025-07-06 04:50:37,156 INFO jaxlogit._optimize: Iter 4, fun = 4470.256, |grad| = 221.282
# 2025-07-06 04:50:37,632 INFO jaxlogit._optimize: Iter 5, fun = 4395.300, |grad| = 63.354
# 2025-07-06 04:50:38,173 INFO jaxlogit._optimize: Iter 6, fun = 4380.971, |grad| = 54.077
# 2025-07-06 04:50:38,710 INFO jaxlogit._optimize: Iter 7, fun = 4366.435, |grad| = 40.186
# 2025-07-06 04:50:39,274 INFO jaxlogit._optimize: Iter 8, fun = 4360.871, |grad| = 13.210
# 2025-07-06 04:50:39,811 INFO jaxlogit._optimize: Iter 9, fun = 4360.011, |grad| = 10.823
# 2025-07-06 04:50:40,318 INFO jaxlogit._optimize: Iter 10, fun = 4359.481, |grad| = 6.401
# 2025-07-06 04:50:40,849 INFO jaxlogit._optimize: Iter 11, fun = 4359.251, |grad| = 2.223
# 2025-07-06 04:50:41,352 INFO jaxlogit._optimize: Iter 12, fun = 4359.224, |grad| = 1.269
# 2025-07-06 04:50:41,880 INFO jaxlogit._optimize: Iter 13, fun = 4359.219, |grad| = 0.360
# 2025-07-06 04:50:42,363 INFO jaxlogit._optimize: Iter 14, fun = 4359.218, |grad| = 0.078
# 2025-07-06 04:50:42,896 INFO jaxlogit._optimize: Iter 15, fun = 4359.218, |grad| = 0.018
# 2025-07-06 04:50:43,526 INFO jaxlogit._optimize: Iter 16, fun = 4359.218, |grad| = 0.002
# 2025-07-06 04:50:43,527 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -4359.22
# 2025-07-06 04:50:43,528 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-06 04:50:47,107 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-06 04:50:53,427 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-06 04:50:53,679 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 16
#     Function evaluations: 17
# Estimation time= 21.8 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# ASC_CAR                 0.2831119     0.0560481     5.0512331       4.5e-07 ***
# ASC_TRAIN              -0.5722801     0.0794782    -7.2004683      6.65e-13 ***
# CO                     -1.6601727     0.0778872   -21.3151023      1.26e-97 ***
# TT                     -3.2289922     0.1749822   -18.4532610      3.17e-74 ***
# sd.TT                   3.6485578     0.1683478    21.6727368     9.28e-101 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -4359.218
# AIC= 8728.436
# BIC= 8762.536

# %% [markdown]
# ## Example of fixing parameters

# %%
# we left this one out before, let's add it and assert parameters to 0
df['ASC_SM'] = np.ones(len(df))*(df['alt'] == 'SM')

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'ASC_SM', 'CO', 'TT']
fixedvars = {'ASC_SM': 0.0}  # Fixing parameters
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars={'TT': 'n'},
    n_draws=1500,
    fixedvars=fixedvars
)
model.summary()
# Out:
# 2025-07-06 04:51:32,129 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# 2025-07-06 04:51:32,970 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-06 04:51:33,442 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 7309.54
# 2025-07-06 04:51:33,443 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-06 04:51:34,267 INFO jaxlogit._optimize: Iter 1, fun = 5509.545, |grad| = 1054.174
# 2025-07-06 04:51:34,797 INFO jaxlogit._optimize: Iter 2, fun = 4969.103, |grad| = 571.378
# 2025-07-06 04:51:35,290 INFO jaxlogit._optimize: Iter 3, fun = 4611.336, |grad| = 275.850
# 2025-07-06 04:51:35,741 INFO jaxlogit._optimize: Iter 4, fun = 4470.256, |grad| = 221.282
# 2025-07-06 04:51:36,297 INFO jaxlogit._optimize: Iter 5, fun = 4395.300, |grad| = 63.354
# 2025-07-06 04:51:36,827 INFO jaxlogit._optimize: Iter 6, fun = 4380.971, |grad| = 54.077
# 2025-07-06 04:51:37,414 INFO jaxlogit._optimize: Iter 7, fun = 4366.435, |grad| = 40.186
# 2025-07-06 04:51:37,991 INFO jaxlogit._optimize: Iter 8, fun = 4360.871, |grad| = 13.210
# 2025-07-06 04:51:38,573 INFO jaxlogit._optimize: Iter 9, fun = 4360.011, |grad| = 10.823
# 2025-07-06 04:51:39,141 INFO jaxlogit._optimize: Iter 10, fun = 4359.481, |grad| = 6.401
# 2025-07-06 04:51:39,775 INFO jaxlogit._optimize: Iter 11, fun = 4359.251, |grad| = 2.223
# 2025-07-06 04:51:40,323 INFO jaxlogit._optimize: Iter 12, fun = 4359.224, |grad| = 1.269
# 2025-07-06 04:51:40,897 INFO jaxlogit._optimize: Iter 13, fun = 4359.219, |grad| = 0.360
# 2025-07-06 04:51:41,399 INFO jaxlogit._optimize: Iter 14, fun = 4359.218, |grad| = 0.078
# 2025-07-06 04:51:41,959 INFO jaxlogit._optimize: Iter 15, fun = 4359.218, |grad| = 0.018
# 2025-07-06 04:51:42,454 INFO jaxlogit._optimize: Iter 16, fun = 4359.218, |grad| = 0.002
# 2025-07-06 04:51:42,456 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -4359.22
# 2025-07-06 04:51:42,457 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-06 04:51:45,901 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-06 04:51:54,480 INFO jaxlogit._choice_model: Post fit processing
# /home/jzill/code/jaxlogit/jaxlogit/_choice_model.py:114: RuntimeWarning: invalid value encountered in divide
#   self.zvalues = self.coeff_ / self.stderr
# 2025-07-06 04:51:54,740 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 16
#     Function evaluations: 17
# Estimation time= 22.6 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# ASC_CAR                 0.2831119     0.0560481     5.0512331       4.5e-07 ***
# ASC_TRAIN              -0.5722801     0.0794782    -7.2004683      6.65e-13 ***
# ASC_SM                  0.0000000     0.0000000           nan           nan
# CO                     -1.6601727     0.0778872   -21.3151023      1.26e-97 ***
# TT                     -3.2289922     0.1749822   -18.4532610      3.17e-74 ***
# sd.TT                   3.6485578     0.1683478    21.6727368     9.28e-101 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -4359.218
# AIC= 8728.436
# BIC= 8762.536

# %% [markdown]
# ## Now let's add correlations
#
# Error component model

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'ASC_SM', 'CO', 'TT']

randvars={'ASC_CAR': 'n', 'ASC_TRAIN': 'n', 'ASC_SM': 'n'}
fixedvars = {'ASC_SM': 0.0, 'sd.ASC_SM': 0.0}  # Mean and variance of SM is fixed to 0

model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars=randvars,
    n_draws=1500,
    fixedvars=fixedvars,
    include_correlations=True,  # Enable correlation between random parameters
)
model.summary()
# Out:
# 2025-07-06 04:56:48,395 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# 2025-07-06 04:56:49,228 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# ---------------------------------------------------------------------------
# NonConcreteBooleanIndexError              Traceback (most recent call last)
# Cell In[13], line 7
#       4 fixedvars = {'ASC_SM': 0.0, 'sd.ASC_SM': 0.0}  # Mean and variance of SM is fixed to 0
#       6 model = MixedLogit()
# ----> 7 res = model.fit(
#       8     X=df[varnames],
#       9     y=df['CHOICE'],
#      10     varnames=varnames,
#      11     alts=df['alt'],
#      12     ids=df['custom_id'],
#      13     avail=df['AV'],
#      14     panels=df["ID"],
#      15     randvars=randvars,
#      16     n_draws=1500,
#      17     fixedvars=fixedvars,
#      18     include_correlations=True,  # Enable correlation between random parameters
#      19 )
#      20 model.summary()
#
# File ~/code/jaxlogit/jaxlogit/mixed_logit.py:398, in MixedLogit.fit(self, X, y, varnames, alts, ids, randvars, isvars, weights, avail, panels, base_alt, fit_intercept, init_coeff, maxiter, random_state, n_draws, halton, halton_opts, tol_opts, robust, num_hess, fixedvars, scale_factor, optim_method, skip_std_errs, include_correlations)
#     396 jit_neg_loglike = jax.jit(neg_loglike, static_argnames=["num_panels", "include_correlations"])
#     397 neg_loglik_and_grad = jax.value_and_grad(jit_neg_loglike, argnums=0)
# --> 398 init_loglik = neg_loglik_and_grad(betas, *fargs)
#     399 logger.info(f"Compilation finished, init neg_loglike = {init_loglik[0]:.2f}")
#     401 def neg_loglike_scipy(betas, *args):
#
#     [... skipping hidden 32 frame]
#
# File ~/code/jaxlogit/jaxlogit/mixed_logit.py:714, in neg_loglike(betas, Xdf, Xdr, panels, draws, weights, avail, scale_d, mask, values_for_mask, rvdix, rand_idx, fixed_idx, num_panels, idx_ln_dist, include_correlations)
#     696 def neg_loglike(
#     697     betas,
#     698     Xdf,
#    (...)
#     712     include_correlations,
#     713 ):
# --> 714     loglik_individ = loglike_individual(
#     715         betas,
#     716         Xdf,
#     717         Xdr,
#     718         panels,
#     719         draws,
#     720         weights,
#     721         avail,
#     722         scale_d,
#     723         mask,
#     724         values_for_mask,
#     725         rvdix,
#     726         rand_idx,
#     727         fixed_idx,
#     728         num_panels,
#     729         idx_ln_dist,
#     730         include_correlations,
#     731     )
#     733     loglik = loglik_individ.sum()
#     734     return -loglik
#
# File ~/code/jaxlogit/jaxlogit/mixed_logit.py:785, in loglike_individual(betas, Xdf, Xdr, panels, draws, weights, avail, scale_d, mask, values_for_mask, rvdix, rand_idx, fixed_idx, num_panels, idx_ln_dist, include_correlations)
#     782 chol_slice_size = (sd_slice_size * (sd_slice_size + 1)) // 2 - sd_slice_size
#     784 # Utility for random parameters
# --> 785 Br = _transform_rand_betas(
#     786     betas,
#     787     draws,
#     788     rand_idx,
#     789     sd_start_idx,
#     790     sd_slice_size,
#     791     chol_start_idx,
#     792     chol_slice_size,
#     793     idx_ln_dist,
#     794     include_correlations,
#     795 )
#     797 # Vdr shape: (N,J-1,R)
#     798 Vd = Vdf[:, :, None] + jnp.einsum("njk,nkr -> njr", Xdr, Br)
#
# File ~/code/jaxlogit/jaxlogit/mixed_logit.py:678, in _transform_rand_betas(betas, draws, rand_idx, sd_start_index, sd_slice_size, chol_start_idx, chol_slice_size, idx_ln_dist, include_correlations)
#     676 diag_mask = tril_rows == tril_cols
#     677 # now using bounds in L-BFGS-B, use softmax when using optimization algorithm that does not support bounds
# --> 678 L = L.at[tril_rows[diag_mask], tril_cols[diag_mask]].set(diag_vals)
#     679 L = L.at[tril_rows[~diag_mask], tril_cols[~diag_mask]].set(
#     680     jax.lax.dynamic_slice(betas, (chol_start_idx,), (chol_slice_size,))
#     681 )
#     682 N, _, R = draws.shape
#
# File ~/code/jaxlogit/venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:1083, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1082 def op(self, *args):
# -> 1083   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/code/jaxlogit/venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:657, in _getitem(self, item)
#     656 def _getitem(self, item):
# --> 657   return indexing.rewriting_take(self, item)
#
# File ~/code/jaxlogit/venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:645, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, out_sharding)
#     639     if (isinstance(aval, core.DShapedArray) and aval.shape == () and
#     640         dtypes.issubdtype(aval.dtype, np.integer) and
#     641         not dtypes.issubdtype(aval.dtype, dtypes.bool_) and
#     642         isinstance(arr.shape[0], int)):
#     643       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
# --> 645 treedef, static_idx, dynamic_idx = split_index_for_jit(idx, arr.shape)
#     646 internal_gather = partial(
#     647     _gather, treedef=treedef, static_idx=static_idx,
#     648     indices_are_sorted=indices_are_sorted, unique_indices=unique_indices,
#     649     mode=mode, fill_value=fill_value)
#     650 if out_sharding is not None:
#
# File ~/code/jaxlogit/venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:738, in split_index_for_jit(idx, shape)
#     734   raise TypeError(f"JAX does not support string indexing; got {idx=}")
#     736 # Expand any (concrete) boolean indices. We can then use advanced integer
#     737 # indexing logic to handle them.
# --> 738 idx = _expand_bool_indices(idx, shape)
#     740 leaves, treedef = tree_flatten(idx)
#     741 dynamic = [None] * len(leaves)
#
# File ~/code/jaxlogit/venv/lib/python3.10/site-packages/jax/_src/numpy/indexing.py:1059, in _expand_bool_indices(idx, shape)
#    1055   abstract_i = core.get_aval(i)
#    1057 if not core.is_concrete(i):
#    1058   # TODO(mattjj): improve this error by tracking _why_ the indices are not concrete
# -> 1059   raise errors.NonConcreteBooleanIndexError(abstract_i)
#    1060 elif np.ndim(i) == 0:
#    1061   out.append(bool(i))
#
# NonConcreteBooleanIndexError: Array boolean indices must be concrete; got bool[6]
#
# See https://docs.jax.dev/en/latest/errors.html#jax.errors.NonConcreteBooleanIndexError

# %%
model.coeff_names
# Out:
# array(['ASC_CAR', 'ASC_TRAIN', 'ASC_SM', 'CO', 'TT', 'sd.ASC_CAR',
#        'sd.ASC_TRAIN', 'sd.ASC_SM'], dtype='<U12')
