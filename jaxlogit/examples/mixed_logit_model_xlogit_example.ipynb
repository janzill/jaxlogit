# %% [markdown]
# # Mixed Logit

# %%
import pandas as pd
import numpy as np
import jax

from jaxlogit.mixed_logit import MixedLogit

# %%
#  for log dists?
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Swissmetro Dataset

# %% [markdown]
# The swissmetro dataset contains stated-preferences for three alternative transportation modes that include car, train and a newly introduced mode: the swissmetro. This dataset is commonly used for estimation examples with the `Biogeme` and `PyLogit` packages. The dataset is available at http://transp-or.epfl.ch/data/swissmetro.dat and [Bierlaire et. al., (2001)](https://transp-or.epfl.ch/documents/proceedings/BierAxhaAbay01.pdf) provides a detailed discussion of the data as wells as its context and collection process. The explanatory variables in this example include the travel time (`TT`) and cost `CO` for each of the three alternative modes.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is imported to the Python environment using `pandas`. Then, two types of samples, ones with a trip purpose different to commute or business and ones with an unknown choice, are filtered out. The original dataset contains 10,729 records, but after filtering, 6,768 records remain for following analysis. Finally, a new column that uniquely identifies each sample is added to the dataframe and the `CHOICE` column, which originally contains a numerical coding of the choices, is mapped to a description that is consistent with the alternatives in the column names.

# %%
df_wide = pd.read_table("http://transp-or.epfl.ch/data/swissmetro.dat", sep='\t')

# Keep only observations for commute and business purposes that contain known choices
df_wide = df_wide[(df_wide['PURPOSE'].isin([1, 3]) & (df_wide['CHOICE'] != 0))]

df_wide['custom_id'] = np.arange(len(df_wide))  # Add unique identifier
df_wide['CHOICE'] = df_wide['CHOICE'].map({1: 'TRAIN', 2:'SM', 3: 'CAR'})
df_wide
# Out:
#       GROUP  SURVEY  SP   ID  PURPOSE  FIRST  TICKET  WHO  LUGGAGE  AGE  ...  \
# 0         2       0   1    1        1      0       1    1        0    3  ...
# 1         2       0   1    1        1      0       1    1        0    3  ...
# 2         2       0   1    1        1      0       1    1        0    3  ...
# 3         2       0   1    1        1      0       1    1        0    3  ...
# 4         2       0   1    1        1      0       1    1        0    3  ...
# ...     ...     ...  ..  ...      ...    ...     ...  ...      ...  ...  ...
# 8446      3       1   1  939        3      1       7    3        1    5  ...
# 8447      3       1   1  939        3      1       7    3        1    5  ...
# 8448      3       1   1  939        3      1       7    3        1    5  ...
# 8449      3       1   1  939        3      1       7    3        1    5  ...
# 8450      3       1   1  939        3      1       7    3        1    5  ...
#
#       TRAIN_CO  TRAIN_HE  SM_TT  SM_CO  SM_HE  SM_SEATS  CAR_TT  CAR_CO  \
# 0           48       120     63     52     20         0     117      65
# 1           48        30     60     49     10         0     117      84
# 2           48        60     67     58     30         0     117      52
# 3           40        30     63     52     20         0      72      52
# 4           36        60     63     42     20         0      90      84
# ...        ...       ...    ...    ...    ...       ...     ...     ...
# 8446        13        30     50     17     30         0     130      64
# 8447        12        30     53     16     10         0      80      80
# 8448        16        60     50     16     20         0      80      64
# 8449        16        30     53     17     30         0      80     104
# 8450        13        60     53     21     30         0     100      80
#
#       CHOICE  custom_id
# 0         SM          0
# 1         SM          1
# 2         SM          2
# 3         SM          3
# 4         SM          4
# ...      ...        ...
# 8446   TRAIN       6763
# 8447   TRAIN       6764
# 8448   TRAIN       6765
# 8449   TRAIN       6766
# 8450   TRAIN       6767
#
# [6768 rows x 29 columns]

# %% [markdown]
# ### Reshape data

# %% [markdown]
# The imported dataframe is in wide format, and it needs to be reshaped to long format for processing by `xlogit`, which offers the convenient `wide_to_long` utility for this reshaping process. The user needs to specify the column that uniquely identifies each sample, the names of the alternatives, the columns that vary across alternatives, and whether the alternative names are a prefix or suffix of the column names. Additionally, the user can specify a value (`empty_val`) to be used by default when an alternative is not available for a certain variable. Additional usage examples for the `wide_to_long` function are available in xlogit's documentation at https://xlogit.readthedocs.io/en/latest/notebooks/convert_data_wide_to_long.html. Also, details about the function parameters are available at the [API reference ](https://xlogit.readthedocs.io/en/latest/api/utils.html#xlogit.utils.wide_to_long).

# %%
from jaxlogit.utils import wide_to_long

df = wide_to_long(df_wide, id_col='custom_id', alt_name='alt', sep='_',
                  alt_list=['TRAIN', 'SM', 'CAR'], empty_val=0,
                  varying=['TT', 'CO', 'HE', 'AV', 'SEATS'], alt_is_prefix=True)
df
# Out:
#        custom_id    alt   TT   CO   HE  AV  SEATS  GROUP  SURVEY  SP  ...  \
# 0              0  TRAIN  112   48  120   1      0      2       0   1  ...
# 1              0     SM   63   52   20   1      0      2       0   1  ...
# 2              0    CAR  117   65    0   1      0      2       0   1  ...
# 3              1  TRAIN  103   48   30   1      0      2       0   1  ...
# 4              1     SM   60   49   10   1      0      2       0   1  ...
# ...          ...    ...  ...  ...  ...  ..    ...    ...     ...  ..  ...
# 20299       6766     SM   53   17   30   1      0      3       1   1  ...
# 20300       6766    CAR   80  104    0   1      0      3       1   1  ...
# 20301       6767  TRAIN  108   13   60   1      0      3       1   1  ...
# 20302       6767     SM   53   21   30   1      0      3       1   1  ...
# 20303       6767    CAR  100   80    0   1      0      3       1   1  ...
#
#        TICKET  WHO  LUGGAGE  AGE  MALE  INCOME  GA  ORIGIN  DEST  CHOICE
# 0           1    1        0    3     0       2   0       2     1      SM
# 1           1    1        0    3     0       2   0       2     1      SM
# 2           1    1        0    3     0       2   0       2     1      SM
# 3           1    1        0    3     0       2   0       2     1      SM
# 4           1    1        0    3     0       2   0       2     1      SM
# ...       ...  ...      ...  ...   ...     ...  ..     ...   ...     ...
# 20299       7    3        1    5     1       2   0       1     2   TRAIN
# 20300       7    3        1    5     1       2   0       1     2   TRAIN
# 20301       7    3        1    5     1       2   0       1     2   TRAIN
# 20302       7    3        1    5     1       2   0       1     2   TRAIN
# 20303       7    3        1    5     1       2   0       1     2   TRAIN
#
# [20304 rows x 23 columns]

# %% [markdown]
# ### Create model specification

# %% [markdown]
# Following the reshaping, users can create or update the dataset's columns in order to accommodate their model specification needs, if necessary. The code below shows how the columns `ASC_TRAIN` and `ASC_CAR` were created to incorporate alternative-specific constants in the model. In addition, the example illustrates an effective way of establishing variable interactions (e.g., trip costs for commuters with an annual pass) by updating existing columns conditional on values of other columns. Although apparently simple, column operations provide users with an intuitive and highly-flexible mechanism to incorporate model specification aspects, such as variable transformations, interactions, and alternative specific coefficients and constants. By operating the dataframe columns, any utility specification can be accommodated in `xlogit`. As shown in [this specification example](https://xlogit.readthedocs.io/en/latest/notebooks/multinomial_model.html#Create-model-specification), highly-flexible utility specifications can be modeled in `xlogit` by operating the dataframe columns.

# %%
df['ASC_TRAIN'] = np.ones(len(df))*(df['alt'] == 'TRAIN')
df['ASC_CAR'] = np.ones(len(df))*(df['alt'] == 'CAR')
df['TT'], df['CO'] = df['TT']/100, df['CO']/100  # Scale variables
annual_pass = (df['GA'] == 1) & (df['alt'].isin(['TRAIN', 'SM']))
df.loc[annual_pass, 'CO'] = 0  # Cost zero for pass holders

# %% [markdown]
# ### Estimate model parameters

# %% [markdown]
# The `fit` method estimates the model by taking as input the data from the previous step along with additional specification criteria, such as the distribution of the random parameters (`randvars`), the number of random draws (`n_draws`), and the availability of alternatives for the choice situations (`avail`). We set the optimization method as `L-BFGS-B` as this is a robust routine that usually helps solve convergence issues.  Once the estimation routine is completed, the `summary` method can be used to display the estimation results.

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'CO', 'TT']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars={'TT': 'n'},
    n_draws=1500,
)
model.summary()
# Out:
# 2025-07-04 13:33:49,310 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# INFO:2025-07-04 13:33:49,390:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 13:33:49,390 INFO jax._src.xla_bridge: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 13:33:51,401 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:33:52,019 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 7309.54
# 2025-07-04 13:33:52,021 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:33:52,797 INFO jaxlogit._optimize: Iter 1, fun = 5509.545, |grad| = 1054.174
# 2025-07-04 13:33:53,232 INFO jaxlogit._optimize: Iter 2, fun = 4969.103, |grad| = 571.378
# 2025-07-04 13:33:53,725 INFO jaxlogit._optimize: Iter 3, fun = 4611.336, |grad| = 275.850
# 2025-07-04 13:33:54,191 INFO jaxlogit._optimize: Iter 4, fun = 4470.256, |grad| = 221.282
# 2025-07-04 13:33:54,651 INFO jaxlogit._optimize: Iter 5, fun = 4395.300, |grad| = 63.354
# 2025-07-04 13:33:55,107 INFO jaxlogit._optimize: Iter 6, fun = 4380.971, |grad| = 54.077
# 2025-07-04 13:33:55,541 INFO jaxlogit._optimize: Iter 7, fun = 4366.435, |grad| = 40.186
# 2025-07-04 13:33:55,978 INFO jaxlogit._optimize: Iter 8, fun = 4360.871, |grad| = 13.210
# 2025-07-04 13:33:56,451 INFO jaxlogit._optimize: Iter 9, fun = 4360.011, |grad| = 10.823
# 2025-07-04 13:33:56,931 INFO jaxlogit._optimize: Iter 10, fun = 4359.481, |grad| = 6.401
# 2025-07-04 13:33:57,450 INFO jaxlogit._optimize: Iter 11, fun = 4359.251, |grad| = 2.223
# 2025-07-04 13:33:57,961 INFO jaxlogit._optimize: Iter 12, fun = 4359.224, |grad| = 1.269
# 2025-07-04 13:33:58,506 INFO jaxlogit._optimize: Iter 13, fun = 4359.219, |grad| = 0.360
# 2025-07-04 13:33:58,982 INFO jaxlogit._optimize: Iter 14, fun = 4359.218, |grad| = 0.078
# 2025-07-04 13:33:59,491 INFO jaxlogit._optimize: Iter 15, fun = 4359.218, |grad| = 0.018
# 2025-07-04 13:33:59,943 INFO jaxlogit._optimize: Iter 16, fun = 4359.218, |grad| = 0.002
# 2025-07-04 13:33:59,944 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -4359.22
# 2025-07-04 13:33:59,945 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:34:02,815 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:34:07,713 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:34:07,898 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 16
#     Function evaluations: 17
# Estimation time= 18.6 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# ASC_CAR                 0.2831119     0.0560481     5.0512331       4.5e-07 ***
# ASC_TRAIN              -0.5722801     0.0794782    -7.2004683      6.65e-13 ***
# CO                     -1.6601727     0.0778872   -21.3151023      1.26e-97 ***
# TT                     -3.2289922     0.1749822   -18.4532610      3.17e-74 ***
# sd.TT                   3.6485578     0.1683478    21.6727368     9.28e-101 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -4359.218
# AIC= 8728.436
# BIC= 8762.536

# %% [markdown]
# The negative signs for the cost and time coefficients suggest that decision makers experience a general disutility with alternatives that have higher waiting times and costs, which conforms to the underlying decision making theory. Note that these estimates are highly consistent with those returned by Biogeme (https://biogeme.epfl.ch/examples/swissmetro/05normalMixtureIntegral.html)

# %% [markdown]
# ## Electricity Dataset

# %% [markdown]
# The electricity dataset contains 4,308 choices among four electricity suppliers based on the attributes of the offered plans, which include prices(pf), contract lengths(cl), time of day rates (tod), seasonal rates(seas), as well as attributes of the suppliers, which include whether the supplier is local (loc) and well-known (wk). The data was collected through a survey where 12 different choice situations were presented to each participant. The multiple responses per participants were organized into panels. Given that some participants answered less than 12 of the choice situations, some panels are unbalanced, which `xlogit` is able to handle. [Revelt and Train (1999)](https://escholarship.org/content/qt1900p96t/qt1900p96t.pdf) provide a detailed description of this dataset.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is already in long format so no reshaping is necessary, it can be used directly in xlogit.

# %%
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/electricity_long.csv")
df
# Out:
#        choice   id  alt  pf  cl  loc  wk  tod  seas  chid
# 0           0    1    1   7   5    0   1    0     0     1
# 1           0    1    2   9   1    1   0    0     0     1
# 2           0    1    3   0   0    0   0    0     1     1
# 3           1    1    4   0   5    0   1    1     0     1
# 4           0    1    1   7   0    0   1    0     0     2
# ...       ...  ...  ...  ..  ..  ...  ..  ...   ...   ...
# 17227       0  361    4   0   1    1   0    0     1  4307
# 17228       1  361    1   9   0    0   1    0     0  4308
# 17229       0  361    2   7   0    0   0    0     0  4308
# 17230       0  361    3   0   1    0   1    0     1  4308
# 17231       0  361    4   0   5    1   0    1     0  4308
#
# [17232 rows x 10 columns]

# %% [markdown]
# ### Fit the model

# %% [markdown]
# Note that the parameter `panels` was included in the `fit` function in order to take into account panel structure of this dataset during estimation.

# %%
varnames = ['pf', 'cl', 'loc', 'wk', 'tod', 'seas']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    ids=df['chid'],
    panels=df['id'],
    alts=df['alt'],
    n_draws=600,
    randvars={'pf': 'n', 'cl': 'n', 'loc': 'n', 'wk': 'n', 'tod': 'n', 'seas': 'n'}
)
model.summary()
# Out:
# 2025-07-04 13:34:55,944 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 600 random draws for each random variable and observation.
# 2025-07-04 13:34:58,128 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:34:58,571 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 5620.08
# 2025-07-04 13:34:58,572 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:34:59,394 INFO jaxlogit._optimize: Iter 1, fun = 5377.286, |grad| = 814.514
# 2025-07-04 13:34:59,757 INFO jaxlogit._optimize: Iter 2, fun = 5324.697, |grad| = 662.525
# 2025-07-04 13:35:00,302 INFO jaxlogit._optimize: Iter 3, fun = 5279.961, |grad| = 523.178
# 2025-07-04 13:35:00,662 INFO jaxlogit._optimize: Iter 4, fun = 5206.861, |grad| = 3507.556
# 2025-07-04 13:35:01,013 INFO jaxlogit._optimize: Iter 5, fun = 5043.345, |grad| = 873.688
# 2025-07-04 13:35:01,390 INFO jaxlogit._optimize: Iter 6, fun = 4945.232, |grad| = 933.875
# 2025-07-04 13:35:01,749 INFO jaxlogit._optimize: Iter 7, fun = 4766.712, |grad| = 465.620
# 2025-07-04 13:35:02,104 INFO jaxlogit._optimize: Iter 8, fun = 4703.285, |grad| = 467.420
# 2025-07-04 13:35:02,505 INFO jaxlogit._optimize: Iter 9, fun = 4648.685, |grad| = 555.690
# 2025-07-04 13:35:02,859 INFO jaxlogit._optimize: Iter 10, fun = 4598.187, |grad| = 456.432
# 2025-07-04 13:35:03,222 INFO jaxlogit._optimize: Iter 11, fun = 4548.417, |grad| = 685.122
# 2025-07-04 13:35:03,692 INFO jaxlogit._optimize: Iter 12, fun = 4509.383, |grad| = 322.061
# 2025-07-04 13:35:04,068 INFO jaxlogit._optimize: Iter 13, fun = 4469.256, |grad| = 136.427
# 2025-07-04 13:35:04,454 INFO jaxlogit._optimize: Iter 14, fun = 4437.989, |grad| = 191.167
# 2025-07-04 13:35:04,852 INFO jaxlogit._optimize: Iter 15, fun = 4338.253, |grad| = 270.984
# 2025-07-04 13:35:05,247 INFO jaxlogit._optimize: Iter 16, fun = 4309.865, |grad| = 456.010
# 2025-07-04 13:35:05,677 INFO jaxlogit._optimize: Iter 17, fun = 4260.679, |grad| = 301.595
# 2025-07-04 13:35:06,035 INFO jaxlogit._optimize: Iter 18, fun = 4239.053, |grad| = 276.427
# 2025-07-04 13:35:06,415 INFO jaxlogit._optimize: Iter 19, fun = 4221.387, |grad| = 121.380
# 2025-07-04 13:35:06,806 INFO jaxlogit._optimize: Iter 20, fun = 4212.505, |grad| = 114.899
# 2025-07-04 13:35:07,185 INFO jaxlogit._optimize: Iter 21, fun = 4171.085, |grad| = 183.024
# 2025-07-04 13:35:07,540 INFO jaxlogit._optimize: Iter 22, fun = 4147.554, |grad| = 277.185
# 2025-07-04 13:35:07,943 INFO jaxlogit._optimize: Iter 23, fun = 4061.441, |grad| = 176.557
# 2025-07-04 13:35:08,499 INFO jaxlogit._optimize: Iter 24, fun = 4039.651, |grad| = 255.352
# 2025-07-04 13:35:08,866 INFO jaxlogit._optimize: Iter 25, fun = 4014.875, |grad| = 144.733
# 2025-07-04 13:35:09,225 INFO jaxlogit._optimize: Iter 26, fun = 4006.659, |grad| = 93.243
# 2025-07-04 13:35:09,608 INFO jaxlogit._optimize: Iter 27, fun = 4001.954, |grad| = 154.019
# 2025-07-04 13:35:10,001 INFO jaxlogit._optimize: Iter 28, fun = 3997.281, |grad| = 83.051
# 2025-07-04 13:35:10,356 INFO jaxlogit._optimize: Iter 29, fun = 3990.484, |grad| = 67.465
# 2025-07-04 13:35:10,720 INFO jaxlogit._optimize: Iter 30, fun = 3984.802, |grad| = 106.685
# 2025-07-04 13:35:11,136 INFO jaxlogit._optimize: Iter 31, fun = 3978.200, |grad| = 97.267
# 2025-07-04 13:35:11,656 INFO jaxlogit._optimize: Iter 32, fun = 3972.940, |grad| = 149.331
# 2025-07-04 13:35:12,059 INFO jaxlogit._optimize: Iter 33, fun = 3959.484, |grad| = 102.357
# 2025-07-04 13:35:12,618 INFO jaxlogit._optimize: Iter 34, fun = 3949.553, |grad| = 90.873
# 2025-07-04 13:35:12,968 INFO jaxlogit._optimize: Iter 35, fun = 3936.496, |grad| = 201.080
# 2025-07-04 13:35:13,342 INFO jaxlogit._optimize: Iter 36, fun = 3926.854, |grad| = 131.863
# 2025-07-04 13:35:13,707 INFO jaxlogit._optimize: Iter 37, fun = 3921.002, |grad| = 74.231
# 2025-07-04 13:35:14,094 INFO jaxlogit._optimize: Iter 38, fun = 3913.789, |grad| = 190.477
# 2025-07-04 13:35:14,475 INFO jaxlogit._optimize: Iter 39, fun = 3905.655, |grad| = 54.497
# 2025-07-04 13:35:14,868 INFO jaxlogit._optimize: Iter 40, fun = 3904.085, |grad| = 44.068
# 2025-07-04 13:35:15,242 INFO jaxlogit._optimize: Iter 41, fun = 3903.203, |grad| = 40.794
# 2025-07-04 13:35:15,638 INFO jaxlogit._optimize: Iter 42, fun = 3899.177, |grad| = 46.047
# 2025-07-04 13:35:16,022 INFO jaxlogit._optimize: Iter 43, fun = 3896.390, |grad| = 107.540
# 2025-07-04 13:35:16,410 INFO jaxlogit._optimize: Iter 44, fun = 3892.627, |grad| = 50.309
# 2025-07-04 13:35:16,830 INFO jaxlogit._optimize: Iter 45, fun = 3890.322, |grad| = 24.534
# 2025-07-04 13:35:17,253 INFO jaxlogit._optimize: Iter 46, fun = 3889.797, |grad| = 25.126
# 2025-07-04 13:35:17,660 INFO jaxlogit._optimize: Iter 47, fun = 3889.424, |grad| = 36.804
# 2025-07-04 13:35:18,101 INFO jaxlogit._optimize: Iter 48, fun = 3889.011, |grad| = 18.120
# 2025-07-04 13:35:18,477 INFO jaxlogit._optimize: Iter 49, fun = 3888.633, |grad| = 11.914
# 2025-07-04 13:35:18,856 INFO jaxlogit._optimize: Iter 50, fun = 3888.540, |grad| = 15.191
# 2025-07-04 13:35:19,209 INFO jaxlogit._optimize: Iter 51, fun = 3888.503, |grad| = 8.172
# 2025-07-04 13:35:19,592 INFO jaxlogit._optimize: Iter 52, fun = 3888.491, |grad| = 1.978
# 2025-07-04 13:35:19,967 INFO jaxlogit._optimize: Iter 53, fun = 3888.490, |grad| = 1.474
# 2025-07-04 13:35:20,376 INFO jaxlogit._optimize: Iter 54, fun = 3888.487, |grad| = 2.080
# 2025-07-04 13:35:20,755 INFO jaxlogit._optimize: Iter 55, fun = 3888.484, |grad| = 2.050
# 2025-07-04 13:35:21,303 INFO jaxlogit._optimize: Iter 56, fun = 3888.481, |grad| = 3.716
# 2025-07-04 13:35:21,763 INFO jaxlogit._optimize: Iter 57, fun = 3888.474, |grad| = 1.759
# 2025-07-04 13:35:22,191 INFO jaxlogit._optimize: Iter 58, fun = 3888.472, |grad| = 1.976
# 2025-07-04 13:35:22,621 INFO jaxlogit._optimize: Iter 59, fun = 3888.471, |grad| = 2.404
# 2025-07-04 13:35:22,992 INFO jaxlogit._optimize: Iter 60, fun = 3888.470, |grad| = 1.036
# 2025-07-04 13:35:23,397 INFO jaxlogit._optimize: Iter 61, fun = 3888.469, |grad| = 0.564
# 2025-07-04 13:35:23,770 INFO jaxlogit._optimize: Iter 62, fun = 3888.468, |grad| = 0.877
# 2025-07-04 13:35:24,124 INFO jaxlogit._optimize: Iter 63, fun = 3888.467, |grad| = 0.832
# 2025-07-04 13:35:24,706 INFO jaxlogit._optimize: Iter 64, fun = 3888.467, |grad| = 1.637
# 2025-07-04 13:35:25,077 INFO jaxlogit._optimize: Iter 65, fun = 3888.466, |grad| = 0.908
# 2025-07-04 13:35:25,451 INFO jaxlogit._optimize: Iter 66, fun = 3888.466, |grad| = 0.369
# 2025-07-04 13:35:25,819 INFO jaxlogit._optimize: Iter 67, fun = 3888.466, |grad| = 0.368
# 2025-07-04 13:35:26,195 INFO jaxlogit._optimize: Iter 68, fun = 3888.465, |grad| = 0.733
# 2025-07-04 13:35:26,601 INFO jaxlogit._optimize: Iter 69, fun = 3888.465, |grad| = 0.363
# 2025-07-04 13:35:26,974 INFO jaxlogit._optimize: Iter 70, fun = 3888.465, |grad| = 0.221
# 2025-07-04 13:35:27,358 INFO jaxlogit._optimize: Iter 71, fun = 3888.465, |grad| = 0.325
# 2025-07-04 13:35:27,729 INFO jaxlogit._optimize: Iter 72, fun = 3888.465, |grad| = 0.132
# 2025-07-04 13:35:28,102 INFO jaxlogit._optimize: Iter 73, fun = 3888.465, |grad| = 0.071
# 2025-07-04 13:35:28,466 INFO jaxlogit._optimize: Iter 74, fun = 3888.465, |grad| = 0.050
# 2025-07-04 13:35:28,852 INFO jaxlogit._optimize: Iter 75, fun = 3888.465, |grad| = 0.053
# 2025-07-04 13:35:29,224 INFO jaxlogit._optimize: Iter 76, fun = 3888.465, |grad| = 0.036
# 2025-07-04 13:35:29,804 INFO jaxlogit._optimize: Iter 77, fun = 3888.465, |grad| = 0.037
# 2025-07-04 13:35:30,195 INFO jaxlogit._optimize: Iter 78, fun = 3888.465, |grad| = 0.014
# 2025-07-04 13:35:30,572 INFO jaxlogit._optimize: Iter 79, fun = 3888.465, |grad| = 0.015
# 2025-07-04 13:35:30,574 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -3888.47
# 2025-07-04 13:35:30,575 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:35:33,943 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:35:39,227 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:35:39,416 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 79
#     Function evaluations: 88
# Estimation time= 43.5 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# pf                     -0.9972195     0.0378223   -26.3659335     3.71e-142 ***
# cl                     -0.2196723     0.0255171    -8.6088317      1.02e-17 ***
# loc                     2.2902120     0.1263074    18.1320474      7.24e-71 ***
# wk                      1.6943254     0.0961493    17.6218125      3.62e-67 ***
# tod                    -9.6753001     0.3350945   -28.8733449     9.79e-168 ***
# seas                   -9.6963453     0.3246603   -29.8661224     2.68e-178 ***
# sd.pf                   0.2207239     0.0191089    11.5508563      2.04e-30 ***
# sd.cl                   0.4115687     0.0254623    16.1638189      4.21e-57 ***
# sd.loc                  1.7840564     0.1181351    15.1018314      2.98e-50 ***
# sd.wk                   1.2296080     0.0943599    13.0310473      4.24e-38 ***
# sd.tod                  2.2757668     0.1737829    13.0954611      1.88e-38 ***
# sd.seas                 1.4864533     0.1638622     9.0713610      1.75e-19 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -3888.465
# AIC= 7800.930
# BIC= 7877.349

# %% [markdown]
# ## Fishing Dataset

# %% [markdown]
# This example illustrates the estimation of a Mixed Logit model for choices of 1,182 individuals for sport fishing modes using `xlogit`. The goal is to analyze the market shares of four alternatives (i.e., beach, pier, boat, and charter) based on their cost and fish catch rate. [Cameron (2005)](http://cameron.econ.ucdavis.edu/mmabook/mma.html) provides additional details about this dataset. The following code illustrates how to use `xlogit` to estimate the model parameters.

# %% [markdown]
# ### Read data

# %% [markdown]
# The data to be analyzed can be imported to Python using any preferred method. In this example, the data in CSV format was imported using the popular `pandas` Python package. However, it is worth highlighting that `xlogit` does not depend on the `pandas` package, as `xlogit` can take any array-like structure as input. This represents an additional advantage because `xlogit` can be used with any preferred dataframe library, and not only with `pandas`.

# %%
import pandas as pd
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/fishing_long.csv")
df
# Out:
#         id      alt  choice      income    price   catch
# 0        1    beach       0  7083.33170  157.930  0.0678
# 1        1     boat       0  7083.33170  157.930  0.2601
# 2        1  charter       1  7083.33170  182.930  0.5391
# 3        1     pier       0  7083.33170  157.930  0.0503
# 4        2    beach       0  1249.99980   15.114  0.1049
# ...    ...      ...     ...         ...      ...     ...
# 4723  1181     pier       0   416.66668   36.636  0.4522
# 4724  1182    beach       0  6250.00130  339.890  0.2537
# 4725  1182     boat       1  6250.00130  235.436  0.6817
# 4726  1182  charter       0  6250.00130  260.436  2.3014
# 4727  1182     pier       0  6250.00130  339.890  0.1498
#
# [4728 rows x 6 columns]

# %% [markdown]
# ### Fit model

# %% [markdown]
# Once the data is in the `Python` environment, `xlogit` can be used to fit the model, as shown below. The `MultinomialLogit` class is imported from `xlogit`, and its constructor is used to initialize a new model. The `fit` method estimates the model using the input data and estimation criteria provided as arguments to the method's call. The arguments of the `fit` methods are described in [`xlogit`'s documentation](https://https://xlogit.readthedocs.io/en/latest/api/).

# %%
varnames = ['price', 'catch']
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['id'],
    n_draws=1000,
    randvars={'price': 'n', 'catch': 'n'},
)
model.summary()
# Out:
# 2025-07-04 13:36:01,149 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1000 random draws for each random variable and observation.
# 2025-07-04 13:36:03,348 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:36:03,701 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 2586.70
# 2025-07-04 13:36:03,702 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:36:03,849 INFO jaxlogit._optimize: Iter 1, fun = 2261.519, |grad| = 509.074
# 2025-07-04 13:36:03,933 INFO jaxlogit._optimize: Iter 2, fun = 2246.481, |grad| = 455.966
# 2025-07-04 13:36:04,028 INFO jaxlogit._optimize: Iter 3, fun = 2119.608, |grad| = 531.081
# 2025-07-04 13:36:04,164 INFO jaxlogit._optimize: Iter 4, fun = 2086.043, |grad| = 710.226
# 2025-07-04 13:36:04,294 INFO jaxlogit._optimize: Iter 5, fun = 2043.830, |grad| = 954.897
# 2025-07-04 13:36:04,606 INFO jaxlogit._optimize: Iter 6, fun = 1983.488, |grad| = 1417.137
# 2025-07-04 13:36:04,790 INFO jaxlogit._optimize: Iter 7, fun = 1941.343, |grad| = 1911.362
# 2025-07-04 13:36:04,971 INFO jaxlogit._optimize: Iter 8, fun = 1880.600, |grad| = 3356.657
# 2025-07-04 13:36:05,152 INFO jaxlogit._optimize: Iter 9, fun = 1832.538, |grad| = 5244.062
# 2025-07-04 13:36:05,325 INFO jaxlogit._optimize: Iter 10, fun = 1608.852, |grad| = 9037.569
# 2025-07-04 13:36:05,446 INFO jaxlogit._optimize: Iter 11, fun = 1531.200, |grad| = 3541.833
# 2025-07-04 13:36:05,673 INFO jaxlogit._optimize: Iter 12, fun = 1393.306, |grad| = 2775.277
# 2025-07-04 13:36:05,951 INFO jaxlogit._optimize: Iter 13, fun = 1378.765, |grad| = 2650.595
# 2025-07-04 13:36:06,245 INFO jaxlogit._optimize: Iter 14, fun = 1324.776, |grad| = 1791.588
# 2025-07-04 13:36:06,403 INFO jaxlogit._optimize: Iter 15, fun = 1323.715, |grad| = 1883.221
# 2025-07-04 13:36:06,531 INFO jaxlogit._optimize: Iter 16, fun = 1317.008, |grad| = 1623.018
# 2025-07-04 13:36:06,646 INFO jaxlogit._optimize: Iter 17, fun = 1313.090, |grad| = 822.774
# 2025-07-04 13:36:06,764 INFO jaxlogit._optimize: Iter 18, fun = 1312.312, |grad| = 228.459
# 2025-07-04 13:36:06,879 INFO jaxlogit._optimize: Iter 19, fun = 1312.270, |grad| = 52.024
# 2025-07-04 13:36:06,992 INFO jaxlogit._optimize: Iter 20, fun = 1312.265, |grad| = 45.882
# 2025-07-04 13:36:07,120 INFO jaxlogit._optimize: Iter 21, fun = 1312.253, |grad| = 85.611
# 2025-07-04 13:36:07,244 INFO jaxlogit._optimize: Iter 22, fun = 1312.221, |grad| = 178.787
# 2025-07-04 13:36:07,371 INFO jaxlogit._optimize: Iter 23, fun = 1312.139, |grad| = 338.338
# 2025-07-04 13:36:07,479 INFO jaxlogit._optimize: Iter 24, fun = 1311.928, |grad| = 588.932
# 2025-07-04 13:36:07,588 INFO jaxlogit._optimize: Iter 25, fun = 1311.413, |grad| = 947.003
# 2025-07-04 13:36:07,712 INFO jaxlogit._optimize: Iter 26, fun = 1310.312, |grad| = 1328.099
# 2025-07-04 13:36:07,857 INFO jaxlogit._optimize: Iter 27, fun = 1308.639, |grad| = 1303.694
# 2025-07-04 13:36:08,078 INFO jaxlogit._optimize: Iter 28, fun = 1308.613, |grad| = 1424.691
# 2025-07-04 13:36:08,187 INFO jaxlogit._optimize: Iter 29, fun = 1307.293, |grad| = 850.545
# 2025-07-04 13:36:08,328 INFO jaxlogit._optimize: Iter 30, fun = 1306.796, |grad| = 267.047
# 2025-07-04 13:36:08,451 INFO jaxlogit._optimize: Iter 31, fun = 1306.722, |grad| = 32.837
# 2025-07-04 13:36:08,572 INFO jaxlogit._optimize: Iter 32, fun = 1306.719, |grad| = 3.662
# 2025-07-04 13:36:08,705 INFO jaxlogit._optimize: Iter 33, fun = 1306.719, |grad| = 3.631
# 2025-07-04 13:36:08,882 INFO jaxlogit._optimize: Iter 34, fun = 1306.677, |grad| = 77.642
# 2025-07-04 13:36:08,990 INFO jaxlogit._optimize: Iter 35, fun = 1306.380, |grad| = 357.894
# 2025-07-04 13:36:09,152 INFO jaxlogit._optimize: Iter 36, fun = 1305.710, |grad| = 941.197
# 2025-07-04 13:36:09,272 INFO jaxlogit._optimize: Iter 37, fun = 1305.093, |grad| = 1120.996
# 2025-07-04 13:36:09,383 INFO jaxlogit._optimize: Iter 38, fun = 1302.868, |grad| = 1262.137
# 2025-07-04 13:36:09,554 INFO jaxlogit._optimize: Iter 39, fun = 1302.677, |grad| = 907.562
# 2025-07-04 13:36:09,678 INFO jaxlogit._optimize: Iter 40, fun = 1301.212, |grad| = 516.536
# 2025-07-04 13:36:09,793 INFO jaxlogit._optimize: Iter 41, fun = 1300.551, |grad| = 117.957
# 2025-07-04 13:36:09,919 INFO jaxlogit._optimize: Iter 42, fun = 1300.526, |grad| = 8.402
# 2025-07-04 13:36:10,043 INFO jaxlogit._optimize: Iter 43, fun = 1300.524, |grad| = 2.315
# 2025-07-04 13:36:10,169 INFO jaxlogit._optimize: Iter 44, fun = 1300.523, |grad| = 0.071
# 2025-07-04 13:36:10,286 INFO jaxlogit._optimize: Iter 45, fun = 1300.523, |grad| = 0.010
# 2025-07-04 13:36:10,288 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1300.52
# 2025-07-04 13:36:10,288 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:36:11,342 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:36:14,167 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:36:14,589 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 45
#     Function evaluations: 75
# Estimation time= 13.4 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# price                  -0.0272469     0.0022842   -11.9283006      4.71e-31 ***
# catch                   1.3260435     0.1738918     7.6256804      4.97e-14 ***
# sd.price                0.0102261     0.0021414     4.7753244      2.02e-06 ***
# sd.catch                1.5661726     0.3755141     4.1707420      3.26e-05 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1300.523
# AIC= 2609.046
# BIC= 2629.346

# %% [markdown]
# ## Car Dataset

# %% [markdown]
# The fourth example uses a stated preference panel dataset for choice of car. Three alternatives are considered, with upto 6 choice situations per individual. This again is an unbalanced panel with responses of some individuals less than 6 situations. The dataset contains 8 explanaotry variables: price, operating cost, range, and binary indicators to indicate whether the car is electric, hybrid, and if performance is high or medium respectively. This dataset was taken from Kenneth Train's MATLAB codes for estimation of Mixed Logit models as shown in this link: https://eml.berkeley.edu/Software/abstracts/train1006mxlmsl.html

# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/car100_long.csv")

# %% [markdown]
# Since price and operating cost need to be estimated with negative coefficients, we reverse the variable signs in the dataframe.

# %%
df['price'] = -df['price']/10000
df['opcost'] = -df['opcost']
df
# Out:
#       person_id  choice_id  alt  choice   price  opcost  range  ev  gas  \
# 0             1          1    1       0 -4.6763  -47.43    0.0   0    0
# 1             1          1    2       1 -5.7209  -27.43    1.3   1    0
# 2             1          1    3       0 -8.7960  -32.41    1.2   1    0
# 3             1          2    1       1 -3.3768   -4.89    1.3   1    0
# 4             1          2    2       0 -9.0336  -30.19    0.0   0    0
# ...         ...        ...  ...     ...     ...     ...    ...  ..  ...
# 4447        100       1483    2       0 -2.8036  -14.45    1.6   1    0
# 4448        100       1483    3       0 -1.9360  -54.76    0.0   0    1
# 4449        100       1484    1       1 -2.4054  -50.57    0.0   0    1
# 4450        100       1484    2       0 -5.2795  -21.25    0.0   0    0
# 4451        100       1484    3       0 -6.0705  -25.41    1.4   1    0
#
#       hybrid  hiperf  medhiperf
# 0          1       0          0
# 1          0       1          1
# 2          0       0          1
# 3          0       1          1
# 4          1       0          1
# ...      ...     ...        ...
# 4447       0       0          0
# 4448       0       1          1
# 4449       0       0          0
# 4450       1       0          1
# 4451       0       0          0
#
# [4452 rows x 12 columns]

# %% [markdown]
# ### Fit the model

# %%
varnames = ['hiperf', 'medhiperf', 'price', 'opcost', 'range', 'ev', 'hybrid'] 
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['choice_id'],
    panels=df['person_id'],
    randvars = {'price': 'ln', 'opcost': 'n',  'range': 'ln', 'ev':'n', 'hybrid': 'n'}, 
    n_draws = 100,
) 
model.summary()
# Out:
# 2025-07-04 13:37:44,364 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 100 random draws for each random variable and observation.
# 2025-07-04 13:37:46,978 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:37:47,596 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 1633.91
# 2025-07-04 13:37:47,597 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:37:47,634 INFO jaxlogit._optimize: Iter 1, fun = 1586.946, |grad| = 567.390
# 2025-07-04 13:37:47,663 INFO jaxlogit._optimize: Iter 2, fun = 1388.794, |grad| = 1873.849
# 2025-07-04 13:37:47,703 INFO jaxlogit._optimize: Iter 3, fun = 1383.811, |grad| = 1691.287
# 2025-07-04 13:37:47,737 INFO jaxlogit._optimize: Iter 4, fun = 1372.993, |grad| = 336.720
# 2025-07-04 13:37:47,764 INFO jaxlogit._optimize: Iter 5, fun = 1366.836, |grad| = 425.777
# 2025-07-04 13:37:47,787 INFO jaxlogit._optimize: Iter 6, fun = 1360.690, |grad| = 371.287
# 2025-07-04 13:37:47,810 INFO jaxlogit._optimize: Iter 7, fun = 1340.339, |grad| = 119.331
# 2025-07-04 13:37:47,834 INFO jaxlogit._optimize: Iter 8, fun = 1335.058, |grad| = 69.472
# 2025-07-04 13:37:47,862 INFO jaxlogit._optimize: Iter 9, fun = 1330.524, |grad| = 57.684
# 2025-07-04 13:37:47,892 INFO jaxlogit._optimize: Iter 10, fun = 1321.992, |grad| = 58.043
# 2025-07-04 13:37:47,919 INFO jaxlogit._optimize: Iter 11, fun = 1314.266, |grad| = 54.214
# 2025-07-04 13:37:47,950 INFO jaxlogit._optimize: Iter 12, fun = 1311.391, |grad| = 33.163
# 2025-07-04 13:37:47,983 INFO jaxlogit._optimize: Iter 13, fun = 1309.328, |grad| = 17.513
# 2025-07-04 13:37:48,014 INFO jaxlogit._optimize: Iter 14, fun = 1308.967, |grad| = 12.972
# 2025-07-04 13:37:48,054 INFO jaxlogit._optimize: Iter 15, fun = 1308.958, |grad| = 24.101
# 2025-07-04 13:37:48,090 INFO jaxlogit._optimize: Iter 16, fun = 1308.791, |grad| = 16.978
# 2025-07-04 13:37:48,138 INFO jaxlogit._optimize: Iter 17, fun = 1308.738, |grad| = 64.825
# 2025-07-04 13:37:48,168 INFO jaxlogit._optimize: Iter 18, fun = 1308.567, |grad| = 48.806
# 2025-07-04 13:37:48,200 INFO jaxlogit._optimize: Iter 19, fun = 1307.927, |grad| = 19.121
# 2025-07-04 13:37:48,231 INFO jaxlogit._optimize: Iter 20, fun = 1307.500, |grad| = 41.969
# 2025-07-04 13:37:48,269 INFO jaxlogit._optimize: Iter 21, fun = 1306.889, |grad| = 52.880
# 2025-07-04 13:37:48,300 INFO jaxlogit._optimize: Iter 22, fun = 1305.880, |grad| = 70.414
# 2025-07-04 13:37:48,329 INFO jaxlogit._optimize: Iter 23, fun = 1305.236, |grad| = 21.009
# 2025-07-04 13:37:48,363 INFO jaxlogit._optimize: Iter 24, fun = 1305.116, |grad| = 7.226
# 2025-07-04 13:37:48,395 INFO jaxlogit._optimize: Iter 25, fun = 1305.076, |grad| = 9.795
# 2025-07-04 13:37:48,423 INFO jaxlogit._optimize: Iter 26, fun = 1305.041, |grad| = 56.097
# 2025-07-04 13:37:48,471 INFO jaxlogit._optimize: Iter 27, fun = 1304.968, |grad| = 22.883
# 2025-07-04 13:37:48,513 INFO jaxlogit._optimize: Iter 28, fun = 1304.884, |grad| = 17.452
# 2025-07-04 13:37:48,544 INFO jaxlogit._optimize: Iter 29, fun = 1304.807, |grad| = 20.126
# 2025-07-04 13:37:48,576 INFO jaxlogit._optimize: Iter 30, fun = 1304.779, |grad| = 35.809
# 2025-07-04 13:37:48,608 INFO jaxlogit._optimize: Iter 31, fun = 1304.738, |grad| = 27.094
# 2025-07-04 13:37:48,642 INFO jaxlogit._optimize: Iter 32, fun = 1304.682, |grad| = 31.384
# 2025-07-04 13:37:48,677 INFO jaxlogit._optimize: Iter 33, fun = 1304.636, |grad| = 32.173
# 2025-07-04 13:37:48,708 INFO jaxlogit._optimize: Iter 34, fun = 1304.593, |grad| = 20.377
# 2025-07-04 13:37:48,738 INFO jaxlogit._optimize: Iter 35, fun = 1304.567, |grad| = 10.395
# 2025-07-04 13:37:48,768 INFO jaxlogit._optimize: Iter 36, fun = 1304.546, |grad| = 18.988
# 2025-07-04 13:37:48,799 INFO jaxlogit._optimize: Iter 37, fun = 1304.517, |grad| = 32.665
# 2025-07-04 13:37:48,835 INFO jaxlogit._optimize: Iter 38, fun = 1304.464, |grad| = 38.595
# 2025-07-04 13:37:48,878 INFO jaxlogit._optimize: Iter 39, fun = 1304.440, |grad| = 69.149
# 2025-07-04 13:37:48,919 INFO jaxlogit._optimize: Iter 40, fun = 1304.401, |grad| = 13.102
# 2025-07-04 13:37:48,956 INFO jaxlogit._optimize: Iter 41, fun = 1304.377, |grad| = 8.443
# 2025-07-04 13:37:48,999 INFO jaxlogit._optimize: Iter 42, fun = 1304.375, |grad| = 9.005
# 2025-07-04 13:37:49,030 INFO jaxlogit._optimize: Iter 43, fun = 1304.372, |grad| = 4.146
# 2025-07-04 13:37:49,062 INFO jaxlogit._optimize: Iter 44, fun = 1304.370, |grad| = 6.240
# 2025-07-04 13:37:49,098 INFO jaxlogit._optimize: Iter 45, fun = 1304.365, |grad| = 12.840
# 2025-07-04 13:37:49,133 INFO jaxlogit._optimize: Iter 46, fun = 1304.355, |grad| = 22.732
# 2025-07-04 13:37:49,170 INFO jaxlogit._optimize: Iter 47, fun = 1304.336, |grad| = 31.237
# 2025-07-04 13:37:49,206 INFO jaxlogit._optimize: Iter 48, fun = 1304.306, |grad| = 31.856
# 2025-07-04 13:37:49,255 INFO jaxlogit._optimize: Iter 49, fun = 1304.288, |grad| = 33.536
# 2025-07-04 13:37:49,308 INFO jaxlogit._optimize: Iter 50, fun = 1304.254, |grad| = 20.233
# 2025-07-04 13:37:49,378 INFO jaxlogit._optimize: Iter 51, fun = 1304.237, |grad| = 18.343
# 2025-07-04 13:37:49,411 INFO jaxlogit._optimize: Iter 52, fun = 1304.229, |grad| = 6.996
# 2025-07-04 13:37:49,441 INFO jaxlogit._optimize: Iter 53, fun = 1304.226, |grad| = 5.634
# 2025-07-04 13:37:49,472 INFO jaxlogit._optimize: Iter 54, fun = 1304.222, |grad| = 5.677
# 2025-07-04 13:37:49,506 INFO jaxlogit._optimize: Iter 55, fun = 1304.219, |grad| = 7.818
# 2025-07-04 13:37:49,535 INFO jaxlogit._optimize: Iter 56, fun = 1304.211, |grad| = 15.661
# 2025-07-04 13:37:49,567 INFO jaxlogit._optimize: Iter 57, fun = 1304.201, |grad| = 13.728
# 2025-07-04 13:37:49,606 INFO jaxlogit._optimize: Iter 58, fun = 1304.195, |grad| = 9.676
# 2025-07-04 13:37:49,644 INFO jaxlogit._optimize: Iter 59, fun = 1304.185, |grad| = 4.141
# 2025-07-04 13:37:49,682 INFO jaxlogit._optimize: Iter 60, fun = 1304.179, |grad| = 2.849
# 2025-07-04 13:37:49,714 INFO jaxlogit._optimize: Iter 61, fun = 1304.170, |grad| = 11.459
# 2025-07-04 13:37:49,749 INFO jaxlogit._optimize: Iter 62, fun = 1304.162, |grad| = 2.484
# 2025-07-04 13:37:49,784 INFO jaxlogit._optimize: Iter 63, fun = 1304.156, |grad| = 4.289
# 2025-07-04 13:37:49,820 INFO jaxlogit._optimize: Iter 64, fun = 1304.154, |grad| = 4.646
# 2025-07-04 13:37:49,856 INFO jaxlogit._optimize: Iter 65, fun = 1304.152, |grad| = 3.561
# 2025-07-04 13:37:49,906 INFO jaxlogit._optimize: Iter 66, fun = 1304.150, |grad| = 4.848
# 2025-07-04 13:37:49,954 INFO jaxlogit._optimize: Iter 67, fun = 1304.137, |grad| = 6.048
# 2025-07-04 13:37:50,024 INFO jaxlogit._optimize: Iter 68, fun = 1304.132, |grad| = 17.954
# 2025-07-04 13:37:50,072 INFO jaxlogit._optimize: Iter 69, fun = 1304.124, |grad| = 10.244
# 2025-07-04 13:37:50,113 INFO jaxlogit._optimize: Iter 70, fun = 1304.115, |grad| = 3.398
# 2025-07-04 13:37:50,150 INFO jaxlogit._optimize: Iter 71, fun = 1304.114, |grad| = 5.097
# 2025-07-04 13:37:50,190 INFO jaxlogit._optimize: Iter 72, fun = 1304.113, |grad| = 4.509
# 2025-07-04 13:37:50,227 INFO jaxlogit._optimize: Iter 73, fun = 1304.113, |grad| = 2.185
# 2025-07-04 13:37:50,266 INFO jaxlogit._optimize: Iter 74, fun = 1304.113, |grad| = 1.109
# 2025-07-04 13:37:50,298 INFO jaxlogit._optimize: Iter 75, fun = 1304.112, |grad| = 1.627
# 2025-07-04 13:37:50,333 INFO jaxlogit._optimize: Iter 76, fun = 1304.112, |grad| = 1.883
# 2025-07-04 13:37:50,371 INFO jaxlogit._optimize: Iter 77, fun = 1304.112, |grad| = 0.696
# 2025-07-04 13:37:50,408 INFO jaxlogit._optimize: Iter 78, fun = 1304.112, |grad| = 0.788
# 2025-07-04 13:37:50,443 INFO jaxlogit._optimize: Iter 79, fun = 1304.111, |grad| = 2.146
# 2025-07-04 13:37:50,479 INFO jaxlogit._optimize: Iter 80, fun = 1304.111, |grad| = 2.310
# 2025-07-04 13:37:50,536 INFO jaxlogit._optimize: Iter 81, fun = 1304.111, |grad| = 2.438
# 2025-07-04 13:37:50,573 INFO jaxlogit._optimize: Iter 82, fun = 1304.111, |grad| = 0.819
# 2025-07-04 13:37:50,609 INFO jaxlogit._optimize: Iter 83, fun = 1304.111, |grad| = 0.432
# 2025-07-04 13:37:50,665 INFO jaxlogit._optimize: Iter 84, fun = 1304.111, |grad| = 1.132
# 2025-07-04 13:37:50,700 INFO jaxlogit._optimize: Iter 85, fun = 1304.110, |grad| = 0.800
# 2025-07-04 13:37:50,740 INFO jaxlogit._optimize: Iter 86, fun = 1304.110, |grad| = 0.400
# 2025-07-04 13:37:50,776 INFO jaxlogit._optimize: Iter 87, fun = 1304.110, |grad| = 1.025
# 2025-07-04 13:37:50,813 INFO jaxlogit._optimize: Iter 88, fun = 1304.110, |grad| = 1.296
# 2025-07-04 13:37:50,851 INFO jaxlogit._optimize: Iter 89, fun = 1304.110, |grad| = 1.549
# 2025-07-04 13:37:50,884 INFO jaxlogit._optimize: Iter 90, fun = 1304.110, |grad| = 0.332
# 2025-07-04 13:37:50,922 INFO jaxlogit._optimize: Iter 91, fun = 1304.110, |grad| = 0.202
# 2025-07-04 13:37:50,956 INFO jaxlogit._optimize: Iter 92, fun = 1304.110, |grad| = 0.522
# 2025-07-04 13:37:50,994 INFO jaxlogit._optimize: Iter 93, fun = 1304.110, |grad| = 0.296
# 2025-07-04 13:37:51,031 INFO jaxlogit._optimize: Iter 94, fun = 1304.110, |grad| = 0.155
# 2025-07-04 13:37:51,064 INFO jaxlogit._optimize: Iter 95, fun = 1304.110, |grad| = 0.341
# 2025-07-04 13:37:51,095 INFO jaxlogit._optimize: Iter 96, fun = 1304.110, |grad| = 0.470
# 2025-07-04 13:37:51,130 INFO jaxlogit._optimize: Iter 97, fun = 1304.110, |grad| = 0.302
# 2025-07-04 13:37:51,162 INFO jaxlogit._optimize: Iter 98, fun = 1304.110, |grad| = 0.826
# 2025-07-04 13:37:51,190 INFO jaxlogit._optimize: Iter 99, fun = 1304.110, |grad| = 0.225
# 2025-07-04 13:37:51,227 INFO jaxlogit._optimize: Iter 100, fun = 1304.110, |grad| = 0.073
# 2025-07-04 13:37:51,257 INFO jaxlogit._optimize: Iter 101, fun = 1304.110, |grad| = 0.095
# 2025-07-04 13:37:51,288 INFO jaxlogit._optimize: Iter 102, fun = 1304.110, |grad| = 0.182
# 2025-07-04 13:37:51,321 INFO jaxlogit._optimize: Iter 103, fun = 1304.110, |grad| = 0.236
# 2025-07-04 13:37:51,360 INFO jaxlogit._optimize: Iter 104, fun = 1304.110, |grad| = 0.452
# 2025-07-04 13:37:51,396 INFO jaxlogit._optimize: Iter 105, fun = 1304.110, |grad| = 0.162
# 2025-07-04 13:37:51,430 INFO jaxlogit._optimize: Iter 106, fun = 1304.110, |grad| = 0.089
# 2025-07-04 13:37:51,466 INFO jaxlogit._optimize: Iter 107, fun = 1304.110, |grad| = 0.094
# 2025-07-04 13:37:51,495 INFO jaxlogit._optimize: Iter 108, fun = 1304.110, |grad| = 0.154
# 2025-07-04 13:37:51,540 INFO jaxlogit._optimize: Iter 109, fun = 1304.110, |grad| = 0.493
# 2025-07-04 13:37:51,576 INFO jaxlogit._optimize: Iter 110, fun = 1304.110, |grad| = 0.382
# 2025-07-04 13:37:51,606 INFO jaxlogit._optimize: Iter 111, fun = 1304.110, |grad| = 0.088
# 2025-07-04 13:37:51,641 INFO jaxlogit._optimize: Iter 112, fun = 1304.110, |grad| = 0.060
# 2025-07-04 13:37:51,672 INFO jaxlogit._optimize: Iter 113, fun = 1304.110, |grad| = 0.110
# 2025-07-04 13:37:51,704 INFO jaxlogit._optimize: Iter 114, fun = 1304.110, |grad| = 0.160
# 2025-07-04 13:37:51,735 INFO jaxlogit._optimize: Iter 115, fun = 1304.110, |grad| = 0.237
# 2025-07-04 13:37:51,773 INFO jaxlogit._optimize: Iter 116, fun = 1304.110, |grad| = 0.727
# 2025-07-04 13:37:51,808 INFO jaxlogit._optimize: Iter 117, fun = 1304.110, |grad| = 0.341
# 2025-07-04 13:37:51,839 INFO jaxlogit._optimize: Iter 118, fun = 1304.110, |grad| = 0.140
# 2025-07-04 13:37:51,872 INFO jaxlogit._optimize: Iter 119, fun = 1304.110, |grad| = 0.162
# 2025-07-04 13:37:51,902 INFO jaxlogit._optimize: Iter 120, fun = 1304.110, |grad| = 1.099
# 2025-07-04 13:37:51,932 INFO jaxlogit._optimize: Iter 121, fun = 1304.110, |grad| = 0.203
# 2025-07-04 13:37:51,965 INFO jaxlogit._optimize: Iter 122, fun = 1304.110, |grad| = 0.147
# 2025-07-04 13:37:52,019 INFO jaxlogit._optimize: Iter 123, fun = 1304.110, |grad| = 0.207
# 2025-07-04 13:37:52,070 INFO jaxlogit._optimize: Iter 124, fun = 1304.110, |grad| = 0.231
# 2025-07-04 13:37:52,117 INFO jaxlogit._optimize: Iter 125, fun = 1304.110, |grad| = 0.158
# 2025-07-04 13:37:52,147 INFO jaxlogit._optimize: Iter 126, fun = 1304.110, |grad| = 0.173
# 2025-07-04 13:37:52,176 INFO jaxlogit._optimize: Iter 127, fun = 1304.110, |grad| = 0.300
# 2025-07-04 13:37:52,206 INFO jaxlogit._optimize: Iter 128, fun = 1304.110, |grad| = 0.342
# 2025-07-04 13:37:52,251 INFO jaxlogit._optimize: Iter 129, fun = 1304.110, |grad| = 0.445
# 2025-07-04 13:37:52,284 INFO jaxlogit._optimize: Iter 130, fun = 1304.110, |grad| = 0.187
# 2025-07-04 13:37:52,313 INFO jaxlogit._optimize: Iter 131, fun = 1304.110, |grad| = 0.072
# 2025-07-04 13:37:52,345 INFO jaxlogit._optimize: Iter 132, fun = 1304.110, |grad| = 0.039
# 2025-07-04 13:37:52,377 INFO jaxlogit._optimize: Iter 133, fun = 1304.110, |grad| = 0.105
# 2025-07-04 13:37:52,415 INFO jaxlogit._optimize: Iter 134, fun = 1304.110, |grad| = 0.126
# 2025-07-04 13:37:52,451 INFO jaxlogit._optimize: Iter 135, fun = 1304.110, |grad| = 0.071
# 2025-07-04 13:37:52,483 INFO jaxlogit._optimize: Iter 136, fun = 1304.110, |grad| = 0.028
# 2025-07-04 13:37:52,513 INFO jaxlogit._optimize: Iter 137, fun = 1304.110, |grad| = 0.050
# 2025-07-04 13:37:52,515 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1304.11
# 2025-07-04 13:37:52,516 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:37:54,460 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:37:59,542 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:37:59,751 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 137
#     Function evaluations: 152
# Estimation time= 15.4 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# hiperf                  0.1177953     0.0963411     1.2226904         0.222
# medhiperf               0.5575976     0.0997809     5.5882211      2.73e-08 ***
# price                   0.6888002     0.0746569     9.2262147      9.34e-20 ***
# opcost                  0.0102561     0.0057795     1.7745696        0.0762 .
# range                   0.4741680     0.2254765     2.1029603        0.0356 *
# ev                     -1.5306126     0.3554883    -4.3056627      1.77e-05 ***
# hybrid                  0.6233113     0.1473977     4.2287733      2.49e-05 ***
# sd.price                0.4517371     0.0536072     8.4267917      8.28e-17 ***
# sd.opcost               0.0377705     0.0049602     7.6147788      4.68e-14 ***
# sd.range                0.6352979     0.1581616     4.0167639       6.2e-05 ***
# sd.ev                   0.8574290     0.2580084     3.3232593      0.000911 ***
# sd.hybrid               0.4251265     0.1869649     2.2738310        0.0231 *
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1304.110
# AIC= 2632.219
# BIC= 2695.849

# %% [markdown]
# ## References

# %% [markdown]
# - Bierlaire, M. (2018). PandasBiogeme: a short introduction. EPFL (Transport and Mobility Laboratory, ENAC).
#
# - Brathwaite, T., & Walker, J. L. (2018). Asymmetric, closed-form, finite-parameter models of multinomial choice. Journal of Choice Modelling, 29, 78–112.
#
# - Cameron, A. C., & Trivedi, P. K. (2005). Microeconometrics: methods and applications. Cambridge university press.
#
# - Croissant, Y. (2020). Estimation of Random Utility Models in R: The mlogit Package. Journal of Statistical Software, 95(1), 1-41.
#
# - Revelt, D., & Train, K. (1999). Customer-specific taste parameters and mixed logit. University of California, Berkeley.
