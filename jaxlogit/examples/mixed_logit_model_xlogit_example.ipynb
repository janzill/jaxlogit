# %% [markdown]
# # Mixed Logit

# %%
import pandas as pd
import numpy as np
import jax

from jaxlogit.mixed_logit import MixedLogit

# %%
#  64bit precision
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Swissmetro Dataset

# %% [markdown]
# The swissmetro dataset contains stated-preferences for three alternative transportation modes that include car, train and a newly introduced mode: the swissmetro. This dataset is commonly used for estimation examples with the `Biogeme` and `PyLogit` packages. The dataset is available at http://transp-or.epfl.ch/data/swissmetro.dat and [Bierlaire et. al., (2001)](https://transp-or.epfl.ch/documents/proceedings/BierAxhaAbay01.pdf) provides a detailed discussion of the data as wells as its context and collection process. The explanatory variables in this example include the travel time (`TT`) and cost `CO` for each of the three alternative modes.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is imported to the Python environment using `pandas`. Then, two types of samples, ones with a trip purpose different to commute or business and ones with an unknown choice, are filtered out. The original dataset contains 10,729 records, but after filtering, 6,768 records remain for following analysis. Finally, a new column that uniquely identifies each sample is added to the dataframe and the `CHOICE` column, which originally contains a numerical coding of the choices, is mapped to a description that is consistent with the alternatives in the column names.

# %%
df_wide = pd.read_table("http://transp-or.epfl.ch/data/swissmetro.dat", sep='\t')

# Keep only observations for commute and business purposes that contain known choices
df_wide = df_wide[(df_wide['PURPOSE'].isin([1, 3]) & (df_wide['CHOICE'] != 0))]

df_wide['custom_id'] = np.arange(len(df_wide))  # Add unique identifier
df_wide['CHOICE'] = df_wide['CHOICE'].map({1: 'TRAIN', 2:'SM', 3: 'CAR'})
df_wide
# Out:
#       GROUP  SURVEY  SP   ID  PURPOSE  FIRST  TICKET  WHO  LUGGAGE  AGE  ...  \
# 0         2       0   1    1        1      0       1    1        0    3  ...
# 1         2       0   1    1        1      0       1    1        0    3  ...
# 2         2       0   1    1        1      0       1    1        0    3  ...
# 3         2       0   1    1        1      0       1    1        0    3  ...
# 4         2       0   1    1        1      0       1    1        0    3  ...
# ...     ...     ...  ..  ...      ...    ...     ...  ...      ...  ...  ...
# 8446      3       1   1  939        3      1       7    3        1    5  ...
# 8447      3       1   1  939        3      1       7    3        1    5  ...
# 8448      3       1   1  939        3      1       7    3        1    5  ...
# 8449      3       1   1  939        3      1       7    3        1    5  ...
# 8450      3       1   1  939        3      1       7    3        1    5  ...
#
#       TRAIN_CO  TRAIN_HE  SM_TT  SM_CO  SM_HE  SM_SEATS  CAR_TT  CAR_CO  \
# 0           48       120     63     52     20         0     117      65
# 1           48        30     60     49     10         0     117      84
# 2           48        60     67     58     30         0     117      52
# 3           40        30     63     52     20         0      72      52
# 4           36        60     63     42     20         0      90      84
# ...        ...       ...    ...    ...    ...       ...     ...     ...
# 8446        13        30     50     17     30         0     130      64
# 8447        12        30     53     16     10         0      80      80
# 8448        16        60     50     16     20         0      80      64
# 8449        16        30     53     17     30         0      80     104
# 8450        13        60     53     21     30         0     100      80
#
#       CHOICE  custom_id
# 0         SM          0
# 1         SM          1
# 2         SM          2
# 3         SM          3
# 4         SM          4
# ...      ...        ...
# 8446   TRAIN       6763
# 8447   TRAIN       6764
# 8448   TRAIN       6765
# 8449   TRAIN       6766
# 8450   TRAIN       6767
#
# [6768 rows x 29 columns]

# %% [markdown]
# ### Reshape data

# %% [markdown]
# The imported dataframe is in wide format, and it needs to be reshaped to long format for processing by `xlogit`, which offers the convenient `wide_to_long` utility for this reshaping process. The user needs to specify the column that uniquely identifies each sample, the names of the alternatives, the columns that vary across alternatives, and whether the alternative names are a prefix or suffix of the column names. Additionally, the user can specify a value (`empty_val`) to be used by default when an alternative is not available for a certain variable. Additional usage examples for the `wide_to_long` function are available in xlogit's documentation at https://xlogit.readthedocs.io/en/latest/notebooks/convert_data_wide_to_long.html. Also, details about the function parameters are available at the [API reference ](https://xlogit.readthedocs.io/en/latest/api/utils.html#xlogit.utils.wide_to_long).

# %%
from jaxlogit.utils import wide_to_long

df = wide_to_long(df_wide, id_col='custom_id', alt_name='alt', sep='_',
                  alt_list=['TRAIN', 'SM', 'CAR'], empty_val=0,
                  varying=['TT', 'CO', 'HE', 'AV', 'SEATS'], alt_is_prefix=True)
df
# Out:
#        custom_id    alt   TT   CO   HE  AV  SEATS  GROUP  SURVEY  SP  ...  \
# 0              0  TRAIN  112   48  120   1      0      2       0   1  ...
# 1              0     SM   63   52   20   1      0      2       0   1  ...
# 2              0    CAR  117   65    0   1      0      2       0   1  ...
# 3              1  TRAIN  103   48   30   1      0      2       0   1  ...
# 4              1     SM   60   49   10   1      0      2       0   1  ...
# ...          ...    ...  ...  ...  ...  ..    ...    ...     ...  ..  ...
# 20299       6766     SM   53   17   30   1      0      3       1   1  ...
# 20300       6766    CAR   80  104    0   1      0      3       1   1  ...
# 20301       6767  TRAIN  108   13   60   1      0      3       1   1  ...
# 20302       6767     SM   53   21   30   1      0      3       1   1  ...
# 20303       6767    CAR  100   80    0   1      0      3       1   1  ...
#
#        TICKET  WHO  LUGGAGE  AGE  MALE  INCOME  GA  ORIGIN  DEST  CHOICE
# 0           1    1        0    3     0       2   0       2     1      SM
# 1           1    1        0    3     0       2   0       2     1      SM
# 2           1    1        0    3     0       2   0       2     1      SM
# 3           1    1        0    3     0       2   0       2     1      SM
# 4           1    1        0    3     0       2   0       2     1      SM
# ...       ...  ...      ...  ...   ...     ...  ..     ...   ...     ...
# 20299       7    3        1    5     1       2   0       1     2   TRAIN
# 20300       7    3        1    5     1       2   0       1     2   TRAIN
# 20301       7    3        1    5     1       2   0       1     2   TRAIN
# 20302       7    3        1    5     1       2   0       1     2   TRAIN
# 20303       7    3        1    5     1       2   0       1     2   TRAIN
#
# [20304 rows x 23 columns]

# %% [markdown]
# ### Create model specification

# %% [markdown]
# Following the reshaping, users can create or update the dataset's columns in order to accommodate their model specification needs, if necessary. The code below shows how the columns `ASC_TRAIN` and `ASC_CAR` were created to incorporate alternative-specific constants in the model. In addition, the example illustrates an effective way of establishing variable interactions (e.g., trip costs for commuters with an annual pass) by updating existing columns conditional on values of other columns. Although apparently simple, column operations provide users with an intuitive and highly-flexible mechanism to incorporate model specification aspects, such as variable transformations, interactions, and alternative specific coefficients and constants. By operating the dataframe columns, any utility specification can be accommodated in `xlogit`. As shown in [this specification example](https://xlogit.readthedocs.io/en/latest/notebooks/multinomial_model.html#Create-model-specification), highly-flexible utility specifications can be modeled in `xlogit` by operating the dataframe columns.

# %%
df['ASC_TRAIN'] = np.ones(len(df))*(df['alt'] == 'TRAIN')
df['ASC_CAR'] = np.ones(len(df))*(df['alt'] == 'CAR')
df['TT'], df['CO'] = df['TT']/100, df['CO']/100  # Scale variables
annual_pass = (df['GA'] == 1) & (df['alt'].isin(['TRAIN', 'SM']))
df.loc[annual_pass, 'CO'] = 0  # Cost zero for pass holders

# %% [markdown]
# ### Estimate model parameters

# %% [markdown]
# The `fit` method estimates the model by taking as input the data from the previous step along with additional specification criteria, such as the distribution of the random parameters (`randvars`), the number of random draws (`n_draws`), and the availability of alternatives for the choice situations (`avail`). We set the optimization method as `L-BFGS-B` as this is a robust routine that usually helps solve convergence issues.  Once the estimation routine is completed, the `summary` method can be used to display the estimation results.

# %%
varnames=['ASC_CAR', 'ASC_TRAIN', 'CO', 'TT']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['CHOICE'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['custom_id'],
    avail=df['AV'],
    panels=df["ID"],
    randvars={'TT': 'n'},
    n_draws=1500,
)
model.summary()
# Out:
# 2025-07-04 13:50:24,777 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1500 random draws for each random variable and observation.
# INFO:2025-07-04 13:50:24,904:jax._src.xla_bridge:752: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 13:50:24,904 INFO jax._src.xla_bridge: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-07-04 13:50:27,044 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:50:27,548 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 7309.54
# 2025-07-04 13:50:27,551 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:50:28,349 INFO jaxlogit._optimize: Iter 1, fun = 5509.545, |grad| = 1054.174
# 2025-07-04 13:50:28,812 INFO jaxlogit._optimize: Iter 2, fun = 4969.103, |grad| = 571.378
# 2025-07-04 13:50:29,248 INFO jaxlogit._optimize: Iter 3, fun = 4611.336, |grad| = 275.850
# 2025-07-04 13:50:29,698 INFO jaxlogit._optimize: Iter 4, fun = 4470.256, |grad| = 221.282
# 2025-07-04 13:50:30,132 INFO jaxlogit._optimize: Iter 5, fun = 4395.300, |grad| = 63.354
# 2025-07-04 13:50:30,603 INFO jaxlogit._optimize: Iter 6, fun = 4380.971, |grad| = 54.077
# 2025-07-04 13:50:31,077 INFO jaxlogit._optimize: Iter 7, fun = 4366.435, |grad| = 40.186
# 2025-07-04 13:50:31,532 INFO jaxlogit._optimize: Iter 8, fun = 4360.871, |grad| = 13.210
# 2025-07-04 13:50:31,979 INFO jaxlogit._optimize: Iter 9, fun = 4360.011, |grad| = 10.823
# 2025-07-04 13:50:32,449 INFO jaxlogit._optimize: Iter 10, fun = 4359.481, |grad| = 6.401
# 2025-07-04 13:50:32,900 INFO jaxlogit._optimize: Iter 11, fun = 4359.251, |grad| = 2.223
# 2025-07-04 13:50:33,407 INFO jaxlogit._optimize: Iter 12, fun = 4359.224, |grad| = 1.269
# 2025-07-04 13:50:33,880 INFO jaxlogit._optimize: Iter 13, fun = 4359.219, |grad| = 0.360
# 2025-07-04 13:50:34,368 INFO jaxlogit._optimize: Iter 14, fun = 4359.218, |grad| = 0.078
# 2025-07-04 13:50:34,845 INFO jaxlogit._optimize: Iter 15, fun = 4359.218, |grad| = 0.018
# 2025-07-04 13:50:35,301 INFO jaxlogit._optimize: Iter 16, fun = 4359.218, |grad| = 0.002
# 2025-07-04 13:50:35,303 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -4359.22
# 2025-07-04 13:50:35,304 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:50:38,034 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:50:43,267 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:50:43,418 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 16
#     Function evaluations: 17
# Estimation time= 18.6 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# ASC_CAR                 0.2831119     0.0560481     5.0512331       4.5e-07 ***
# ASC_TRAIN              -0.5722801     0.0794782    -7.2004683      6.65e-13 ***
# CO                     -1.6601727     0.0778872   -21.3151023      1.26e-97 ***
# TT                     -3.2289922     0.1749822   -18.4532610      3.17e-74 ***
# sd.TT                   3.6485578     0.1683478    21.6727368     9.28e-101 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -4359.218
# AIC= 8728.436
# BIC= 8762.536

# %% [markdown]
# The negative signs for the cost and time coefficients suggest that decision makers experience a general disutility with alternatives that have higher waiting times and costs, which conforms to the underlying decision making theory. Note that these estimates are highly consistent with those returned by Biogeme (https://biogeme.epfl.ch/examples/swissmetro/05normalMixtureIntegral.html)

# %% [markdown]
# ## Electricity Dataset

# %% [markdown]
# The electricity dataset contains 4,308 choices among four electricity suppliers based on the attributes of the offered plans, which include prices(pf), contract lengths(cl), time of day rates (tod), seasonal rates(seas), as well as attributes of the suppliers, which include whether the supplier is local (loc) and well-known (wk). The data was collected through a survey where 12 different choice situations were presented to each participant. The multiple responses per participants were organized into panels. Given that some participants answered less than 12 of the choice situations, some panels are unbalanced, which `xlogit` is able to handle. [Revelt and Train (1999)](https://escholarship.org/content/qt1900p96t/qt1900p96t.pdf) provide a detailed description of this dataset.

# %% [markdown]
# ### Read data

# %% [markdown]
# The dataset is already in long format so no reshaping is necessary, it can be used directly in xlogit.

# %%
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/electricity_long.csv")
df
# Out:
#        choice   id  alt  pf  cl  loc  wk  tod  seas  chid
# 0           0    1    1   7   5    0   1    0     0     1
# 1           0    1    2   9   1    1   0    0     0     1
# 2           0    1    3   0   0    0   0    0     1     1
# 3           1    1    4   0   5    0   1    1     0     1
# 4           0    1    1   7   0    0   1    0     0     2
# ...       ...  ...  ...  ..  ..  ...  ..  ...   ...   ...
# 17227       0  361    4   0   1    1   0    0     1  4307
# 17228       1  361    1   9   0    0   1    0     0  4308
# 17229       0  361    2   7   0    0   0    0     0  4308
# 17230       0  361    3   0   1    0   1    0     1  4308
# 17231       0  361    4   0   5    1   0    1     0  4308
#
# [17232 rows x 10 columns]

# %% [markdown]
# ### Fit the model

# %% [markdown]
# Note that the parameter `panels` was included in the `fit` function in order to take into account panel structure of this dataset during estimation.

# %%
varnames = ['pf', 'cl', 'loc', 'wk', 'tod', 'seas']
model = MixedLogit()
res = model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    ids=df['chid'],
    panels=df['id'],
    alts=df['alt'],
    n_draws=600,
    randvars={'pf': 'n', 'cl': 'n', 'loc': 'n', 'wk': 'n', 'tod': 'n', 'seas': 'n'}
)
model.summary()
# Out:
# 2025-07-04 13:50:52,804 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 600 random draws for each random variable and observation.
# 2025-07-04 13:50:55,024 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:50:55,505 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 5620.08
# 2025-07-04 13:50:55,507 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:50:56,291 INFO jaxlogit._optimize: Iter 1, fun = 5377.286, |grad| = 814.514
# 2025-07-04 13:50:56,653 INFO jaxlogit._optimize: Iter 2, fun = 5324.697, |grad| = 662.525
# 2025-07-04 13:50:57,193 INFO jaxlogit._optimize: Iter 3, fun = 5279.961, |grad| = 523.178
# 2025-07-04 13:50:57,534 INFO jaxlogit._optimize: Iter 4, fun = 5206.861, |grad| = 3507.556
# 2025-07-04 13:50:57,890 INFO jaxlogit._optimize: Iter 5, fun = 5043.345, |grad| = 873.688
# 2025-07-04 13:50:58,226 INFO jaxlogit._optimize: Iter 6, fun = 4945.232, |grad| = 933.875
# 2025-07-04 13:50:58,579 INFO jaxlogit._optimize: Iter 7, fun = 4766.712, |grad| = 465.620
# 2025-07-04 13:50:58,965 INFO jaxlogit._optimize: Iter 8, fun = 4703.285, |grad| = 467.420
# 2025-07-04 13:50:59,347 INFO jaxlogit._optimize: Iter 9, fun = 4648.685, |grad| = 555.690
# 2025-07-04 13:50:59,718 INFO jaxlogit._optimize: Iter 10, fun = 4598.187, |grad| = 456.432
# 2025-07-04 13:51:00,064 INFO jaxlogit._optimize: Iter 11, fun = 4548.417, |grad| = 685.122
# 2025-07-04 13:51:00,438 INFO jaxlogit._optimize: Iter 12, fun = 4509.383, |grad| = 322.061
# 2025-07-04 13:51:00,819 INFO jaxlogit._optimize: Iter 13, fun = 4469.256, |grad| = 136.427
# 2025-07-04 13:51:01,190 INFO jaxlogit._optimize: Iter 14, fun = 4437.989, |grad| = 191.167
# 2025-07-04 13:51:01,557 INFO jaxlogit._optimize: Iter 15, fun = 4338.253, |grad| = 270.984
# 2025-07-04 13:51:01,947 INFO jaxlogit._optimize: Iter 16, fun = 4309.865, |grad| = 456.010
# 2025-07-04 13:51:02,348 INFO jaxlogit._optimize: Iter 17, fun = 4260.679, |grad| = 301.595
# 2025-07-04 13:51:02,707 INFO jaxlogit._optimize: Iter 18, fun = 4239.053, |grad| = 276.427
# 2025-07-04 13:51:03,084 INFO jaxlogit._optimize: Iter 19, fun = 4221.387, |grad| = 121.380
# 2025-07-04 13:51:03,464 INFO jaxlogit._optimize: Iter 20, fun = 4212.505, |grad| = 114.899
# 2025-07-04 13:51:03,822 INFO jaxlogit._optimize: Iter 21, fun = 4171.085, |grad| = 183.024
# 2025-07-04 13:51:04,197 INFO jaxlogit._optimize: Iter 22, fun = 4147.554, |grad| = 277.185
# 2025-07-04 13:51:04,591 INFO jaxlogit._optimize: Iter 23, fun = 4061.441, |grad| = 176.557
# 2025-07-04 13:51:05,112 INFO jaxlogit._optimize: Iter 24, fun = 4039.651, |grad| = 255.352
# 2025-07-04 13:51:05,539 INFO jaxlogit._optimize: Iter 25, fun = 4014.875, |grad| = 144.733
# 2025-07-04 13:51:05,909 INFO jaxlogit._optimize: Iter 26, fun = 4006.659, |grad| = 93.243
# 2025-07-04 13:51:06,272 INFO jaxlogit._optimize: Iter 27, fun = 4001.954, |grad| = 154.019
# 2025-07-04 13:51:06,646 INFO jaxlogit._optimize: Iter 28, fun = 3997.281, |grad| = 83.051
# 2025-07-04 13:51:07,026 INFO jaxlogit._optimize: Iter 29, fun = 3990.484, |grad| = 67.465
# 2025-07-04 13:51:07,403 INFO jaxlogit._optimize: Iter 30, fun = 3984.802, |grad| = 106.685
# 2025-07-04 13:51:07,804 INFO jaxlogit._optimize: Iter 31, fun = 3978.200, |grad| = 97.267
# 2025-07-04 13:51:08,391 INFO jaxlogit._optimize: Iter 32, fun = 3972.940, |grad| = 149.331
# 2025-07-04 13:51:08,782 INFO jaxlogit._optimize: Iter 33, fun = 3959.484, |grad| = 102.357
# 2025-07-04 13:51:09,326 INFO jaxlogit._optimize: Iter 34, fun = 3949.553, |grad| = 90.873
# 2025-07-04 13:51:09,733 INFO jaxlogit._optimize: Iter 35, fun = 3936.496, |grad| = 201.080
# 2025-07-04 13:51:10,131 INFO jaxlogit._optimize: Iter 36, fun = 3926.854, |grad| = 131.863
# 2025-07-04 13:51:10,488 INFO jaxlogit._optimize: Iter 37, fun = 3921.002, |grad| = 74.231
# 2025-07-04 13:51:10,868 INFO jaxlogit._optimize: Iter 38, fun = 3913.789, |grad| = 190.477
# 2025-07-04 13:51:11,244 INFO jaxlogit._optimize: Iter 39, fun = 3905.655, |grad| = 54.497
# 2025-07-04 13:51:11,618 INFO jaxlogit._optimize: Iter 40, fun = 3904.085, |grad| = 44.068
# 2025-07-04 13:51:11,998 INFO jaxlogit._optimize: Iter 41, fun = 3903.203, |grad| = 40.794
# 2025-07-04 13:51:12,401 INFO jaxlogit._optimize: Iter 42, fun = 3899.177, |grad| = 46.047
# 2025-07-04 13:51:12,776 INFO jaxlogit._optimize: Iter 43, fun = 3896.390, |grad| = 107.540
# 2025-07-04 13:51:13,125 INFO jaxlogit._optimize: Iter 44, fun = 3892.627, |grad| = 50.309
# 2025-07-04 13:51:13,505 INFO jaxlogit._optimize: Iter 45, fun = 3890.322, |grad| = 24.534
# 2025-07-04 13:51:13,856 INFO jaxlogit._optimize: Iter 46, fun = 3889.797, |grad| = 25.126
# 2025-07-04 13:51:14,220 INFO jaxlogit._optimize: Iter 47, fun = 3889.424, |grad| = 36.804
# 2025-07-04 13:51:14,600 INFO jaxlogit._optimize: Iter 48, fun = 3889.011, |grad| = 18.120
# 2025-07-04 13:51:14,973 INFO jaxlogit._optimize: Iter 49, fun = 3888.633, |grad| = 11.914
# 2025-07-04 13:51:15,341 INFO jaxlogit._optimize: Iter 50, fun = 3888.540, |grad| = 15.191
# 2025-07-04 13:51:15,709 INFO jaxlogit._optimize: Iter 51, fun = 3888.503, |grad| = 8.172
# 2025-07-04 13:51:16,092 INFO jaxlogit._optimize: Iter 52, fun = 3888.491, |grad| = 1.978
# 2025-07-04 13:51:16,484 INFO jaxlogit._optimize: Iter 53, fun = 3888.490, |grad| = 1.474
# 2025-07-04 13:51:16,841 INFO jaxlogit._optimize: Iter 54, fun = 3888.487, |grad| = 2.080
# 2025-07-04 13:51:17,229 INFO jaxlogit._optimize: Iter 55, fun = 3888.484, |grad| = 2.050
# 2025-07-04 13:51:17,819 INFO jaxlogit._optimize: Iter 56, fun = 3888.481, |grad| = 3.716
# 2025-07-04 13:51:18,233 INFO jaxlogit._optimize: Iter 57, fun = 3888.474, |grad| = 1.759
# 2025-07-04 13:51:18,649 INFO jaxlogit._optimize: Iter 58, fun = 3888.472, |grad| = 1.976
# 2025-07-04 13:51:19,035 INFO jaxlogit._optimize: Iter 59, fun = 3888.471, |grad| = 2.404
# 2025-07-04 13:51:19,421 INFO jaxlogit._optimize: Iter 60, fun = 3888.470, |grad| = 1.036
# 2025-07-04 13:51:19,794 INFO jaxlogit._optimize: Iter 61, fun = 3888.469, |grad| = 0.564
# 2025-07-04 13:51:20,176 INFO jaxlogit._optimize: Iter 62, fun = 3888.468, |grad| = 0.877
# 2025-07-04 13:51:20,566 INFO jaxlogit._optimize: Iter 63, fun = 3888.467, |grad| = 0.832
# 2025-07-04 13:51:21,099 INFO jaxlogit._optimize: Iter 64, fun = 3888.467, |grad| = 1.637
# 2025-07-04 13:51:21,479 INFO jaxlogit._optimize: Iter 65, fun = 3888.466, |grad| = 0.908
# 2025-07-04 13:51:21,871 INFO jaxlogit._optimize: Iter 66, fun = 3888.466, |grad| = 0.369
# 2025-07-04 13:51:22,353 INFO jaxlogit._optimize: Iter 67, fun = 3888.466, |grad| = 0.368
# 2025-07-04 13:51:22,747 INFO jaxlogit._optimize: Iter 68, fun = 3888.465, |grad| = 0.733
# 2025-07-04 13:51:23,120 INFO jaxlogit._optimize: Iter 69, fun = 3888.465, |grad| = 0.363
# 2025-07-04 13:51:23,481 INFO jaxlogit._optimize: Iter 70, fun = 3888.465, |grad| = 0.221
# 2025-07-04 13:51:23,853 INFO jaxlogit._optimize: Iter 71, fun = 3888.465, |grad| = 0.325
# 2025-07-04 13:51:24,258 INFO jaxlogit._optimize: Iter 72, fun = 3888.465, |grad| = 0.132
# 2025-07-04 13:51:24,670 INFO jaxlogit._optimize: Iter 73, fun = 3888.465, |grad| = 0.071
# 2025-07-04 13:51:25,049 INFO jaxlogit._optimize: Iter 74, fun = 3888.465, |grad| = 0.050
# 2025-07-04 13:51:25,446 INFO jaxlogit._optimize: Iter 75, fun = 3888.465, |grad| = 0.053
# 2025-07-04 13:51:25,834 INFO jaxlogit._optimize: Iter 76, fun = 3888.465, |grad| = 0.036
# 2025-07-04 13:51:26,376 INFO jaxlogit._optimize: Iter 77, fun = 3888.465, |grad| = 0.037
# 2025-07-04 13:51:26,803 INFO jaxlogit._optimize: Iter 78, fun = 3888.465, |grad| = 0.014
# 2025-07-04 13:51:27,182 INFO jaxlogit._optimize: Iter 79, fun = 3888.465, |grad| = 0.015
# 2025-07-04 13:51:27,185 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -3888.47
# 2025-07-04 13:51:27,186 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:51:30,442 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:51:35,865 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:51:36,066 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 79
#     Function evaluations: 88
# Estimation time= 43.3 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# pf                     -0.9972195     0.0378223   -26.3659335     3.71e-142 ***
# cl                     -0.2196723     0.0255171    -8.6088317      1.02e-17 ***
# loc                     2.2902120     0.1263074    18.1320474      7.24e-71 ***
# wk                      1.6943254     0.0961493    17.6218125      3.62e-67 ***
# tod                    -9.6753001     0.3350945   -28.8733449     9.79e-168 ***
# seas                   -9.6963453     0.3246603   -29.8661224     2.68e-178 ***
# sd.pf                   0.2207239     0.0191089    11.5508563      2.04e-30 ***
# sd.cl                   0.4115687     0.0254623    16.1638189      4.21e-57 ***
# sd.loc                  1.7840564     0.1181351    15.1018314      2.98e-50 ***
# sd.wk                   1.2296080     0.0943599    13.0310473      4.24e-38 ***
# sd.tod                  2.2757668     0.1737829    13.0954611      1.88e-38 ***
# sd.seas                 1.4864533     0.1638622     9.0713610      1.75e-19 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -3888.465
# AIC= 7800.930
# BIC= 7877.349

# %% [markdown]
# ## Fishing Dataset

# %% [markdown]
# This example illustrates the estimation of a Mixed Logit model for choices of 1,182 individuals for sport fishing modes using `xlogit`. The goal is to analyze the market shares of four alternatives (i.e., beach, pier, boat, and charter) based on their cost and fish catch rate. [Cameron (2005)](http://cameron.econ.ucdavis.edu/mmabook/mma.html) provides additional details about this dataset. The following code illustrates how to use `xlogit` to estimate the model parameters.

# %% [markdown]
# ### Read data

# %% [markdown]
# The data to be analyzed can be imported to Python using any preferred method. In this example, the data in CSV format was imported using the popular `pandas` Python package. However, it is worth highlighting that `xlogit` does not depend on the `pandas` package, as `xlogit` can take any array-like structure as input. This represents an additional advantage because `xlogit` can be used with any preferred dataframe library, and not only with `pandas`.

# %%
import pandas as pd
df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/fishing_long.csv")
df
# Out:
#         id      alt  choice      income    price   catch
# 0        1    beach       0  7083.33170  157.930  0.0678
# 1        1     boat       0  7083.33170  157.930  0.2601
# 2        1  charter       1  7083.33170  182.930  0.5391
# 3        1     pier       0  7083.33170  157.930  0.0503
# 4        2    beach       0  1249.99980   15.114  0.1049
# ...    ...      ...     ...         ...      ...     ...
# 4723  1181     pier       0   416.66668   36.636  0.4522
# 4724  1182    beach       0  6250.00130  339.890  0.2537
# 4725  1182     boat       1  6250.00130  235.436  0.6817
# 4726  1182  charter       0  6250.00130  260.436  2.3014
# 4727  1182     pier       0  6250.00130  339.890  0.1498
#
# [4728 rows x 6 columns]

# %% [markdown]
# ### Fit model

# %% [markdown]
# Once the data is in the `Python` environment, `xlogit` can be used to fit the model, as shown below. The `MultinomialLogit` class is imported from `xlogit`, and its constructor is used to initialize a new model. The `fit` method estimates the model using the input data and estimation criteria provided as arguments to the method's call. The arguments of the `fit` methods are described in [`xlogit`'s documentation](https://https://xlogit.readthedocs.io/en/latest/api/).

# %%
varnames = ['price', 'catch']
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['id'],
    n_draws=1000,
    randvars={'price': 'n', 'catch': 'n'},
)
model.summary()
# Out:
# 2025-07-04 13:51:36,347 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 1000 random draws for each random variable and observation.
# 2025-07-04 13:51:38,691 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:51:39,062 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 2586.70
# 2025-07-04 13:51:39,064 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:51:39,215 INFO jaxlogit._optimize: Iter 1, fun = 2261.519, |grad| = 509.074
# 2025-07-04 13:51:39,307 INFO jaxlogit._optimize: Iter 2, fun = 2246.481, |grad| = 455.966
# 2025-07-04 13:51:39,402 INFO jaxlogit._optimize: Iter 3, fun = 2119.608, |grad| = 531.081
# 2025-07-04 13:51:39,542 INFO jaxlogit._optimize: Iter 4, fun = 2086.043, |grad| = 710.226
# 2025-07-04 13:51:39,680 INFO jaxlogit._optimize: Iter 5, fun = 2043.830, |grad| = 954.897
# 2025-07-04 13:51:39,988 INFO jaxlogit._optimize: Iter 6, fun = 1983.488, |grad| = 1417.137
# 2025-07-04 13:51:40,161 INFO jaxlogit._optimize: Iter 7, fun = 1941.343, |grad| = 1911.362
# 2025-07-04 13:51:40,334 INFO jaxlogit._optimize: Iter 8, fun = 1880.600, |grad| = 3356.657
# 2025-07-04 13:51:40,525 INFO jaxlogit._optimize: Iter 9, fun = 1832.538, |grad| = 5244.062
# 2025-07-04 13:51:40,694 INFO jaxlogit._optimize: Iter 10, fun = 1608.852, |grad| = 9037.569
# 2025-07-04 13:51:40,818 INFO jaxlogit._optimize: Iter 11, fun = 1531.200, |grad| = 3541.833
# 2025-07-04 13:51:41,033 INFO jaxlogit._optimize: Iter 12, fun = 1393.306, |grad| = 2775.277
# 2025-07-04 13:51:41,288 INFO jaxlogit._optimize: Iter 13, fun = 1378.765, |grad| = 2650.595
# 2025-07-04 13:51:41,576 INFO jaxlogit._optimize: Iter 14, fun = 1324.776, |grad| = 1791.588
# 2025-07-04 13:51:41,729 INFO jaxlogit._optimize: Iter 15, fun = 1323.715, |grad| = 1883.221
# 2025-07-04 13:51:41,852 INFO jaxlogit._optimize: Iter 16, fun = 1317.008, |grad| = 1623.018
# 2025-07-04 13:51:41,961 INFO jaxlogit._optimize: Iter 17, fun = 1313.090, |grad| = 822.774
# 2025-07-04 13:51:42,078 INFO jaxlogit._optimize: Iter 18, fun = 1312.312, |grad| = 228.459
# 2025-07-04 13:51:42,191 INFO jaxlogit._optimize: Iter 19, fun = 1312.270, |grad| = 52.024
# 2025-07-04 13:51:42,302 INFO jaxlogit._optimize: Iter 20, fun = 1312.265, |grad| = 45.882
# 2025-07-04 13:51:42,426 INFO jaxlogit._optimize: Iter 21, fun = 1312.253, |grad| = 85.611
# 2025-07-04 13:51:42,533 INFO jaxlogit._optimize: Iter 22, fun = 1312.221, |grad| = 178.787
# 2025-07-04 13:51:42,646 INFO jaxlogit._optimize: Iter 23, fun = 1312.139, |grad| = 338.338
# 2025-07-04 13:51:42,783 INFO jaxlogit._optimize: Iter 24, fun = 1311.928, |grad| = 588.932
# 2025-07-04 13:51:42,969 INFO jaxlogit._optimize: Iter 25, fun = 1311.413, |grad| = 947.003
# 2025-07-04 13:51:43,113 INFO jaxlogit._optimize: Iter 26, fun = 1310.312, |grad| = 1328.099
# 2025-07-04 13:51:43,231 INFO jaxlogit._optimize: Iter 27, fun = 1308.639, |grad| = 1303.694
# 2025-07-04 13:51:43,445 INFO jaxlogit._optimize: Iter 28, fun = 1308.613, |grad| = 1424.691
# 2025-07-04 13:51:43,552 INFO jaxlogit._optimize: Iter 29, fun = 1307.293, |grad| = 850.545
# 2025-07-04 13:51:43,678 INFO jaxlogit._optimize: Iter 30, fun = 1306.796, |grad| = 267.047
# 2025-07-04 13:51:43,796 INFO jaxlogit._optimize: Iter 31, fun = 1306.722, |grad| = 32.837
# 2025-07-04 13:51:43,917 INFO jaxlogit._optimize: Iter 32, fun = 1306.719, |grad| = 3.662
# 2025-07-04 13:51:44,032 INFO jaxlogit._optimize: Iter 33, fun = 1306.719, |grad| = 3.631
# 2025-07-04 13:51:44,182 INFO jaxlogit._optimize: Iter 34, fun = 1306.677, |grad| = 77.642
# 2025-07-04 13:51:44,323 INFO jaxlogit._optimize: Iter 35, fun = 1306.380, |grad| = 357.894
# 2025-07-04 13:51:44,489 INFO jaxlogit._optimize: Iter 36, fun = 1305.710, |grad| = 941.197
# 2025-07-04 13:51:44,607 INFO jaxlogit._optimize: Iter 37, fun = 1305.093, |grad| = 1120.996
# 2025-07-04 13:51:44,725 INFO jaxlogit._optimize: Iter 38, fun = 1302.868, |grad| = 1262.137
# 2025-07-04 13:51:44,893 INFO jaxlogit._optimize: Iter 39, fun = 1302.677, |grad| = 907.562
# 2025-07-04 13:51:45,015 INFO jaxlogit._optimize: Iter 40, fun = 1301.212, |grad| = 516.536
# 2025-07-04 13:51:45,119 INFO jaxlogit._optimize: Iter 41, fun = 1300.551, |grad| = 117.957
# 2025-07-04 13:51:45,224 INFO jaxlogit._optimize: Iter 42, fun = 1300.526, |grad| = 8.402
# 2025-07-04 13:51:45,334 INFO jaxlogit._optimize: Iter 43, fun = 1300.524, |grad| = 2.315
# 2025-07-04 13:51:45,447 INFO jaxlogit._optimize: Iter 44, fun = 1300.523, |grad| = 0.071
# 2025-07-04 13:51:45,583 INFO jaxlogit._optimize: Iter 45, fun = 1300.523, |grad| = 0.010
# 2025-07-04 13:51:45,585 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1300.52
# 2025-07-04 13:51:45,586 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:51:46,620 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:51:49,324 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:51:49,520 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 45
#     Function evaluations: 75
# Estimation time= 13.2 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# price                  -0.0272469     0.0022842   -11.9283006      4.71e-31 ***
# catch                   1.3260435     0.1738918     7.6256804      4.97e-14 ***
# sd.price                0.0102261     0.0021414     4.7753244      2.02e-06 ***
# sd.catch                1.5661726     0.3755141     4.1707420      3.26e-05 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1300.523
# AIC= 2609.046
# BIC= 2629.346

# %% [markdown]
# ## Car Dataset

# %% [markdown]
# The fourth example uses a stated preference panel dataset for choice of car. Three alternatives are considered, with upto 6 choice situations per individual. This again is an unbalanced panel with responses of some individuals less than 6 situations. The dataset contains 8 explanaotry variables: price, operating cost, range, and binary indicators to indicate whether the car is electric, hybrid, and if performance is high or medium respectively. This dataset was taken from Kenneth Train's MATLAB codes for estimation of Mixed Logit models as shown in this link: https://eml.berkeley.edu/Software/abstracts/train1006mxlmsl.html

# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.github.com/arteagac/xlogit/master/examples/data/car100_long.csv")

# %% [markdown]
# Since price and operating cost need to be estimated with negative coefficients, we reverse the variable signs in the dataframe.

# %%
df['price'] = -df['price']/10000
df['opcost'] = -df['opcost']
df
# Out:
#       person_id  choice_id  alt  choice   price  opcost  range  ev  gas  \
# 0             1          1    1       0 -4.6763  -47.43    0.0   0    0
# 1             1          1    2       1 -5.7209  -27.43    1.3   1    0
# 2             1          1    3       0 -8.7960  -32.41    1.2   1    0
# 3             1          2    1       1 -3.3768   -4.89    1.3   1    0
# 4             1          2    2       0 -9.0336  -30.19    0.0   0    0
# ...         ...        ...  ...     ...     ...     ...    ...  ..  ...
# 4447        100       1483    2       0 -2.8036  -14.45    1.6   1    0
# 4448        100       1483    3       0 -1.9360  -54.76    0.0   0    1
# 4449        100       1484    1       1 -2.4054  -50.57    0.0   0    1
# 4450        100       1484    2       0 -5.2795  -21.25    0.0   0    0
# 4451        100       1484    3       0 -6.0705  -25.41    1.4   1    0
#
#       hybrid  hiperf  medhiperf
# 0          1       0          0
# 1          0       1          1
# 2          0       0          1
# 3          0       1          1
# 4          1       0          1
# ...      ...     ...        ...
# 4447       0       0          0
# 4448       0       1          1
# 4449       0       0          0
# 4450       1       0          1
# 4451       0       0          0
#
# [4452 rows x 12 columns]

# %% [markdown]
# ### Fit the model

# %%
varnames = ['hiperf', 'medhiperf', 'price', 'opcost', 'range', 'ev', 'hybrid'] 
model = MixedLogit()
model.fit(
    X=df[varnames],
    y=df['choice'],
    varnames=varnames,
    alts=df['alt'],
    ids=df['choice_id'],
    panels=df['person_id'],
    randvars = {'price': 'ln', 'opcost': 'n',  'range': 'ln', 'ev':'n', 'hybrid': 'n'}, 
    n_draws = 100,
) 
model.summary()
# Out:
# 2025-07-04 13:51:49,793 INFO jaxlogit.mixed_logit: Starting data preparation, including generation of 100 random draws for each random variable and observation.
# 2025-07-04 13:51:52,215 INFO jaxlogit.mixed_logit: Compiling log-likelihood function.
# 2025-07-04 13:51:53,057 INFO jaxlogit.mixed_logit: Compilation finished, init neg_loglike = 1944.17
# 2025-07-04 13:51:53,058 INFO jaxlogit._optimize: Running minimization with method L-BFGS-B
# 2025-07-04 13:51:53,105 INFO jaxlogit._optimize: Iter 1, fun = 1875.113, |grad| = 746.045
# 2025-07-04 13:51:53,151 INFO jaxlogit._optimize: Iter 2, fun = 1870.203, |grad| = 572.564
# 2025-07-04 13:51:53,182 INFO jaxlogit._optimize: Iter 3, fun = 1870.091, |grad| = 1427.395
# 2025-07-04 13:51:53,216 INFO jaxlogit._optimize: Iter 4, fun = 1858.951, |grad| = 1015.272
# 2025-07-04 13:51:53,248 INFO jaxlogit._optimize: Iter 5, fun = 1845.192, |grad| = 787.144
# 2025-07-04 13:51:53,289 INFO jaxlogit._optimize: Iter 6, fun = 1828.246, |grad| = 686.696
# 2025-07-04 13:51:53,320 INFO jaxlogit._optimize: Iter 7, fun = 1765.698, |grad| = 349.168
# 2025-07-04 13:51:53,353 INFO jaxlogit._optimize: Iter 8, fun = 1750.545, |grad| = 290.529
# 2025-07-04 13:51:53,390 INFO jaxlogit._optimize: Iter 9, fun = 1688.037, |grad| = 486.600
# 2025-07-04 13:51:53,469 INFO jaxlogit._optimize: Iter 10, fun = 1536.297, |grad| = 5767.616
# 2025-07-04 13:51:53,529 INFO jaxlogit._optimize: Iter 11, fun = 1519.389, |grad| = 2086.680
# 2025-07-04 13:51:53,647 INFO jaxlogit._optimize: Iter 12, fun = 1345.582, |grad| = 1490.449
# 2025-07-04 13:51:53,726 INFO jaxlogit._optimize: Iter 13, fun = 1344.272, |grad| = 1548.210
# 2025-07-04 13:51:53,775 INFO jaxlogit._optimize: Iter 14, fun = 1332.073, |grad| = 607.485
# 2025-07-04 13:51:53,832 INFO jaxlogit._optimize: Iter 15, fun = 1329.323, |grad| = 200.864
# 2025-07-04 13:51:53,886 INFO jaxlogit._optimize: Iter 16, fun = 1328.694, |grad| = 73.737
# 2025-07-04 13:51:53,939 INFO jaxlogit._optimize: Iter 17, fun = 1328.333, |grad| = 97.884
# 2025-07-04 13:51:53,980 INFO jaxlogit._optimize: Iter 18, fun = 1328.024, |grad| = 143.222
# 2025-07-04 13:51:54,028 INFO jaxlogit._optimize: Iter 19, fun = 1327.304, |grad| = 198.948
# 2025-07-04 13:51:54,075 INFO jaxlogit._optimize: Iter 20, fun = 1325.669, |grad| = 245.443
# 2025-07-04 13:51:54,123 INFO jaxlogit._optimize: Iter 21, fun = 1322.376, |grad| = 252.877
# 2025-07-04 13:51:54,201 INFO jaxlogit._optimize: Iter 22, fun = 1321.906, |grad| = 330.292
# 2025-07-04 13:51:54,254 INFO jaxlogit._optimize: Iter 23, fun = 1317.988, |grad| = 235.283
# 2025-07-04 13:51:54,297 INFO jaxlogit._optimize: Iter 24, fun = 1316.789, |grad| = 424.524
# 2025-07-04 13:51:54,345 INFO jaxlogit._optimize: Iter 25, fun = 1314.731, |grad| = 38.951
# 2025-07-04 13:51:54,388 INFO jaxlogit._optimize: Iter 26, fun = 1314.508, |grad| = 42.826
# 2025-07-04 13:51:54,431 INFO jaxlogit._optimize: Iter 27, fun = 1313.254, |grad| = 166.722
# 2025-07-04 13:51:54,491 INFO jaxlogit._optimize: Iter 28, fun = 1312.400, |grad| = 121.750
# 2025-07-04 13:51:54,550 INFO jaxlogit._optimize: Iter 29, fun = 1310.487, |grad| = 72.741
# 2025-07-04 13:51:54,632 INFO jaxlogit._optimize: Iter 30, fun = 1307.755, |grad| = 87.325
# 2025-07-04 13:51:54,687 INFO jaxlogit._optimize: Iter 31, fun = 1305.308, |grad| = 77.136
# 2025-07-04 13:51:54,745 INFO jaxlogit._optimize: Iter 32, fun = 1304.345, |grad| = 49.357
# 2025-07-04 13:51:54,806 INFO jaxlogit._optimize: Iter 33, fun = 1303.735, |grad| = 43.633
# 2025-07-04 13:51:54,879 INFO jaxlogit._optimize: Iter 34, fun = 1303.528, |grad| = 42.959
# 2025-07-04 13:51:54,924 INFO jaxlogit._optimize: Iter 35, fun = 1303.370, |grad| = 37.900
# 2025-07-04 13:51:54,990 INFO jaxlogit._optimize: Iter 36, fun = 1303.202, |grad| = 104.904
# 2025-07-04 13:51:55,031 INFO jaxlogit._optimize: Iter 37, fun = 1302.888, |grad| = 77.965
# 2025-07-04 13:51:55,078 INFO jaxlogit._optimize: Iter 38, fun = 1302.097, |grad| = 56.825
# 2025-07-04 13:51:55,117 INFO jaxlogit._optimize: Iter 39, fun = 1301.045, |grad| = 53.610
# 2025-07-04 13:51:55,176 INFO jaxlogit._optimize: Iter 40, fun = 1300.848, |grad| = 131.528
# 2025-07-04 13:51:55,223 INFO jaxlogit._optimize: Iter 41, fun = 1300.185, |grad| = 77.657
# 2025-07-04 13:51:55,265 INFO jaxlogit._optimize: Iter 42, fun = 1299.806, |grad| = 15.240
# 2025-07-04 13:51:55,304 INFO jaxlogit._optimize: Iter 43, fun = 1299.733, |grad| = 15.602
# 2025-07-04 13:51:55,349 INFO jaxlogit._optimize: Iter 44, fun = 1299.533, |grad| = 19.740
# 2025-07-04 13:51:55,413 INFO jaxlogit._optimize: Iter 45, fun = 1299.457, |grad| = 38.135
# 2025-07-04 13:51:55,460 INFO jaxlogit._optimize: Iter 46, fun = 1299.271, |grad| = 36.738
# 2025-07-04 13:51:55,536 INFO jaxlogit._optimize: Iter 47, fun = 1299.209, |grad| = 62.664
# 2025-07-04 13:51:55,588 INFO jaxlogit._optimize: Iter 48, fun = 1298.770, |grad| = 59.541
# 2025-07-04 13:51:55,652 INFO jaxlogit._optimize: Iter 49, fun = 1298.728, |grad| = 46.053
# 2025-07-04 13:51:55,721 INFO jaxlogit._optimize: Iter 50, fun = 1298.210, |grad| = 20.915
# 2025-07-04 13:51:55,781 INFO jaxlogit._optimize: Iter 51, fun = 1298.117, |grad| = 37.328
# 2025-07-04 13:51:55,839 INFO jaxlogit._optimize: Iter 52, fun = 1297.977, |grad| = 10.464
# 2025-07-04 13:51:55,919 INFO jaxlogit._optimize: Iter 53, fun = 1297.941, |grad| = 47.866
# 2025-07-04 13:51:55,977 INFO jaxlogit._optimize: Iter 54, fun = 1297.891, |grad| = 14.573
# 2025-07-04 13:51:56,035 INFO jaxlogit._optimize: Iter 55, fun = 1297.877, |grad| = 12.716
# 2025-07-04 13:51:56,084 INFO jaxlogit._optimize: Iter 56, fun = 1297.865, |grad| = 18.662
# 2025-07-04 13:51:56,136 INFO jaxlogit._optimize: Iter 57, fun = 1297.841, |grad| = 29.927
# 2025-07-04 13:51:56,215 INFO jaxlogit._optimize: Iter 58, fun = 1297.805, |grad| = 34.728
# 2025-07-04 13:51:56,279 INFO jaxlogit._optimize: Iter 59, fun = 1297.788, |grad| = 58.630
# 2025-07-04 13:51:56,351 INFO jaxlogit._optimize: Iter 60, fun = 1297.735, |grad| = 10.081
# 2025-07-04 13:51:56,417 INFO jaxlogit._optimize: Iter 61, fun = 1297.719, |grad| = 10.360
# 2025-07-04 13:51:56,467 INFO jaxlogit._optimize: Iter 62, fun = 1297.704, |grad| = 23.710
# 2025-07-04 13:51:56,519 INFO jaxlogit._optimize: Iter 63, fun = 1297.696, |grad| = 25.098
# 2025-07-04 13:51:56,577 INFO jaxlogit._optimize: Iter 64, fun = 1297.677, |grad| = 27.055
# 2025-07-04 13:51:56,645 INFO jaxlogit._optimize: Iter 65, fun = 1297.669, |grad| = 7.763
# 2025-07-04 13:51:56,692 INFO jaxlogit._optimize: Iter 66, fun = 1297.660, |grad| = 9.375
# 2025-07-04 13:51:56,738 INFO jaxlogit._optimize: Iter 67, fun = 1297.646, |grad| = 6.936
# 2025-07-04 13:51:56,785 INFO jaxlogit._optimize: Iter 68, fun = 1297.636, |grad| = 12.744
# 2025-07-04 13:51:56,834 INFO jaxlogit._optimize: Iter 69, fun = 1297.617, |grad| = 11.051
# 2025-07-04 13:51:56,887 INFO jaxlogit._optimize: Iter 70, fun = 1297.585, |grad| = 14.911
# 2025-07-04 13:51:56,953 INFO jaxlogit._optimize: Iter 71, fun = 1297.558, |grad| = 47.540
# 2025-07-04 13:51:56,995 INFO jaxlogit._optimize: Iter 72, fun = 1297.488, |grad| = 19.204
# 2025-07-04 13:51:57,035 INFO jaxlogit._optimize: Iter 73, fun = 1297.432, |grad| = 18.249
# 2025-07-04 13:51:57,080 INFO jaxlogit._optimize: Iter 74, fun = 1297.363, |grad| = 21.898
# 2025-07-04 13:51:57,127 INFO jaxlogit._optimize: Iter 75, fun = 1297.319, |grad| = 23.072
# 2025-07-04 13:51:57,191 INFO jaxlogit._optimize: Iter 76, fun = 1297.316, |grad| = 29.225
# 2025-07-04 13:51:57,234 INFO jaxlogit._optimize: Iter 77, fun = 1297.246, |grad| = 25.406
# 2025-07-04 13:51:57,309 INFO jaxlogit._optimize: Iter 78, fun = 1297.228, |grad| = 14.736
# 2025-07-04 13:51:57,371 INFO jaxlogit._optimize: Iter 79, fun = 1297.187, |grad| = 4.348
# 2025-07-04 13:51:57,429 INFO jaxlogit._optimize: Iter 80, fun = 1297.159, |grad| = 14.970
# 2025-07-04 13:51:57,474 INFO jaxlogit._optimize: Iter 81, fun = 1297.140, |grad| = 13.723
# 2025-07-04 13:51:57,515 INFO jaxlogit._optimize: Iter 82, fun = 1297.138, |grad| = 29.241
# 2025-07-04 13:51:57,555 INFO jaxlogit._optimize: Iter 83, fun = 1297.103, |grad| = 10.280
# 2025-07-04 13:51:57,600 INFO jaxlogit._optimize: Iter 84, fun = 1297.073, |grad| = 11.365
# 2025-07-04 13:51:57,646 INFO jaxlogit._optimize: Iter 85, fun = 1297.008, |grad| = 24.240
# 2025-07-04 13:51:57,709 INFO jaxlogit._optimize: Iter 86, fun = 1296.970, |grad| = 11.565
# 2025-07-04 13:51:57,772 INFO jaxlogit._optimize: Iter 87, fun = 1296.965, |grad| = 9.711
# 2025-07-04 13:51:57,835 INFO jaxlogit._optimize: Iter 88, fun = 1296.965, |grad| = 8.337
# 2025-07-04 13:51:57,892 INFO jaxlogit._optimize: Iter 89, fun = 1296.961, |grad| = 3.838
# 2025-07-04 13:51:57,931 INFO jaxlogit._optimize: Iter 90, fun = 1296.958, |grad| = 3.918
# 2025-07-04 13:51:57,972 INFO jaxlogit._optimize: Iter 91, fun = 1296.956, |grad| = 7.082
# 2025-07-04 13:51:58,020 INFO jaxlogit._optimize: Iter 92, fun = 1296.953, |grad| = 5.481
# 2025-07-04 13:51:58,061 INFO jaxlogit._optimize: Iter 93, fun = 1296.952, |grad| = 10.801
# 2025-07-04 13:51:58,102 INFO jaxlogit._optimize: Iter 94, fun = 1296.949, |grad| = 9.348
# 2025-07-04 13:51:58,142 INFO jaxlogit._optimize: Iter 95, fun = 1296.947, |grad| = 4.286
# 2025-07-04 13:51:58,193 INFO jaxlogit._optimize: Iter 96, fun = 1296.946, |grad| = 2.559
# 2025-07-04 13:51:58,233 INFO jaxlogit._optimize: Iter 97, fun = 1296.941, |grad| = 6.221
# 2025-07-04 13:51:58,273 INFO jaxlogit._optimize: Iter 98, fun = 1296.934, |grad| = 10.497
# 2025-07-04 13:51:58,313 INFO jaxlogit._optimize: Iter 99, fun = 1296.927, |grad| = 21.907
# 2025-07-04 13:51:58,357 INFO jaxlogit._optimize: Iter 100, fun = 1296.916, |grad| = 13.469
# 2025-07-04 13:51:58,418 INFO jaxlogit._optimize: Iter 101, fun = 1296.909, |grad| = 8.129
# 2025-07-04 13:51:58,461 INFO jaxlogit._optimize: Iter 102, fun = 1296.902, |grad| = 7.147
# 2025-07-04 13:51:58,502 INFO jaxlogit._optimize: Iter 103, fun = 1296.901, |grad| = 6.766
# 2025-07-04 13:51:58,542 INFO jaxlogit._optimize: Iter 104, fun = 1296.898, |grad| = 3.787
# 2025-07-04 13:51:58,620 INFO jaxlogit._optimize: Iter 105, fun = 1296.898, |grad| = 2.629
# 2025-07-04 13:51:58,662 INFO jaxlogit._optimize: Iter 106, fun = 1296.897, |grad| = 2.567
# 2025-07-04 13:51:58,713 INFO jaxlogit._optimize: Iter 107, fun = 1296.897, |grad| = 2.070
# 2025-07-04 13:51:58,777 INFO jaxlogit._optimize: Iter 108, fun = 1296.896, |grad| = 12.148
# 2025-07-04 13:51:58,844 INFO jaxlogit._optimize: Iter 109, fun = 1296.894, |grad| = 6.009
# 2025-07-04 13:51:58,918 INFO jaxlogit._optimize: Iter 110, fun = 1296.891, |grad| = 1.438
# 2025-07-04 13:51:58,995 INFO jaxlogit._optimize: Iter 111, fun = 1296.889, |grad| = 3.034
# 2025-07-04 13:51:59,065 INFO jaxlogit._optimize: Iter 112, fun = 1296.888, |grad| = 5.111
# 2025-07-04 13:51:59,124 INFO jaxlogit._optimize: Iter 113, fun = 1296.888, |grad| = 1.702
# 2025-07-04 13:51:59,173 INFO jaxlogit._optimize: Iter 114, fun = 1296.887, |grad| = 1.938
# 2025-07-04 13:51:59,225 INFO jaxlogit._optimize: Iter 115, fun = 1296.887, |grad| = 3.201
# 2025-07-04 13:51:59,279 INFO jaxlogit._optimize: Iter 116, fun = 1296.885, |grad| = 4.453
# 2025-07-04 13:51:59,347 INFO jaxlogit._optimize: Iter 117, fun = 1296.884, |grad| = 5.262
# 2025-07-04 13:51:59,393 INFO jaxlogit._optimize: Iter 118, fun = 1296.883, |grad| = 3.233
# 2025-07-04 13:51:59,445 INFO jaxlogit._optimize: Iter 119, fun = 1296.881, |grad| = 1.344
# 2025-07-04 13:51:59,493 INFO jaxlogit._optimize: Iter 120, fun = 1296.881, |grad| = 1.578
# 2025-07-04 13:51:59,543 INFO jaxlogit._optimize: Iter 121, fun = 1296.880, |grad| = 2.032
# 2025-07-04 13:51:59,589 INFO jaxlogit._optimize: Iter 122, fun = 1296.879, |grad| = 7.850
# 2025-07-04 13:51:59,644 INFO jaxlogit._optimize: Iter 123, fun = 1296.878, |grad| = 3.400
# 2025-07-04 13:51:59,685 INFO jaxlogit._optimize: Iter 124, fun = 1296.877, |grad| = 1.598
# 2025-07-04 13:51:59,736 INFO jaxlogit._optimize: Iter 125, fun = 1296.876, |grad| = 3.411
# 2025-07-04 13:51:59,786 INFO jaxlogit._optimize: Iter 126, fun = 1296.876, |grad| = 1.140
# 2025-07-04 13:51:59,833 INFO jaxlogit._optimize: Iter 127, fun = 1296.876, |grad| = 0.495
# 2025-07-04 13:51:59,886 INFO jaxlogit._optimize: Iter 128, fun = 1296.876, |grad| = 0.833
# 2025-07-04 13:51:59,935 INFO jaxlogit._optimize: Iter 129, fun = 1296.876, |grad| = 1.490
# 2025-07-04 13:51:59,996 INFO jaxlogit._optimize: Iter 130, fun = 1296.876, |grad| = 1.344
# 2025-07-04 13:52:00,049 INFO jaxlogit._optimize: Iter 131, fun = 1296.875, |grad| = 1.448
# 2025-07-04 13:52:00,122 INFO jaxlogit._optimize: Iter 132, fun = 1296.875, |grad| = 0.701
# 2025-07-04 13:52:00,168 INFO jaxlogit._optimize: Iter 133, fun = 1296.875, |grad| = 0.826
# 2025-07-04 13:52:00,228 INFO jaxlogit._optimize: Iter 134, fun = 1296.875, |grad| = 0.675
# 2025-07-04 13:52:00,268 INFO jaxlogit._optimize: Iter 135, fun = 1296.875, |grad| = 0.436
# 2025-07-04 13:52:00,307 INFO jaxlogit._optimize: Iter 136, fun = 1296.875, |grad| = 0.631
# 2025-07-04 13:52:00,350 INFO jaxlogit._optimize: Iter 137, fun = 1296.875, |grad| = 1.455
# 2025-07-04 13:52:00,392 INFO jaxlogit._optimize: Iter 138, fun = 1296.875, |grad| = 0.997
# 2025-07-04 13:52:00,429 INFO jaxlogit._optimize: Iter 139, fun = 1296.875, |grad| = 0.955
# 2025-07-04 13:52:00,467 INFO jaxlogit._optimize: Iter 140, fun = 1296.874, |grad| = 2.189
# 2025-07-04 13:52:00,506 INFO jaxlogit._optimize: Iter 141, fun = 1296.873, |grad| = 2.663
# 2025-07-04 13:52:00,567 INFO jaxlogit._optimize: Iter 142, fun = 1296.873, |grad| = 4.640
# 2025-07-04 13:52:00,608 INFO jaxlogit._optimize: Iter 143, fun = 1296.873, |grad| = 2.184
# 2025-07-04 13:52:00,646 INFO jaxlogit._optimize: Iter 144, fun = 1296.872, |grad| = 0.467
# 2025-07-04 13:52:00,690 INFO jaxlogit._optimize: Iter 145, fun = 1296.872, |grad| = 0.489
# 2025-07-04 13:52:00,729 INFO jaxlogit._optimize: Iter 146, fun = 1296.872, |grad| = 0.957
# 2025-07-04 13:52:00,773 INFO jaxlogit._optimize: Iter 147, fun = 1296.872, |grad| = 1.231
# 2025-07-04 13:52:00,816 INFO jaxlogit._optimize: Iter 148, fun = 1296.872, |grad| = 0.574
# 2025-07-04 13:52:00,860 INFO jaxlogit._optimize: Iter 149, fun = 1296.872, |grad| = 0.381
# 2025-07-04 13:52:00,903 INFO jaxlogit._optimize: Iter 150, fun = 1296.872, |grad| = 0.490
# 2025-07-04 13:52:00,944 INFO jaxlogit._optimize: Iter 151, fun = 1296.872, |grad| = 0.680
# 2025-07-04 13:52:00,987 INFO jaxlogit._optimize: Iter 152, fun = 1296.871, |grad| = 0.717
# 2025-07-04 13:52:01,023 INFO jaxlogit._optimize: Iter 153, fun = 1296.871, |grad| = 0.712
# 2025-07-04 13:52:01,067 INFO jaxlogit._optimize: Iter 154, fun = 1296.871, |grad| = 0.858
# 2025-07-04 13:52:01,110 INFO jaxlogit._optimize: Iter 155, fun = 1296.871, |grad| = 0.523
# 2025-07-04 13:52:01,149 INFO jaxlogit._optimize: Iter 156, fun = 1296.871, |grad| = 0.333
# 2025-07-04 13:52:01,191 INFO jaxlogit._optimize: Iter 157, fun = 1296.871, |grad| = 0.357
# 2025-07-04 13:52:01,231 INFO jaxlogit._optimize: Iter 158, fun = 1296.871, |grad| = 0.334
# 2025-07-04 13:52:01,269 INFO jaxlogit._optimize: Iter 159, fun = 1296.871, |grad| = 0.261
# 2025-07-04 13:52:01,310 INFO jaxlogit._optimize: Iter 160, fun = 1296.871, |grad| = 0.309
# 2025-07-04 13:52:01,355 INFO jaxlogit._optimize: Iter 161, fun = 1296.871, |grad| = 0.498
# 2025-07-04 13:52:01,399 INFO jaxlogit._optimize: Iter 162, fun = 1296.871, |grad| = 0.497
# 2025-07-04 13:52:01,439 INFO jaxlogit._optimize: Iter 163, fun = 1296.871, |grad| = 0.938
# 2025-07-04 13:52:01,486 INFO jaxlogit._optimize: Iter 164, fun = 1296.871, |grad| = 0.361
# 2025-07-04 13:52:01,556 INFO jaxlogit._optimize: Iter 165, fun = 1296.871, |grad| = 0.449
# 2025-07-04 13:52:01,607 INFO jaxlogit._optimize: Iter 166, fun = 1296.871, |grad| = 0.604
# 2025-07-04 13:52:01,663 INFO jaxlogit._optimize: Iter 167, fun = 1296.871, |grad| = 0.362
# 2025-07-04 13:52:01,707 INFO jaxlogit._optimize: Iter 168, fun = 1296.871, |grad| = 0.246
# 2025-07-04 13:52:01,766 INFO jaxlogit._optimize: Iter 169, fun = 1296.871, |grad| = 0.418
# 2025-07-04 13:52:01,810 INFO jaxlogit._optimize: Iter 170, fun = 1296.871, |grad| = 0.748
# 2025-07-04 13:52:01,856 INFO jaxlogit._optimize: Iter 171, fun = 1296.871, |grad| = 0.940
# 2025-07-04 13:52:01,934 INFO jaxlogit._optimize: Iter 172, fun = 1296.871, |grad| = 1.497
# 2025-07-04 13:52:01,987 INFO jaxlogit._optimize: Iter 173, fun = 1296.871, |grad| = 0.760
# 2025-07-04 13:52:02,039 INFO jaxlogit._optimize: Iter 174, fun = 1296.871, |grad| = 0.132
# 2025-07-04 13:52:02,107 INFO jaxlogit._optimize: Iter 175, fun = 1296.871, |grad| = 0.154
# 2025-07-04 13:52:02,161 INFO jaxlogit._optimize: Iter 176, fun = 1296.871, |grad| = 0.165
# 2025-07-04 13:52:02,220 INFO jaxlogit._optimize: Iter 177, fun = 1296.871, |grad| = 0.217
# 2025-07-04 13:52:02,282 INFO jaxlogit._optimize: Iter 178, fun = 1296.871, |grad| = 0.060
# 2025-07-04 13:52:02,356 INFO jaxlogit._optimize: Iter 179, fun = 1296.871, |grad| = 0.094
# 2025-07-04 13:52:02,405 INFO jaxlogit._optimize: Iter 180, fun = 1296.871, |grad| = 0.196
# 2025-07-04 13:52:02,459 INFO jaxlogit._optimize: Iter 181, fun = 1296.871, |grad| = 0.201
# 2025-07-04 13:52:02,531 INFO jaxlogit._optimize: Iter 182, fun = 1296.871, |grad| = 0.302
# 2025-07-04 13:52:02,603 INFO jaxlogit._optimize: Iter 183, fun = 1296.871, |grad| = 0.211
# 2025-07-04 13:52:02,682 INFO jaxlogit._optimize: Iter 184, fun = 1296.871, |grad| = 0.120
# 2025-07-04 13:52:02,741 INFO jaxlogit._optimize: Iter 185, fun = 1296.871, |grad| = 0.050
# 2025-07-04 13:52:02,805 INFO jaxlogit._optimize: Iter 186, fun = 1296.871, |grad| = 0.049
# 2025-07-04 13:52:02,868 INFO jaxlogit._optimize: Iter 187, fun = 1296.871, |grad| = 0.090
# 2025-07-04 13:52:02,942 INFO jaxlogit._optimize: Iter 188, fun = 1296.871, |grad| = 0.098
# 2025-07-04 13:52:03,030 INFO jaxlogit._optimize: Iter 189, fun = 1296.871, |grad| = 0.207
# 2025-07-04 13:52:03,086 INFO jaxlogit._optimize: Iter 190, fun = 1296.871, |grad| = 0.166
# 2025-07-04 13:52:03,140 INFO jaxlogit._optimize: Iter 191, fun = 1296.871, |grad| = 0.098
# 2025-07-04 13:52:03,207 INFO jaxlogit._optimize: Iter 192, fun = 1296.871, |grad| = 0.057
# 2025-07-04 13:52:03,266 INFO jaxlogit._optimize: Iter 193, fun = 1296.871, |grad| = 0.049
# 2025-07-04 13:52:03,332 INFO jaxlogit._optimize: Iter 194, fun = 1296.871, |grad| = 0.047
# 2025-07-04 13:52:03,377 INFO jaxlogit._optimize: Iter 195, fun = 1296.871, |grad| = 0.047
# 2025-07-04 13:52:03,443 INFO jaxlogit._optimize: Iter 196, fun = 1296.871, |grad| = 0.067
# 2025-07-04 13:52:03,491 INFO jaxlogit._optimize: Iter 197, fun = 1296.871, |grad| = 0.053
# 2025-07-04 13:52:03,540 INFO jaxlogit._optimize: Iter 198, fun = 1296.871, |grad| = 0.053
# 2025-07-04 13:52:03,579 INFO jaxlogit._optimize: Iter 199, fun = 1296.871, |grad| = 0.059
# 2025-07-04 13:52:03,640 INFO jaxlogit._optimize: Iter 200, fun = 1296.871, |grad| = 0.078
# 2025-07-04 13:52:03,642 INFO jaxlogit.mixed_logit: Optimization finished, success = True, final loglike = -1296.87
# 2025-07-04 13:52:03,643 INFO jaxlogit.mixed_logit: Calculating gradient of individual log-likelihood contributions
# 2025-07-04 13:52:05,383 INFO jaxlogit.mixed_logit: Calculating H_inv
# 2025-07-04 13:52:11,078 INFO jaxlogit._choice_model: Post fit processing
# 2025-07-04 13:52:11,239 INFO jaxlogit._choice_model: Optimization terminated successfully.
#     Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#     Iterations: 200
#     Function evaluations: 233
# Estimation time= 21.4 seconds
# ---------------------------------------------------------------------------
# Coefficient              Estimate      Std.Err.         z-val         P>|z|
# ---------------------------------------------------------------------------
# hiperf                  0.1096929     0.0967745     1.1334894         0.257
# medhiperf               0.5706422     0.0997384     5.7213867      1.28e-08 ***
# price                  -0.7218903     0.1377049    -5.2423009      1.81e-07 ***
# opcost                  0.0095353     0.0056277     1.6943461        0.0904 .
# range                  -0.5731345     0.4148359    -1.3815933         0.167
# ev                     -1.6026576     0.3439568    -4.6594733      3.45e-06 ***
# hybrid                  0.6863887     0.1610010     4.2632569      2.14e-05 ***
# sd.price                0.8776710     0.1124821     7.8027604      1.13e-14 ***
# sd.opcost              -0.0382526     0.0054981    -6.9573705      5.18e-12 ***
# sd.range                0.4455649     0.3340143     1.3339695         0.182
# sd.ev                   1.0328025     0.1733611     5.9575203      3.19e-09 ***
# sd.hybrid              -0.7003717     0.1628990    -4.2994224      1.82e-05 ***
# ---------------------------------------------------------------------------
# Significance:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Log-Likelihood= -1296.871
# AIC= 2617.742
# BIC= 2681.372

# %% [markdown]
# ## References

# %% [markdown]
# - Bierlaire, M. (2018). PandasBiogeme: a short introduction. EPFL (Transport and Mobility Laboratory, ENAC).
#
# - Brathwaite, T., & Walker, J. L. (2018). Asymmetric, closed-form, finite-parameter models of multinomial choice. Journal of Choice Modelling, 29, 78–112.
#
# - Cameron, A. C., & Trivedi, P. K. (2005). Microeconometrics: methods and applications. Cambridge university press.
#
# - Croissant, Y. (2020). Estimation of Random Utility Models in R: The mlogit Package. Journal of Statistical Software, 95(1), 1-41.
#
# - Revelt, D., & Train, K. (1999). Customer-specific taste parameters and mixed logit. University of California, Berkeley.
